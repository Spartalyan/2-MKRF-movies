# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <b>Привет, Мария!👋
#
# Меня зовут Эльвира, я буду ревьюером твоего проекта. Предлагаю общаться на «ты», но если это не удобно - дай мне знать, и мы перейдем на «вы».
#
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Такими комментариями я буду помечать отлично проделаную работу😉
# </div>
#
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# В таких комментариях я постараюсь подсказать тебе более элегантное или легкое решение, некоторые хитрости и фишки. Части проекта, помеченные такими комментариями, можно не исправлять, но рекомендую обратить на них внимание.</div>
#
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 🤔<a class="tocSkip"></h2>
#
# В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Если ты видишь такой комментарий, значит здесть есть недочет, который следует исправить.
# </div>
#
# Ты также можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. Это нужно, чтобы не создавалась путаница🙃
#
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Чтобы сделать подобный блок, кликни здесь дважды и скопируй всю предыдущую строку ;)
#
# Пожалуйста, не удаляй и не перемещай мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.</div></b>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Привет, Эльвира)</div>

# %% [markdown]
# ## Исследование данных о российском кинопрокате

# %% [markdown]
# ### В этой работе мы изучим рынок российского кинопроката.
#
# #### С помощью анализа бюджета, сборов и рейтингов проанализируем вышедшие в прокат фильмы. Выделим тренды, рассмотрим окупаемость фильмов. Отдельно изучим фильмы получающие государственную поддержку.
#
# Для анализа используем данные опубликованные на портале открытых данных министерства культуры Российской Федерации.
#
# План работы:
#
# 1) Получить данные и преобразовать их.
#
# 2) Провести первичный анализ и преобрабоку данных:
#
#  - Изучить формат, где необходимо внести корректировки.
#  - Изучить пропуски, где возможно дополнить необходимой информацией.
#  - Проверить данные на наличие дубликатов, явных и нет.
#  - Добавить столбцы с необходимой для дальнейшего исследовательского анализа данными.
#
# 3) Провести исследователский анализ.
#
# 3.1 Анализ всех фильмов вышедших в кинопрокат.
#
# - Анализ количества фильмов в разные периоды времени.
#
# - Анализ сборов в общем по годам и средних медианных прказателей.
#
# - Взимосвязь сборов по ранзным категориям фильмов.
#
# 3.2 Анализ фильов получивших государственную поддержку.
#
# - Сколько фильмов с поддержкой выходило за данный период времени, с разбивкой по годам и по источникам финансирования.
# - Анализ бюджета, "условная окупаемость" фильмов.
# - Анализ сборов по годам, динамика.
# - Топ самых дорогих фильмов.
# - Топ самых кассовых фильмов.
# - Топ самых популярных у зрителей фильмов.
# - Самые популярные и самые кассовые фильмы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 🤔<a class="tocSkip"></h2>
# <s>
# Введение, как и общий вывод - важные части твоей работы, на которые в первую очередь обращает внимание заказчик. Давай добавим следующие пункты:
# * заголовок,
#
# * краткое описание проекта,
#
# * выделим цель проекта
#
# * описание данных
#
# * краткий план работы, выделим основные этапы, которые должны сделать.
#
# Тогда получатель отчета сможет быстрей его понять.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>  Добавила. </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# Хорошо)

# %% [markdown]
# ### Шаг 1. Откройте файлы с данными и объедините их в один датафрейм.
#
# Объедините данные таким образом, чтобы все объекты из датасета `mkrf_movies` обязательно вошли в получившийся датафрейм.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_0" aria-expanded="false" aria-controls="collapseHint_0">Подсказка</button>
#         </div>
#         <div id="collapseHint_0" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на тип данных столбца, по которому будете соединять датафреймы. Тип данных этих столбцов должен быть одинаковым в обоих датафреймах.
#             </div>
#         </div>
#     </div>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/datasets/mkrf_movies.csv')
df2 = pd.read_csv('/datasets/mkrf_shows.csv')

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Блок загрузки библиотек лучше размещать в отдельной от остального кода ячейке. Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок (есть они есть) и исключит повторное выполнение кода. </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>  Done. </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# 👍

# %%
df1.head()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                                NaN
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
# 2    «18+» - запрещено для детей                 NaN                    NaN
# 3    «18+» - запрещено для детей                 NaN                    NaN
# 4    «18+» - запрещено для детей                 NaN                    NaN
#
#    budget financing_source ratings                     genres
# 0     NaN              NaN     7.2     боевик,драма,мелодрама
# 1     NaN              NaN     6.6              драма,военный
# 2     NaN              NaN     6.8  фантастика,боевик,триллер
# 3     NaN              NaN     6.8  фантастика,боевик,триллер
# 4     NaN              NaN     6.8  фантастика,боевик,триллер

# %% [markdown]
#     Первый содержит данные краткую информацию о фильме (номер прокатного удостоверения, дату показа, страна, режсссер, продюссер, возрастная категория, жанр и пр), а так же, где возможно информацию о бюджете.

# %%
df2.head()
# Out:
#     puNumber   box_office
# 0  111000113      2450.00
# 1  111000115     61040.00
# 2  111000116 153030013.40
# 3  111000117  12260956.00
# 4  111000118 163684057.79

# %%
#Убираем экспоненциальную запись числа
pd.set_option("display.float_format", "{:.2f}".format)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Очень хорошо)

# %% [markdown]
#     Во втором информация о кассовом сборе фильма по прокатному номеру.

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# #### Шаг 2.1. Проверьте типы данных
#
# - Проверьте типы данных в датафрейме и преобразуйте их там, где это необходимо.

# %% [markdown]
# Рассмотрим информацию об этих таблицах подробнее.

# %%
print(df1.info())
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 877.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB
# None

# %% [markdown]
#    Нам нужно объединить два датафрейма. Будем это делать по графе с одинаковыми данными по первому и второму массиву, номеру прокатного удостоверения. Но в первом массиве в этой графе общий тип данных, в то время как во втором он целочисленный. Второй вариант вернее, преобразуем столбец puNumber в первом массииве.

# %%
#df1['puNumber'] = pd.to_numeric(df1['puNumber'])
#df1.info()

# %% [markdown]
# Не получается. Рассмотрим в каком месте возникла заминка.

# %%
df1[~df1['puNumber'].str.isdigit()]
# Out:
#                                   title    puNumber           show_start_date  \
# 804               Паранормальный Якутск   111004112  2012-08-24T12:00:00.000Z
# 1797  Курбан-роман. (История с жертвой)         нет  2014-05-15T12:00:00.000Z
#
#                 type       film_studio production_country    director  \
# 804   Художественный  ИП Тимофеев К.П.             Россия  К.Тимофеев
# 1797  Художественный  ФОНД "ИННОВАЦИЯ"             Россия     С.Юзеев
#
#         producer                  age_restriction  refundable_support  \
# 804          NaN  «16+» - для детей старше 16 лет                 NaN
# 1797  М.Галицкая  «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings genres
# 804                     NaN     NaN              NaN     NaN    NaN
# 1797                    NaN     NaN              NaN     NaN    NaN

# %% [markdown]
# Всего 2 строки.
#
# В первой скорее всего есть пробел, в начале или в конце, удалим.
#
#
# Во втором, нет информации о номере прокатного удостоверения. Возможно у этого фильма, его просто нет, а может данные утерялись. В любом случаем заменм на 0.
# И повторим плопытку перевести данные в другой формат.

# %%
df1['puNumber'] = df1['puNumber'].str.replace('нет', '0').str.strip()
df1['puNumber'] = pd.to_numeric(df1['puNumber'], errors='coerce')

# %% [markdown]
# Теперь соеденим 2 датафрейма в 1.

# %%
movies = df1.merge(df2, on = 'puNumber', how='left')
movies.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   int64
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
#  15  box_office             3158 non-null   float64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 994.2+ KB

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 🤔<a class="tocSkip"></h2>
#   <s>
# Так как нас интересуют сборы только тех фильмов, информация о которых есть в таблице с фильмами, лучше выбрать другой способ объединения, при котором попадет только нужная информация)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>  Хмм, то есть я неправильно поняла задание и нам нужно провести анализ фильмов исключиетльно вышедших в прокат в кинотеатрах? То есть за основу взять информацию из второго датафрейма, только те фильмы которые выходили в кинопрокат? Сейчас поправлю.
#
# UPD Поправила все, взяв за основу второй дафрейм вот так
#
# movies = df2.merge(df1, on = 'puNumber', how='inner')
#
# Но из-за этого пошли ошибки, когда дело дошло до сравненяе общего числа вышедших фильмов и фильмов которые показывали в кино. Так как я исключила из датафрейма фильмы которых не было во второй таблице.
#
# Это лишило данную стадию анализа всякого смысла. Потому вернула все как было.</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 🤔<a class="tocSkip"></h2>
# <s>
# Нет, нам нужны не только пользователи, которые есть в обоих таблицах, но и те о которых есть информация в таблице с фильмами. То есть нужно задать параметр `left`, вместо `outer`

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#     Не понимаю.
#     Ты пишешь:
#     "Нет, нам нужны не только пользователи, которые есть в обоих таблицах, но и те о которых есть информация в таблице с фильмами. "
#
#     то есть нам нужны не только пользователи из ДВУХ таблиц, но и пользователи из первой таблицы. Так они же включены в то число.
#
#
#     "Ему противоположен тип слияния outer (от англ. «внешний», здесь значит «объединение данных»). Он объединяет данные из внешней общей области — такие, которые есть хотя бы в одном из датафреймов."
#
#
#     Я переписала код с "left" и данные остались такие же. Что логично, ведь фильмы из df1 включают в себя фильмы из df2.</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_3<a class="tocSkip"> </h2>
#
# Верно, но если бы у нас были лишние данные в столбце с кассовыми сборами о фильмах, которых не было в первой таблице, то при объединении через `outer` они попали бы в общую таблицу, а нам они для анализа никак не помогли бы. Поэтому важно  понимать принципы работы объединения таблиц)

# %%
movies.head()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                                NaN
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
# 2    «18+» - запрещено для детей                 NaN                    NaN
# 3    «18+» - запрещено для детей                 NaN                    NaN
# 4    «18+» - запрещено для детей                 NaN                    NaN
#
#    budget financing_source ratings                     genres  box_office
# 0     NaN              NaN     7.2     боевик,драма,мелодрама         NaN
# 1     NaN              NaN     6.6              драма,военный         NaN
# 2     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 3     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 4     NaN              NaN     6.8  фантастика,боевик,триллер         NaN

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   int64
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
#  15  box_office             3158 non-null   float64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 994.2+ KB

# %% [markdown]
# На выходе получилась одна общая таблица которая объединяет в себе информацию из каждого массива.
# В данных содержится информация о 7486 фильмах.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Молодец, что проверяешь таблицу после объединения)

# %% [markdown]
# Поправим формат даты.

# %%
movies['show_start_date'] = (
    pd.to_datetime(movies['show_start_date'],
                   format=('%Y-%m-%dT%H:%M:%S.%fZ'))
                           .dt.date
                          )

# %% [markdown]
# Рассмотрим чуть подробнее информацию о рейтингах.

# %%
movies['ratings'].unique()
# Out:
# array(['7.2', '6.6', '6.8', '7.7', '8.3', '8.0', '7.8', '8.1', '7.1',
#        '6.0', '7.4', '5.8', '8.7', '6.3', '6.9', '5.0', '4.3', '7.3',
#        '7.0', '6.4', nan, '8.2', '7.5', '6.7', '7.9', '5.9', '6.2', '5.6',
#        '6.5', '2.4', '7.6', '6.1', '8.6', '8.5', '8.8', '5.5', '5.1',
#        '5.7', '5.4', '99%', '4.4', '4.5', '5.3', '4.1', '8.4', '2.6',
#        '3.8', '4.6', '4.8', '4.0', '3.0', '1.6', '4.2', '5.2', '4.7',
#        '4.9', '3.9', '2.7', '3.3', '2.9', '28%', '3.7', '1.4', '3.1',
#        '97%', '3.5', '3.2', '2.8', '1.5', '2.1', '2.5', '9.2', '3.4',
#        '1.1', '3.6', '83%', '64%', '91%', '94%', '62%', '79%', '90%',
#        '19%', '88%', '1.0', '89%', '1.3', '1.9', '1.8', '1.2', '1.7',
#        '9.0', '98%', '8.9', '9.1'], dtype=object)

# %% [markdown]
# Часть рейтингов указана в бальной системе, от 0 до 10. Часть в процентном виде. Приведем все к одинаковому формату, десятибальной шкале.

# %%
#Заменим знаки % на пробел, затем удалим его
movies['ratings'] = movies['ratings'].str.replace('%', '').str.strip()
#приеобразуем формат столбца на числовой
movies['ratings'] = pd.to_numeric(movies['ratings'], errors='coerce')
#рейтинги размером от 10 до 100 (бывшие процентные значения, разделим на 10 и перезапишем столбец)
movies.loc[movies['ratings'] > 10, 'ratings'] = movies.loc[movies['ratings'] > 10, 'ratings'] / 10

# %%
movies['ratings'].unique()
# Out:
# array([7.2, 6.6, 6.8, 7.7, 8.3, 8. , 7.8, 8.1, 7.1, 6. , 7.4, 5.8, 8.7,
#        6.3, 6.9, 5. , 4.3, 7.3, 7. , 6.4, nan, 8.2, 7.5, 6.7, 7.9, 5.9,
#        6.2, 5.6, 6.5, 2.4, 7.6, 6.1, 8.6, 8.5, 8.8, 5.5, 5.1, 5.7, 5.4,
#        9.9, 4.4, 4.5, 5.3, 4.1, 8.4, 2.6, 3.8, 4.6, 4.8, 4. , 3. , 1.6,
#        4.2, 5.2, 4.7, 4.9, 3.9, 2.7, 3.3, 2.9, 2.8, 3.7, 1.4, 3.1, 9.7,
#        3.5, 3.2, 1.5, 2.1, 2.5, 9.2, 3.4, 1.1, 3.6, 9.1, 9.4, 9. , 1.9,
#        1. , 8.9, 1.3, 1.8, 1.2, 1.7, 9.8])

# %%
movies.head()
# Out:
#                   title   puNumber show_start_date            type  \
# 0      Открытый простор  221048915      2015-11-27  Художественный
# 1  Особо важное задание  111013716      2016-09-13  Художественный
# 2          Особо опасен  221038416      2016-10-10  Художественный
# 3          Особо опасен  221026916      2016-06-10  Художественный
# 4          Особо опасен  221030815      2015-07-29  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                                NaN
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
# 2    «18+» - запрещено для детей                 NaN                    NaN
# 3    «18+» - запрещено для детей                 NaN                    NaN
# 4    «18+» - запрещено для детей                 NaN                    NaN
#
#    budget financing_source  ratings                     genres  box_office
# 0     NaN              NaN     7.20     боевик,драма,мелодрама         NaN
# 1     NaN              NaN     6.60              драма,военный         NaN
# 2     NaN              NaN     6.80  фантастика,боевик,триллер         NaN
# 3     NaN              NaN     6.80  фантастика,боевик,триллер         NaN
# 4     NaN              NaN     6.80  фантастика,боевик,триллер         NaN

# %% [markdown]
# В этой части работы:
#
# - Объеденена информация из двух датафреймов в один.
#
# - Подкорректирован столбец в датой начала проката.
#
# - Данные о рейтингах приведены в к общему виду.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
#  Типы скорректированы верно)

# %% [markdown]
# #### Шаг 2.2. Изучите пропуски в датафрейме
#
# - Объясните, почему заполнили пропуски определённым образом или почему не стали этого делать.

# %% [markdown]
# Изучим общую информацию о пропусках

# %%
movies.isna().sum()
# Out:
# title                       0
# puNumber                    0
# show_start_date             0
# type                        0
# film_studio                18
# production_country          2
# director                    9
# producer                  568
# age_restriction             0
# refundable_support       7154
# nonrefundable_support    7154
# budget                   7154
# financing_source         7154
# ratings                   967
# genres                    976
# box_office               4328
# dtype: int64

# %%
pd.DataFrame(round(movies.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_49e71_row0_col0,#T_49e71_row1_col0,#T_49e71_row2_col0,#T_49e71_row3_col0,#T_49e71_row4_col0,#T_49e71_row5_col0,#T_49e71_row6_col0,#T_49e71_row8_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_49e71_row7_col0{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_49e71_row9_col0,#T_49e71_row10_col0,#T_49e71_row11_col0,#T_49e71_row12_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_49e71_row13_col0,#T_49e71_row14_col0{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_49e71_row15_col0{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }</style><table id="T_49e71_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_49e71_level0_row0" class="row_heading level0 row0" >title</th>
#                         <td id="T_49e71_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row1" class="row_heading level0 row1" >puNumber</th>
#                         <td id="T_49e71_row1_col0" class="data row1 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row2" class="row_heading level0 row2" >show_start_date</th>
#                         <td id="T_49e71_row2_col0" class="data row2 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row3" class="row_heading level0 row3" >type</th>
#                         <td id="T_49e71_row3_col0" class="data row3 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row4" class="row_heading level0 row4" >film_studio</th>
#                         <td id="T_49e71_row4_col0" class="data row4 col0" >0.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row5" class="row_heading level0 row5" >production_country</th>
#                         <td id="T_49e71_row5_col0" class="data row5 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row6" class="row_heading level0 row6" >director</th>
#                         <td id="T_49e71_row6_col0" class="data row6 col0" >0.100000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row7" class="row_heading level0 row7" >producer</th>
#                         <td id="T_49e71_row7_col0" class="data row7 col0" >7.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row8" class="row_heading level0 row8" >age_restriction</th>
#                         <td id="T_49e71_row8_col0" class="data row8 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row9" class="row_heading level0 row9" >refundable_support</th>
#                         <td id="T_49e71_row9_col0" class="data row9 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row10" class="row_heading level0 row10" >nonrefundable_support</th>
#                         <td id="T_49e71_row10_col0" class="data row10 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row11" class="row_heading level0 row11" >budget</th>
#                         <td id="T_49e71_row11_col0" class="data row11 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row12" class="row_heading level0 row12" >financing_source</th>
#                         <td id="T_49e71_row12_col0" class="data row12 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row13" class="row_heading level0 row13" >ratings</th>
#                         <td id="T_49e71_row13_col0" class="data row13 col0" >12.900000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row14" class="row_heading level0 row14" >genres</th>
#                         <td id="T_49e71_row14_col0" class="data row14 col0" >13.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_49e71_level0_row15" class="row_heading level0 row15" >box_office</th>
#                         <td id="T_49e71_row15_col0" class="data row15 col0" >57.800000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Прослеживается закономерность. Одинаковое количество пропусков в графах об источниках государственного финансирования, объеме возвратных средств государственной поддержки, объеме возвратных средств государственной поддержки и бюджете.
#
# Все вполне логично, в графе budget указан полный объем государственной поддерржки, в остальных столбцах подробности этой поддержки, ее источник и объемы тех и иных средств. Следовательно, можно заменить пропуски в financing_source на "Частное". Пропуски в количественных данных бюджета, оставим без изменений, чтоб они не размазывали картину значений.

# %%
movies['financing_source'] = movies['financing_source'].fillna('Частное')

# %% [markdown]
# Рассмотрим фильмы без государственного финансирования.

# %%
movies.query('financing_source == "Частное"')
# Out:
#                                              title   puNumber show_start_date  \
# 0                                 Открытый простор  221048915      2015-11-27
# 1                             Особо важное задание  111013716      2016-09-13
# 2                                     Особо опасен  221038416      2016-10-10
# 3                                     Особо опасен  221026916      2016-06-10
# 4                                     Особо опасен  221030815      2015-07-29
# ...                                            ...        ...             ...
# 7481     Сад художника: Американский импрессионизм  126008019      2019-12-23
# 7482                               Звериная ярость  121037819      2019-12-24
# 7483     Щенячий патруль: Скорей спешим на помощь!  124010819      2019-12-28
# 7484      Машины песенки. Серия "Испанские мотивы"  124010619      2019-12-30
# 7485  Машины песенки. Серия "Когда цветут кактусы"  124010719      2019-12-30
#
#                  type                                        film_studio  \
# 0      Художественный  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...
# 1      Художественный                              Киностудия "Мосфильм"
# 2      Художественный  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...
# 3      Художественный  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...
# 4      Художественный  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...
# ...               ...                                                ...
# 7481           Прочие                               Севен Артс Продакшнз
# 7482   Художественный  Дэниел Гродник Продакшнз, Вандерфилм Медиа Кор...
# 7483   Художественный           Никелодеон Анимейшн Студиос, Спин Мастер
# 7484     Анимационный           Анимаккорд Лтд., ООО Студия "АНИМАККОРД"
# 7485     Анимационный           Анимаккорд Лтд., ООО Студия "АНИМАККОРД"
#
#            production_country           director  \
# 0                         США      Кевин Костнер
# 1                        СССР          Е.Матвеев
# 2                         США  Тимур Бекмамбетов
# 3                         США  Тимур Бекмамбетов
# 4                         США  Тимур Бекмамбетов
# ...                       ...                ...
# 7481           Великобритания        Фил Грабски
# 7482                      США         Ник Пауэлл
# 7483             США - Канада   Чарльз Е.Бастьен
# 7484  Республика Кипр, Россия           А.Беляев
# 7485  Республика Кипр, Россия           И.Трусов
#
#                                                producer  \
# 0             Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1                                                   NaN
# 2     Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3     Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4     Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# ...                                                 ...
# 7481                                        Фил Грабски
# 7482  Джефф Боулер, Дэниэл Гродник, Луильо Руис, Брэ...
# 7483                                     Дженнифер Додж
# 7484                                          Д.Ловейко
# 7485                                          Д.Ловейко
#
#                              age_restriction  refundable_support  \
# 0                «18+» - запрещено для детей                 NaN
# 1              «6+» - для детей старше 6 лет                 NaN
# 2                «18+» - запрещено для детей                 NaN
# 3                «18+» - запрещено для детей                 NaN
# 4                «18+» - запрещено для детей                 NaN
# ...                                      ...                 ...
# 7481         «12+» - для детей старше 12 лет                 NaN
# 7482         «16+» - для детей старше 16 лет                 NaN
# 7483  «0+» - для любой зрительской аудитории                 NaN
# 7484  «0+» - для любой зрительской аудитории                 NaN
# 7485  «0+» - для любой зрительской аудитории                 NaN
#
#       nonrefundable_support  budget financing_source  ratings  \
# 0                       NaN     NaN          Частное     7.20
# 1                       NaN     NaN          Частное     6.60
# 2                       NaN     NaN          Частное     6.80
# 3                       NaN     NaN          Частное     6.80
# 4                       NaN     NaN          Частное     6.80
# ...                     ...     ...              ...      ...
# 7481                    NaN     NaN          Частное      NaN
# 7482                    NaN     NaN          Частное     5.40
# 7483                    NaN     NaN          Частное      NaN
# 7484                    NaN     NaN          Частное      NaN
# 7485                    NaN     NaN          Частное     6.30
#
#                          genres  box_office
# 0        боевик,драма,мелодрама         NaN
# 1                 драма,военный         NaN
# 2     фантастика,боевик,триллер         NaN
# 3     фантастика,боевик,триллер         NaN
# 4     фантастика,боевик,триллер         NaN
# ...                         ...         ...
# 7481                        NaN         NaN
# 7482             боевик,триллер         NaN
# 7483                        NaN         NaN
# 7484                        NaN         NaN
# 7485            комедия,вестерн         NaN
#
# [7154 rows x 16 columns]

# %% [markdown]
# Пропуски в таких графах как студия производитель, и жанр скорее всего связаны просто с отсутствием данных. Можем заменить на значение "не указано"

# %%
movies['film_studio'] = movies['film_studio'].fillna('не указана')
movies['genres'] = movies['genres'].fillna('не указан')

# %% [markdown]
# Продюссер и режиссер. Может такое быть, что у фильма один человек исполняет эти две роли.
# Заполним пропуски в этих столбцах, копируя данные друг у друга.
#
# Если же нет ни одного, ни второго, то запишем "нет данных".

# %%
movies['director'] = movies['director'].fillna(value=movies['producer'])
movies['producer'] = movies['producer'].fillna(value='нет данных')
movies['producer'] = movies['producer'].fillna(value='нет данных')

# %% [markdown]
# Пропуски в данных о рейтинге могут быть связаны отсутствием каких-либо оценок у фильма, возможно он еще не вышел в прокат, или просто не захотел пока никто оценить. Оставим без изменений.

# %%
movies.loc[movies['ratings'].isna()].head(30)
# Out:
#                                                  title   puNumber  \
# 43            Мемуары гейши (по роману Артура Голдена)  121000606
# 150                                           Жди меня  111013615
# 154   Дом из песка и тумана (по книге Андре Дюбуи III)  221037813
# 159                                  Жемчужная девушка  224011014
# 227                                         Полустанок  111026714
# 264  Разбойник и принцесса /По мотивам сказок Карел...  224010714
# 411  Пьетро Масканьи. Сельская честь /По одноименно...  126001812
# 412                                      Опера на льду  126001712
# 427  Франческо Чилеа. Адриана Лекуврёр /По одноимен...  126000412
# 443  Артур Сеймур Салливан. Микадо. Постановка Sydn...  126000212
# 444  Три тенора: Лучано Паваротти, Пласидо Доминго ...  126000312
# 499  Гаэтано Доницетти. Лукреция Борджиа 3D /По одн...  126001312
# 507  Гаэтано Доницетти. Анна Болейн /По пьесам Иппо...  126001512
# 508  Джузеппе Верди. Макбет /По одноименной пьесе Ш...  126001612
# 537  Осторожно, Любовь! (S.O.S Love! - The Million ...  121005812
# 541  Вольфганг Амадей Моцарт. Волшебная флейта. Пос...  126000912
# 546                         Киногамма. Часть 1: Восток  126001012
# 547                 Киногамма. Часть 2: Дальний Восток  126001112
# 558                                                1+1  121009812
# 567                                               Ася_  111002712
# 608                                     Старинные часы  111001712
# 626                             Маттиола пахнет духами  112000112
# 657                               Нью-йоркская куколка  126000612
# 694                   Приключения итальянцев в Марокко  121032212
# 723  Умберто Джордано. Андре Шенье. Постановка фест...  126001613
# 724  Луи-Джозеф-Фердинанд Герольд. Тщетная предосто...  126001713
# 754  Джузеппе Верди. Травиата /По мотивам романа "Д...  126002612
# 763  Рихард Штраус. Кавалер розы. Постановка Флорен...  126003412
# 764  Три звезды. Концерт в Waldbuhne Theater, Берли...  126003512
# 765  Петр Ильич Чайковский. Щелкунчик /По мотивам с...  126003612
#
#     show_start_date            type  \
# 43       2012-12-14  Художественный
# 150      2015-08-25  Художественный
# 154      2013-10-25  Художественный
# 159      2014-08-28  Художественный
# 227      2014-12-24  Художественный
# 264      2014-08-28  Художественный
# 411      2012-05-29          Прочие
# 412      2012-05-29          Прочие
# 427      2012-02-07          Прочие
# 443      2012-01-27          Прочие
# 444      2012-01-27          Прочие
# 499      2012-04-03          Прочие
# 507      2012-04-17          Прочие
# 508      2012-04-17          Прочие
# 537      2012-03-05  Художественный
# 541      2012-03-13          Прочие
# 546      2012-03-15          Прочие
# 547      2012-03-15          Прочие
# 558      2012-04-17  Художественный
# 567      2012-05-04  Художественный
# 608      2012-02-22  Художественный
# 626      2012-01-16  Документальный
# 657      2012-02-16          Прочие
# 694      2012-12-21  Художественный
# 723      2013-05-07          Прочие
# 724      2013-05-07          Прочие
# 754      2012-10-01          Прочие
# 763      2012-12-04          Прочие
# 764      2012-12-04          Прочие
# 765      2012-12-17          Прочие
#
#                                            film_studio  \
# 43   Коламбия Пикчерз Корпорейшн, ДримУоркс ЭсКейДж...
# 150                              Киностудия "Мосфильм"
# 154                                    Кобальт Пикчерз
# 159  Чешское телевидение,Студия "Три брата" агентск...
# 227                              Киностудия "Мосфильм"
# 264                                Чешское телевидение
# 411                                     Эр А И Синема
# 412                                     Нексо Диджитал
# 427                                          Опус Арте
# 443                                        Синема Лайв
# 444                                              Декка
# 499           И Эн О, Скай 3D, Скай Артс, Мор Ту Скрин
# 507                                 Ризинг Альтернатив
# 508                                          Опус Арте
# 537    Имаджиком Продакшнз,Эстлейк Филмз, Солт Студио
# 541                                       Р А И Синема
# 546                                 Фильм Дистрибусьон
# 547                                 Фильм Дистрибусьон
# 558  Гомон, Куад Продюксьон, Чаокорп, ТФ1 Фильм Про...
# 567                            ООО "Кинокомпания Леда"
# 608                                   ООО "ЛЕДА-ФИЛЬМ"
# 626  ОАО "ТПО "Санкт-Петербургская студия документа...
# 657                              Уан Потейто Продакшнз
# 694          Италиан Дримс Фектори, МиБак, Рай Синема
# 723                                             Эр А И
# 724                                           Опус Арт
# 754        Райзинг Алтернатив, Классик, Юнител Классик
# 763                                        Микросинема
# 764                                 Райзинг Алтернатив
# 765                                          Опус Арте
#
#                  production_country  \
# 43                              США
# 150                            СССР
# 154                             США
# 159                           Чехия
# 227                            СССР
# 264                           Чехия
# 411                          Италия
# 412                          Италия
# 427                  Великобритания
# 443                       Австралия
# 444                          Италия
# 499                  Великобритания
# 507                  Великобритания
# 508                  Великобритания
# 537  США - Венгрия - Великобритания
# 541                          Италия
# 546                         Франция
# 547                         Франция
# 558                         Франция
# 567                          Россия
# 608                          Россия
# 626                          Россия
# 657                             США
# 694                          Италия
# 723                          Италия
# 724                  Великобритания
# 754                  Великобритания
# 763                  Великобритания
# 764                  Великобритания
# 765                  Великобритания
#
#                                               director  \
# 43                                         Роб Маршалл
# 150                                А.Столпер, Б.Иванов
# 154                                    Вадим Перельман
# 159                                      Владимир Дрга
# 227                                           Б.Барнет
# 264                                       Карел Смычек
# 411                                      Марио Мартоне
# 412                                   Кристиан Биодани
# 427                                     Дэвид Маквикар
# 443                                     Стюарт Маундер
# 444                                       Брайан Лардж
# 499                                       Майкл Фиггис
# 507                                      Эрик Геновеси
# 508                                      Филлида Ллойд
# 537                                          Томаш Сас
# 541                                    Уильям Кентридж
# 546                                            Зигфрид
# 547                                            Зигфрид
# 558                       Оливье Накаша, Эрик Толедано
# 567                                          А.Кулямин
# 608                                         Е.Борисова
# 626                                       М.Железников
# 657                                       Грег Уайтели
# 694                                  Франческо Фаласки
# 723                                         Кит Уорнер
# 724                       хореография Фредерика Эштона
# 754                                    Тизнано Манчини
# 763                                         Айке Грамс
# 764                                          не указан
# 765  хореография Питера Райта, Льва Иванова по разр...
#
#                                               producer  \
# 43   Стивен Спилберг, Люси Фишер, Дуглас Уик, Джон ...
# 150                                          не указан
# 154                                       Майкл Лондон
# 159                                          не указан
# 227                                          не указан
# 264                                          не указан
# 411                                           Ла Скала
# 412                 Джиглиола Барбьери, Паоло де Биаси
# 427                                       Дэвид Гроувс
# 443                                        Синема Лайв
# 444                                    Герберт Чаппелл
# 499                                          не указан
# 507                                          не указан
# 508                                          не указан
# 537  Томас Кониглиаро, Томаш Сас, Агнес Фернандез, ...
# 541                                          не указан
# 546                                            Зигфрид
# 547                                            Зигфрид
# 558  Николас Дювал-Адассовский, Лоран Зейтун, Янн Зену
# 567                                        Е.Борисовна
# 608                                         Е.Борисова
# 626                                          А.Тельнов
# 657                           Эд Каннингэм, Сет Гордон
# 694  Мохамед Асли, Джулио Виолати, Сильвия Натили, ...
# 723                                          не указан
# 724                                          не указан
# 754                                      Пьеро Маранчи
# 763                                          не указан
# 764                                    Вальдбюне Театр
# 765                                      Ковент Гарден
#
#                             age_restriction  refundable_support  \
# 43          «12+» - для детей старше 12 лет                 NaN
# 150           «6+» - для детей старше 6 лет                 NaN
# 154         «16+» - для детей старше 16 лет                 NaN
# 159  «0+» - для любой зрительской аудитории                 NaN
# 227         «12+» - для детей старше 12 лет                 NaN
# 264  «0+» - для любой зрительской аудитории                 NaN
# 411  «0+» - для любой зрительской аудитории                 NaN
# 412  «0+» - для любой зрительской аудитории                 NaN
# 427  «0+» - для любой зрительской аудитории                 NaN
# 443  «0+» - для любой зрительской аудитории                 NaN
# 444  «0+» - для любой зрительской аудитории                 NaN
# 499  «0+» - для любой зрительской аудитории                 NaN
# 507  «0+» - для любой зрительской аудитории                 NaN
# 508  «0+» - для любой зрительской аудитории                 NaN
# 537         «16+» - для детей старше 16 лет                 NaN
# 541  «0+» - для любой зрительской аудитории                 NaN
# 546         «16+» - для детей старше 16 лет                 NaN
# 547         «16+» - для детей старше 16 лет                 NaN
# 558         «16+» - для детей старше 16 лет                 NaN
# 567         «16+» - для детей старше 16 лет                 NaN
# 608  «0+» - для любой зрительской аудитории                 NaN
# 626  «0+» - для любой зрительской аудитории                 NaN
# 657         «16+» - для детей старше 16 лет                 NaN
# 694         «12+» - для детей старше 12 лет                 NaN
# 723  «0+» - для любой зрительской аудитории                 NaN
# 724  «0+» - для любой зрительской аудитории                 NaN
# 754  «0+» - для любой зрительской аудитории                 NaN
# 763  «0+» - для любой зрительской аудитории                 NaN
# 764  «0+» - для любой зрительской аудитории                 NaN
# 765  «0+» - для любой зрительской аудитории                 NaN
#
#      nonrefundable_support  budget financing_source  ratings     genres  \
# 43                     NaN     NaN          Частное      NaN  не указан
# 150                    NaN     NaN          Частное      NaN  не указан
# 154                    NaN     NaN          Частное      NaN  не указан
# 159                    NaN     NaN          Частное      NaN  не указан
# 227                    NaN     NaN          Частное      NaN  не указан
# 264                    NaN     NaN          Частное      NaN  не указан
# 411                    NaN     NaN          Частное      NaN  не указан
# 412                    NaN     NaN          Частное      NaN  не указан
# 427                    NaN     NaN          Частное      NaN  не указан
# 443                    NaN     NaN          Частное      NaN  не указан
# 444                    NaN     NaN          Частное      NaN  не указан
# 499                    NaN     NaN          Частное      NaN  не указан
# 507                    NaN     NaN          Частное      NaN  не указан
# 508                    NaN     NaN          Частное      NaN  не указан
# 537                    NaN     NaN          Частное      NaN  не указан
# 541                    NaN     NaN          Частное      NaN  не указан
# 546                    NaN     NaN          Частное      NaN  не указан
# 547                    NaN     NaN          Частное      NaN  не указан
# 558                    NaN     NaN          Частное      NaN  не указан
# 567                    NaN     NaN          Частное      NaN  не указан
# 608                    NaN     NaN          Частное      NaN  не указан
# 626                    NaN     NaN          Частное      NaN  не указан
# 657                    NaN     NaN          Частное      NaN  не указан
# 694                    NaN     NaN          Частное      NaN  не указан
# 723                    NaN     NaN          Частное      NaN  не указан
# 724                    NaN     NaN          Частное      NaN  не указан
# 754                    NaN     NaN          Частное      NaN  не указан
# 763                    NaN     NaN          Частное      NaN  не указан
# 764                    NaN     NaN          Частное      NaN  не указан
# 765                    NaN     NaN          Частное      NaN  не указан
#
#      box_office
# 43          NaN
# 150         NaN
# 154         NaN
# 159         NaN
# 227         NaN
# 264         NaN
# 411         NaN
# 412         NaN
# 427         NaN
# 443         NaN
# 444         NaN
# 499         NaN
# 507    16330.00
# 508         NaN
# 537         NaN
# 541         NaN
# 546         NaN
# 547         NaN
# 558     1600.00
# 567         NaN
# 608     2200.00
# 626         NaN
# 657         NaN
# 694         NaN
# 723         NaN
# 724         NaN
# 754         NaN
# 763         NaN
# 764    44350.00
# 765         NaN

# %%
pd.DataFrame(round(movies.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_d5c30_row0_col0,#T_d5c30_row1_col0,#T_d5c30_row2_col0,#T_d5c30_row3_col0,#T_d5c30_row4_col0,#T_d5c30_row5_col0,#T_d5c30_row6_col0,#T_d5c30_row7_col0,#T_d5c30_row8_col0,#T_d5c30_row12_col0,#T_d5c30_row14_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_d5c30_row9_col0,#T_d5c30_row10_col0,#T_d5c30_row11_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_d5c30_row13_col0{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_d5c30_row15_col0{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }</style><table id="T_d5c30_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d5c30_level0_row0" class="row_heading level0 row0" >title</th>
#                         <td id="T_d5c30_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row1" class="row_heading level0 row1" >puNumber</th>
#                         <td id="T_d5c30_row1_col0" class="data row1 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row2" class="row_heading level0 row2" >show_start_date</th>
#                         <td id="T_d5c30_row2_col0" class="data row2 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row3" class="row_heading level0 row3" >type</th>
#                         <td id="T_d5c30_row3_col0" class="data row3 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row4" class="row_heading level0 row4" >film_studio</th>
#                         <td id="T_d5c30_row4_col0" class="data row4 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row5" class="row_heading level0 row5" >production_country</th>
#                         <td id="T_d5c30_row5_col0" class="data row5 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row6" class="row_heading level0 row6" >director</th>
#                         <td id="T_d5c30_row6_col0" class="data row6 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row7" class="row_heading level0 row7" >producer</th>
#                         <td id="T_d5c30_row7_col0" class="data row7 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row8" class="row_heading level0 row8" >age_restriction</th>
#                         <td id="T_d5c30_row8_col0" class="data row8 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row9" class="row_heading level0 row9" >refundable_support</th>
#                         <td id="T_d5c30_row9_col0" class="data row9 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row10" class="row_heading level0 row10" >nonrefundable_support</th>
#                         <td id="T_d5c30_row10_col0" class="data row10 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row11" class="row_heading level0 row11" >budget</th>
#                         <td id="T_d5c30_row11_col0" class="data row11 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row12" class="row_heading level0 row12" >financing_source</th>
#                         <td id="T_d5c30_row12_col0" class="data row12 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row13" class="row_heading level0 row13" >ratings</th>
#                         <td id="T_d5c30_row13_col0" class="data row13 col0" >12.900000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row14" class="row_heading level0 row14" >genres</th>
#                         <td id="T_d5c30_row14_col0" class="data row14 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d5c30_level0_row15" class="row_heading level0 row15" >box_office</th>
#                         <td id="T_d5c30_row15_col0" class="data row15 col0" >57.800000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# На данном этапе работы, мы почистили данные от пропусков, где необходимо.
#
# - Кино которое не получало государственного субсидирования отметили как "частное".
#
# - Пропуски в категориях страна, продюссер, режиссер и жанр заменила на "не указано".
#
# - Пропуски в рейтингах оставили без изменений.
#
# - Пропуски в кассовых сборах,тоже оставили без изменений.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Заполнять пропуски в данных отвлеченными значениями - это не очень правильное решение. Во-первых, можно просто забыть их отфильтровать. Заполнять нужно в том случае, когда алгоритм, для которого готовятся данные, чувствителен к пропускам. Например, регрессии чувствительны, а корреляция нет. Для них заполнение может даже навредить, если заполнять маркерными значениями и забыть о фильтрации.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>  Ты про  то, что я поставила "0" в графе об объемах финансирования? Да, кажется это изменило мне кое-где картину, сейчас удалю ту замену.</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# Главное не забывать фильтрацию)

# %% [markdown]
# #### Шаг 2.3. Изучите дубликаты в датафрейме
# - Проверьте, есть ли в данных дубликаты. Опишите причины, которые могли повлиять на появление дублей.

# %% [markdown]
# Посмотрим есть ли в данных дублирующиеся строки.

# %%
print('Количество дубликатов:', movies.duplicated().sum())
# Out:
# Количество дубликатов: 0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 🤔<a class="tocSkip"></h2>
#     <s>
# Да, полных дубликатов действительно нет. НО! У нас есть столбцы, которые, по идее, должны содержать уникальные значения. Стоит проверить - так ли это.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>  Вот тут не поняла, про что ты.
#
# Про то, чтг номер прокатного удостоверения должен быть уникальным?
#
# Я это отработала дальше</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# Точно, но еще можно проверить пары название-режиссер может быть там скрыты дубликаты)

# %% [markdown]
# #### Шаг 2.4. Изучите категориальные значения
#
# - Посмотрите, какая общая проблема встречается почти во всех категориальных столбцах;
# - Исправьте проблемные значения в поле `type`.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_1" aria-expanded="false" aria-controls="collapseHint_1">Подсказка</button>
#         </div>
#         <div id="collapseHint_1" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# В поле <code>type</code> есть несколько значений, у которых появился пробел в начале строки. Самый простой способ их «починить» -- использовать метод <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html#pandas.Series.str.strip">.str.strip</a>. Этот метод удаляет все пробелы, которые встречаются в начале и в конце строки. Применяют его таким образом:<br>
# <code>df['type'].str.strip()</code>
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Рассмотрим данные на наличие неявных дубликатов.
# Изучим количество уникальных значений в каждом столбце.

# %%
movies.nunique()
# Out:
# title                    6772
# puNumber                 7484
# show_start_date          1965
# type                        8
# film_studio              5491
# production_country        950
# director                 4812
# producer                 5350
# age_restriction             5
# refundable_support         34
# nonrefundable_support      75
# budget                    290
# financing_source            4
# ratings                    84
# genres                    743
# box_office               2938
# dtype: int64

# %% [markdown]
# Ранее мы уже писали, что в данных у нас инфорция о 7486 фильмах. Отклонение от этих данных говорит нам о наличии повторящихся значений в определенной категории.
#
# Например в столбце с номером прокатного удостоверения 7484 значения.
#
# Это значит где-то есть 2 дубля.

# %%
movies.loc[movies['puNumber'].duplicated(keep=False)].sort_values(by='puNumber')
# Out:
#                                                   title   puNumber  \
# 5067                                    Анализируй это!  221054410
# 5068                                     Анализируй то!  221054410
# 4638                   Как жениться и остаться холостым  221154310
# 4639  Иоанна - женщина на папском престоле /По роман...  221154310
#
#      show_start_date            type  \
# 5067      2010-05-25  Художественный
# 5068      2010-05-25  Художественный
# 4638      2010-12-17  Художественный
# 4639      2010-12-17  Художественный
#
#                                             film_studio  \
# 5067          Уорнер Бразерс, Вилладж Роудшоу Филмз ЛТД
# 5068  Уорнер Бразерс, Виллидж Роадшоу Пикчерз, Эн-Пи...
# 4638  Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# 4639   Константин Фильм, А Эр Ди Дегето Фильм, Дюне ...
#
#                                 production_country        director  \
# 5067                                 США-Австралия   ХЭрольд Рэмис
# 5068                                           США  Гарольд Реймис
# 4638                                       Франция    Эрик Лартиго
# 4639  Германия - Великобритания - Италия - Испания  Зенке Вортманн
#
#                                         producer  \
# 5067             Джейн Розенталь, Пола Уейнстейн
# 5068             Джейн Розенталь, Паул Уэйнстейн
# 4638                     Амандин Било, Алан Шаба
# 4639  Оливер Бербен, Дорис Д.Хайнце, Фарук Элтан
#
#                       age_restriction  refundable_support  \
# 5067  «16+» - для детей старше 16 лет                 NaN
# 5068  «12+» - для детей старше 12 лет                 NaN
# 4638  «16+» - для детей старше 16 лет                 NaN
# 4639  «16+» - для детей старше 16 лет                 NaN
#
#       nonrefundable_support  budget financing_source  ratings  \
# 5067                    NaN     NaN          Частное     7.40
# 5068                    NaN     NaN          Частное     6.80
# 4638                    NaN     NaN          Частное     7.00
# 4639                    NaN     NaN          Частное     7.60
#
#                        genres  box_office
# 5067         комедия,криминал         NaN
# 5068         комедия,криминал         NaN
# 4638        мелодрама,комедия         NaN
# 4639  драма,мелодрама,история         NaN

# %% [markdown]
# Фильм "Анализируй это". Есть 2 строки в с данными о нем. Имеются различия в категории о стране о производителе в транслитерации имени режиссера, а так же разные возрастные категории. Возможно, есть 2 версии фильма. Одна более цензурированная, потому получила категорию 12+.
#
#
# Для красоты поправим имя режиссера, это не критично, но можем заменить номер второй версии на выдуманнный, например 111111111
#
#
# И есть 2 абсолютно разных фильма, с одинаковым прокатным номером. Такое невозможно. Скорее всего, это просто ошибка при оформлении данных. Не критично, но можем изменить номер на выдуманнный 222222222</div>

# %%
movies.loc[5068, 'puNumber'] = 111111111
movies.loc[4639, 'puNumber'] = 222222222
movies['director']= movies['director'].str.replace('ХЭрольд Рэмис', 'Гарольд Реймис')

# %% [markdown]
# Повторы в графе show_start_date обоснованы. В один день могло выйти несколько фильмов в прокат.

# %% [markdown]
# Изучим данные графы "type".

# %%
movies['type'].value_counts()
# Out:
# Художественный                4520
#  Художественный               1389
# Анимационный                   828
# Прочие                         406
# Документальный                 288
# Научно-популярный               53
#  Анимационный                    1
# Музыкально-развлекательный       1
# Name: type, dtype: int64

# %% [markdown]
# Есть неявные дубликаты, вызванные наличием лишних пробелов. Удалим их и посмотрим еще раз.

# %%
movies['type'] = movies['type'].str.strip()
movies['type'].value_counts()
# Out:
# Художественный                5909
# Анимационный                   829
# Прочие                         406
# Документальный                 288
# Научно-популярный               53
# Музыкально-развлекательный       1
# Name: type, dtype: int64

# %% [markdown]
# По такому же приципу уберем лишние пробелы, и пробелы в начале и в конце строки в столбцах где они могут теоритически оказаться film_studio, production_country, producer, director, и genres.

# %%
names = ['film_studio', 'production_country', 'producer', 'director', 'genres']

for name in names:
    movies[name] = movies[name].str.strip()

# %% [markdown]
# В графе title може могу быть повторы,  значит один фильм выходил в прокат не один раз, и каждый раз с новым прокатным удостоверением соотвественно.

# %%
movies.loc[movies['title'].duplicated(keep=False)].sort_values(by='title')
# Out:
#                                   title   puNumber show_start_date  \
# 455                  100 миллионов евро  121013712      2012-06-06
# 454                  100 миллионов евро  221024616      2016-05-25
# 4852                          127 часов  121000811      2011-01-27
# 5058                          127 часов  221069011      2011-05-18
# 3129   13 часов: Тайные солдаты Бенгази  221019616      2016-04-19
# ...                                 ...        ...             ...
# 4505  Я ненавижу день святого Валентина  221139210      2010-12-03
# 1704                  Я, снова я и мама  121030213      2013-11-21
# 1703                  Я, снова я и мама  121013116      2016-05-23
# 6379                       Ян Антонышев  112011818      2018-11-15
# 6380                       Ян Антонышев  112011918      2018-11-15
#
#                 type                                        film_studio  \
# 455   Художественный  Патэ, Эсквуд, Серенити Фильм, ТФ1 Фильм Продюк...
# 454   Художественный  Патэ, Эсквуд, Серенити Фильм, ТФ1 Фильм Продюк...
# 4852  Художественный  Фокс Серчлайт Пикчерз, Клод Эйт Филмз, Филм Фо...
# 5058  Художественный  Фокс Серчлайт Пикчерз, Клод Эйт Филмз, Филм Фо...
# 3129  Художественный  Парамаунт, Дан Филмз, Латина Пикчарз,3 Арт Инт...
# ...              ...                                                ...
# 4505  Художественный  Блю Стар Пикчерз, Ай Хэйт Вдэй Продакшнз, Ай С...
# 1704  Художественный  Гомон, Эль Джи Эм Продакшнз, Ректанль Продюксь...
# 1703  Художественный  Гомон, Эль Джи Эм Продакшнз, Ректанль Продюксь...
# 6379  Документальный                                         не указана
# 6380  Документальный                                         не указана
#
#         production_country       director  \
# 455                Франция   Оливер Барру
# 454                Франция   Оливер Барру
# 4852  США - Великобритания     Дэнни Бойл
# 5058  США - Великобритания     Дэнни Бойл
# 3129                   США      Майкл Бэй
# ...                    ...            ...
# 4505                   США   Ниа Вардалос
# 1704     Франция - Бельгия  Гийом Гальенн
# 1703     Франция - Бельгия  Гийом Гальенн
# 6379                Россия      Е.Окопная
# 6380                Россия      Е.Окопная
#
#                                                producer  \
# 455                                   Ричард Грандпьерр
# 454                                   Ричард Грандпьерр
# 4852            Бернард Беллью, Тесса Росс, Гаррет Смит
# 5058            Бернард Беллью, Тесса Росс, Гаррет Смит
# 3129                             Майкл Бэй, Эрвин Стофф
# ...                                                 ...
# 4505         Доминик Йанно, Мэдлейн Шерак, Уильям Шерак
# 1704  Жан-Батист Дюпон, Алис Жирар, Сирил Кольбо-Жюстен
# 1703  Жан-Батист Дюпон, Алис Жирар, Сирил Кольбо-Жюстен
# 6379                                        Е.Герасимов
# 6380                                        Е.Герасимов
#
#                       age_restriction  refundable_support  \
# 455   «16+» - для детей старше 16 лет                 NaN
# 454   «16+» - для детей старше 16 лет                 NaN
# 4852  «16+» - для детей старше 16 лет                 NaN
# 5058  «16+» - для детей старше 16 лет                 NaN
# 3129      «18+» - запрещено для детей                 NaN
# ...                               ...                 ...
# 4505  «16+» - для детей старше 16 лет                 NaN
# 1704  «16+» - для детей старше 16 лет                 NaN
# 1703  «16+» - для детей старше 16 лет                 NaN
# 6379  «12+» - для детей старше 12 лет                 NaN
# 6380  «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source  ratings  \
# 455                     NaN     NaN          Частное     6.10
# 454                     NaN     NaN          Частное     6.10
# 4852                    NaN     NaN          Частное     7.70
# 5058                    NaN     NaN          Частное     7.70
# 3129                    NaN     NaN          Частное     6.70
# ...                     ...     ...              ...      ...
# 4505                    NaN     NaN          Частное     5.00
# 1704                    NaN     NaN          Частное     6.30
# 1703                    NaN     NaN          Частное     6.30
# 6379                    NaN     NaN          Частное      NaN
# 6380                    NaN     NaN          Частное      NaN
#
#                        genres  box_office
# 455                   комедия         NaN
# 454                   комедия         NaN
# 4852  триллер,биография,драма         NaN
# 5058  триллер,биография,драма         NaN
# 3129     боевик,триллер,драма         NaN
# ...                       ...         ...
# 4505        мелодрама,комедия         NaN
# 1704  комедия,мелодрама,драма         NaN
# 1703  комедия,мелодрама,драма         NaN
# 6379                не указан         NaN
# 6380                не указан         NaN
#
# [1272 rows x 16 columns]

# %% [markdown]
# Все логично, оставляем без изменений.
#
# Рассмотрим данные о стране производителе чуть подробнее.

# %%
movies['production_country'].unique()
# Out:
# array(['США', 'СССР', 'Франция', 'СССР, Венгрия',
#        'Германия-Великобритания', 'Великобритания - Италия',
#        'Чехословакия', 'США - Франция - Турция', 'Новая Зеландия',
#        'Канада - Франция - Испания', 'США-Германия',
#        'США - Великобритания', 'Великобритания', 'США - Германия',
#        'Франция - Мексика - США', 'Россия, Казахстан, США',
#        'СССР, Швеция', 'СССР, Франция, Англия, Куба, ГДР', 'Германия',
#        'Великобритания-США-Германия-КНР',
#        'СССР, ЧССР, Западный Берлин, ПНР', 'СССР, Италия', 'Гонконг, КНР',
#        'США - Франция', 'США - Япония - Франция - Великобритания',
#        'Гонконг - Сингапур - Таиланд - Великобритания', 'США-Канада',
#        'Франция - Италия - Великобритания - США', 'Франция - США',
#        'Ирландия-Великобритания-Германия', 'Чехия', 'США-Австралия',
#        'СССР, Финляндия', 'США-Франция-Великобритания-Австрия',
#        'США - Бельгия', 'США - Ирландия - Великобритания',
#        'Великобритания - США',
#        'Люксембург - Нидерланды - Испания - Великобритания - США - Италия',
#        'Великобритания - Франция - США', 'Новая Зеландия - США',
#        'США - Великобритания - Чехия',
#        'Канада - Франция - Великобритания', 'Ирландия',
#        'Великобритания - Германия - США',
#        'США - Франция - Великобритания', 'Япония', 'СССР, Польша',
#        'Франция - Испания', 'Канада-Франция', 'Германия - Италия - США',
#        'Аргентина - Бразилия', 'Дания - Швейцария - Бельгия - Франция',
#        'США - Испания', 'Германия - США',
#        'Франция - Австрия - Германия - Италия - США', 'Австрия',
#        'США - Канада - Германия', 'США - Канада',
#        'СССР - Швейцария - Франция', 'Россия - Казахстан', 'Гонконг',
#        'Италия', 'США - ОАЭ', 'Россия',
#        'США - Франция - Испания - Великобритания',
#        'Великобритания - Франция', 'США-Италия-Испания-Аргентина',
#        'Франция-Великобритания', 'КНР - Гонконг',
#        'Франция - Италия - Швейцария', 'США - Новая Зеландия',
#        'Франция - Бельгия', 'КНР', 'Германия - Великобритания - Австрия',
#        'Великобритания - Израиль - Франция - Япония - США', 'Швеция',
#        'Испания', 'Дания', 'Франция - Бельгия - Люксембург',
#        'США - Индия - ОАЭ',
#        'Германия-Канада-Великобритания-Швейцария-Франция',
#        'Мексика - Чили', 'Аргентина', 'Бразилия', 'Чили', 'Австралия',
#        'Португалия - Франция', 'США - ЮАР', 'Исландия-Ирландия-Германия',
#        'США-Индонезия', 'Южная Корея', 'Мексика - Испания - Дания - США',
#        'Великобритания-США', 'Франция - Италия', 'США-Франция',
#        'США - Венгрия - Великобритания', 'Бельгия-Франция-Италия',
#        'Чехия - Германия', 'Германия - Франция', 'США-Нидерланды',
#        'Украина', 'Великобритания - Германия', 'Франция-Бельгия',
#        'США-Франция-Испания', 'Италия - Франция', 'Канада',
#        'Швеция-Франция-Дания', 'Германия-Франция-Польша',
#        'Франция-Великобритания - Германия',
#        'США - Бразилия - Франция - Австралия - Великобритания - Германия',
#        'Германия-Австрия', 'Германия-Италия- Шри-Ланка',
#        'Великобритания - Испания',
#        'США - Великобритания - Канада - Швеция',
#        'Босния и Герцеговина - Франция - Великобритания - Германия - Словения - Бельгия - Сербия',
#        'Великобритания - Франция - Италия - США', 'США-ОАЭ',
#        'Испания - Франция', 'США-Великобритания', 'США-ЮАР',
#        'Великобритания-Австралия - США',
#        'Норвегия - Швеция - Дания - Германия', 'Норвегия', 'Швейцария',
#        'Греция - Германия - Франция', 'Норвения', 'Южная Корея - США',
#        'Чили - Франция - США', 'Австрия - Германия - Франция',
#        'Швеция - Дания', 'Великобритания - Франция - Бельгия - Италия',
#        'Франция - Германия', 'Грузия - Франция - Люксембург',
#        'США - Франция - Великобритания - Бразилия', 'США - КНР',
#        'Мексика - Франция', 'США - Германия - Гонконг - Сингапур',
#        'Финляндия - Австрия - Россия', 'Испания - Куба',
#        'Великобритания - ЮАР', 'Великобритания - Ирландия', 'Израиль',
#        'Бразилия - Германия - Порртугалия - Франция',
#        'Франция - Канада - Бельгия', 'Франция-Испания',
#        'Испания - Канада - Япония', 'Иран', 'Швеция-Куба',
#        'США-Великобритания-Ирландия', 'Гонконг - КНР', 'Нидерланды',
#        'Испания - Канада', 'Япония-Великобритания',
#        'Великобритания - Норвегия - Дания - Германия',
#        'Финляндия - Франция - Германия',
#        'Мексика - Франция - Нидерланды - Германия', 'США - Индия',
#        'США-Великобритания-Индия', 'США-Канада-Бельгия',
#        'Республика Узбекистан', 'Турция',
#        'Сербия - Словения - Хорватия - Черногория - Македония',
#        'Киргизия', 'Германия - Нидерланды - Беларусь - Россия - Латвия',
#        'Индия', 'Нидерланды - Россия - Германия',
#        'Великобритания - Нидерланды - Франция - Хорватия',
#        'Канада - Южная Корея',
#        'Великобритания - Польша - КНР - Индия - Норвегия',
#        'Япония - Франция - США - Южная Корея - Турция',
#        'Мексика - Аргентина - Великобритания', 'Израиль - Франция',
#        'Польша - Португалия - Франция - Великобритания',
#        'Австралия - США', 'Франция - Люксембург - Бельгия', 'Армения',
#        'Бельгия - Люксембург - Франция - Швейцария',
#        'США - Великобритания - Канада', 'Норвегия - Швеция',
#        'Канада - Франция', 'КНР - Гонконг - США',
#        'США - Сингапур - Малайзия - Индонезия', 'Германия - Россия',
#        'Япония - Канада', 'Финляндия - Дания - Германия - Ирландия',
#        'Франция - Люксембург - Германия - Бельгия - Швейцария - Великобритания',
#        'Канада - США', 'США-Италия-Испания', 'США-Испания',
#        'США - Швейцария - Франция', 'Испания - США - Колумбия',
#        'Канада-ЮАР', 'Франция - Россия',
#        'Германия - Финляндия - Австралия', 'Дания - Швеция', 'Бельгия',
#        'Германия - Франция - Австрия', 'Франция-Индия', 'ЮАР',
#        'Франция-Перу', 'Франция - Канада', 'Республика Беларусь',
#        'Великобритания - Австрия - Франция - США',
#        'Австрия-Германия-Франция', 'США-Россия', 'Германия-США',
#        'США - Южная Корея', 'Канада - КНР',
#        'Дания - Швеция - Италия - Франция - Германия',
#        'Франция-Италия-Испания-Венгрия', 'Франция - Германия - Бельгия',
#        'Франция-Великобритания-Чехия', 'Румыния - Франция - Бельгия',
#        'Болгария - Франция - Изриль',
#        'Израиль - Германия - Польша - Бельгия - Франция - Люксембург',
#        'Россия, Германия, Франция, Бельгия', 'Индонезия',
#        'Франция - Португалия', 'Великобритания - Пуэрто-Рико',
#        'СССР, ФРГ, Западный Берлин', 'Россия, Республика Беларусь',
#        'США, Великобритания', 'Франция - Австрия', 'Бельгия-Нидерланды',
#        'Великобритания - США - Индия', 'США - Великобритания - Австралия',
#        'Канада - Франция - США - ОАЭ - Великобритания',
#        'США - Австралия - Франция',
#        'Дания-Франция-Бельгия-Германия-Великобритания',
#        'Испания - Аргентина', 'Исландия - Финляндия',
#        'Россия-Польша-Голландия-Словакия', 'Дания - Германия - Швеция',
#        'Южная Корея - США - Канада', 'Таиланд', 'США-Мальта',
#        'США -Германия',
#        'Великобритания - Германия - Франция - Кипр - США', 'Мексика',
#        'США - Великобритания - Ирландия', 'США - Украина',
#        'США - Финляндия - Испания - Великобритания - Франция',
#        'Австралия-Великобритания',
#        'США - Канада - Афганистан - Бельгия - Франция',
#        'США - Великобритания - Германия - Новая Зеландия - Бельгия - Франция',
#        'Франция-Канада',
#        'Ирландия - Финляндия - Бельгия - Великобритания - США - Швейцария',
#        'Малайзия - США', 'Германия - Италия',
#        'США - Франция - Бельгия - Италия', 'Франция - Ирландия - Швеция',
#        'Азербайджан-Россия', 'Великобритания - Италия - Швейцария',
#        'США - Германия - Великобритания',
#        'Германия - Бельгия - США -Франция', 'США-Китай', 'Чили - Испания',
#        'Франция - Швейцария', 'Канада - Испания',
#        'США - Румыния - Великобритания', 'США - Япония',
#        'США - Россия - Франция', 'Франция-США', 'Парагвай',
#        'Германия - Канада', 'США - Канада - Великобритания',
#        'Финляндия - Канада', 'Уругвай-Мексика-Германия', 'США - Чили',
#        'Германия - Аргентина - Нидерланды - Чили',
#        'США - Канада - Индонезия', 'Армения - Казахстан', 'Финляндия',
#        'Испания - Италия - Франция',
#        'Бельгия - Испания - Канада - Нидерланды',
#        'Великобритания - Франция - Швеция - Бельгия',
#        'Мексика - Эквадор - Канада - США - Франция - Малайзия - Италия - Аргентина - Германия - Индия',
#        'Франция - Бенльгия', 'Индия - Великобритания',
#        'Япония - Великобритания - Франция',
#        'Испания - Уругвай - Аргентина',
#        'Франция - Италия - Бельгия - Люксембург',
#        'Франция - Украина - Грузия - Армения',
#        'Сербия - Германия - Венгрия', 'Франция-Польша', 'Румыния-США',
#        'Россия-Азербайджан',
#        'США - Нидерланды - Бельгия - Венгрия - Греция - Канада',
#        'Германия - Франция - Люксембург', 'США - Россия',
#        'Великобритания - США - Франция', 'США - Австралия - Дания',
#        'Бельгия-Франция', 'США-Мексика',
#        'Норвегия - Азербайджан - Россия - Колумбия - Великобритания - Венгрия - Румыния - Франция - Грузия',
#        'СЩА', 'Бразилия - Испания', 'Россия, Франция, Латвия',
#        'Нидерланды - США - Германия - Канада - Франция - Ирландия - Великобритания',
#        'Уругвай - Колумбия', 'США - Испания - Болгария',
#        'Армения - Германия', 'США - Великобритания- Франция - Швеция',
#        'США - Мексика', 'Австралия-Турция-США', 'Швеция - Германия',
#        'Польша - Италия - Россия', 'Франция - Бразилия',
#        'США - Канада - КНР', 'СССР, Венгрия, ЧССР, ГДР',
#        'Бельгия - Германия - Люксембург', 'США - Австралия',
#        'Бразилия - США', 'США - Великобритания - Канада - КНР',
#        'Франция - Чили',
#        'Франция - США - Великобритания - Колумбия - Бельгия - Россия',
#        'Дания - Великобритания - ЮАР', 'Россия-США-Канада-Люксембург',
#        'Россия - Республика Кипр', 'Германия - США - Швеция - Франция',
#        'Великобритания-Германия-Канада-ЮАР', 'Ирландия, Канада',
#        'Япония - Великобритания - Швейцария - Ирландия - Дания - Франция - Польша - Австралия - Канада',
#        'Великобритания, Канада', 'Бельгия - США',
#        'Великобритания - США - Россия', 'Россия-Украина',
#        'Германия - США - Великобритания - Израиль', 'Канада - Германия',
#        'США- Ю.Корея', 'Индия - Мексика',
#        'Великобритания - Франция - Республика Кипр - Швейцария - США - Сербия',
#        'Испания - Аргентина - Индия - США',
#        'Норвегия - Исландия - США - Великобритания',
#        'Турция - Германя - Франция', 'Германия - Великобритания',
#        'Австралия - Германия', 'Мексика - Испания',
#        'Великобритания - США - Германия - Бельгия',
#        'США - Чехия - Франция', 'Россия - Италия', 'Франция-Россия',
#        'Норвегия - Дания - Швеция', 'Франция - Швейцария - Германия',
#        'Грузия - Украина', 'Россия - Эстония - Финляндия - Беларусь',
#        'США - Франция - ЮАР', 'Великобритания - США - Швейцария',
#        'Канада-США', 'Мексика - Нидерланды - Германия - Франция',
#        'США - Испания - Франция', 'США - Великобритания - КНР',
#        'США-Франция-Канада',
#        'Япония, Великобритания, Австрия, Германия, Ю.Корея',
#        'Великобритания - Ирландия - США', 'Бельгия - Италия - Франция',
#        'Швейцария-Германия-ЮАР', 'Великобритания - США - Германия',
#        'Германия - Исландия', 'Испания - США', 'Хорватия',
#        'Финляндия - Исландия - Швеция',
#        'Канада - США - Германия - Франция',
#        'США - Великобритания - Испания', 'Ирландия-Великобритания',
#        'Аргентина - Испания', 'Австрия - Германия',
#        'Германия - Швейцария - Франция - Южная Корея - США',
#        'Украина - Нидерланды', 'Венгрия - Германия - Швеция',
#        'Германия - Франция -  Польша - Турция - Канада - Италия - Россия',
#        'СССР, Афганистан', 'СССР, Монголия', 'Россия-Кипр',
#        'Россия, Грузия, Испания',
#        'Великобритания - Нидерланды - Германия - Франция - Бельгия - Австрия',
#        'Испания - Великобритания - Франция',
#        'Дания - Норвегия - Великобритания',
#        'Бельгия - Франция - Люксембург',
#        'Италия - Франция - Швейцария - Великобритания',
#        'Франция - Бельгия - Великобритания - Испания - Германия - США',
#        'Швейцария - Израиль - Франция - Великобритания',
#        'Великобритания - США - Канада - Нидерланды - Франция',
#        'Россия, Италия', 'СССР, Албания',
#        'Россия, Украина, Республика Беларусь, Литва',
#        'Финляндия - Великобритания - Германия', 'Россия, Украина, Польша',
#        'Франция - Италия - Бельгия - КНР',
#        'Германия - Бельгия - Люксембург - Ирландия', 'КНР - Сингапур',
#        'Франция - Бельгия - Великобритания - США - Нидерланды - Канада',
#        'США - Россия - Польша - Германия - Пуэрто Рико',
#        'Франция - Бельгия - Канада', 'Мексика - США',
#        'США - Гонконг - КНР', 'Греция - Россия',
#        'Ирландия - Дания - Бельгия - Люксембург - Франция',
#        'Эстония - Россия',
#        'Великобритания - Исландия - Испания - Швейцария - США',
#        'Австралия - Великобритания - Бельгия - Индия',
#        'Швеция - Германия - Франция - Норвегия',
#        'Нидерланды - Бельгия - Германия - Ирландия',
#        'Нидерланды - Великобритания - Бельгия',
#        'США - Колумбия - Испания', 'Франция-Испания-Бельгия-Панама',
#        'США-Великобритания-Чехия-Румыния',
#        'Аргентина - Уругвай - Россия - Германия - Франция - Нидерланды',
#        'Швеция - Франция - Норвегия - Дания',
#        'Италия-Франция-Великобритания', 'Великобритания, Франция',
#        'Австралия, США', 'Венесуэла',
#        'Великобритания - США - Австралия - Ирландия - Германия - Куба - Канада',
#        'Южная Корея - КНР',
#        'Аргентина - Мексика - Бразилия - Франция - США', 'Швеция - США',
#        'Франция - Германия - Турция - Катар', 'Франция-Китай',
#        'Россия, Германия, Великобритания',
#        'Великобритания - Италия - Испания', 'Италия - Россия',
#        'Япония - КНР - Южная Корея', 'Россия, Германия',
#        'Россия-Ирландия', 'Македония - Франция - Великобритания',
#        'Франция - Бразилия - Италия', 'Россия-США', 'Армения-Россия',
#        'Россия, Румыния', 'Франция -  Бельгия', 'Грузия-Франция',
#        'ЮАР - США', 'Великобритания-США-Франция',
#        'Великобритания - США - Германия - Канада - Австралия',
#        'США-Ирландия', 'Россия, Республика Кипр',
#        'Германия - Люксембург - Франция', 'Россия-Франция',
#        'США - Нидерланды - Финляндия - Великобритания - Италия',
#        'Республика Кипр', 'Венгрия', 'Франция - США - Норвегия - Дания',
#        'Германия - Австрия - Ирландия', 'США - Финляндия',
#        'Италия-Великобритания', 'Россия, Испания',
#        'США - Великобритания - Болгария', 'Великобритания - Люксембург',
#        'Индия - США', 'США - Канада - Россия - Франция - Чили - Ирландия',
#        'Грузия-Россия',
#        'Дания - Австрия - Ирландия - Финляндия - Норвегия - Швеция - Нидерланды',
#        'США-КНР', 'Грузия', 'Австралия - Ирландия',
#        'Великобритания - Канада', 'Италия - Аргентина - Словения',
#        'Испания - Франция - Нидерланды - Германия - Бельгия - Великобритания - Канада',
#        'Франция - Чехия - Бельгия',
#        'Великобритания - Франция - Германия - США',
#        'Ирландия - Великобритания - Франция - США - Германия - Нидерланды',
#        'США - Канада - Япония - КНР', 'Италия-Франция',
#        'США - Великобритания - Исландия', 'Великобритания-Франция',
#        'Франция - Германия - Нидерланды',
#        'Франция - Германия - Швеция - США - Чехия - Словакия - Великобритания - Нидерланды',
#        'Франция - Канада - Н.Зеландия - США - Нидерланды - Германия - Швеция - Россия',
#        'Турция - США',
#        'Великобритания - США - Канада - Бельгия - Нидерланды - Австрия - Германия',
#        'Израиль - Франция - Германия - Палестина - США - Австрия - Великобритания',
#        'Аргентина - Франция - Испания', 'СССР, Россия',
#        'Великобритания - Франция - Италия - Индия - Дания - КНР - Бангладеш - Камбоджа - Гаити - Уганда',
#        'Италия - Франция - Швейцария',
#        'Ирландия - Великобритания - Канада', 'Перу', 'США - Норвегия',
#        'Испания-Канада', 'Китай-Гонконг', 'США - Германия - КНР',
#        'Великобритания - Новая Зеландия',
#        'Франция - Дания - Швеция - КНР',
#        'США - Великобритания - Германия - Бельгия - Дания',
#        'США - Франция - Канада - Германия - Австралия - Индия', nan,
#        'СССР, Румыния, Франция', 'СССР, ГДР', 'Австралия-Ирландия',
#        'США - Китай', 'Великобритания - Франция - Австрия - Швеция',
#        'Россия, Таджикистан', 'Нидерланды - Бельгия - Болгария',
#        'Великобритания - Канада - США', 'Франция - Бельгия - Испания',
#        'Китай-Гонконг-США', 'Франция - Великобритания', 'США - Вьетнам',
#        'США - Германия - Франция', 'Германия - Франция - Бельгия',
#        'США - Италия',
#        'Германия - Дания - Испания - Швеция - Канада - Эстония - Франция',
#        'Княжество Андорра - Украина', 'Германия - Люксембург - Бельгия',
#        'Великобритания - Россия - Украина - США',
#        'Германия - Бельгия - Люксембург - Норвегия',
#        'США - Австралия - Новая Зеландия - Великобритания',
#        'США - Франция - Канада - Великобритания', 'Испания-Колумбия',
#        'Великобритания - Чехия - Франция', 'Россия, Украина', 'Исландия',
#        'Великобритания - Франция - Венгрия',
#        'Россия, Франция, Германия, Бельгия', 'Франция - Македония',
#        'Нидерланды - Франция - Германия - Бельгия - Швеция - Великобритания',
#        'Испания - США - Великобритания - Канада', 'Германия - Австрия',
#        'Республика Казахстан',
#        'Франция - Испания - Дания - Венгрия - Швейцария', 'Франция-КНР',
#        'США - Пуэрто-Рико - Франция', 'Мексика - Тайвань - США',
#        'Великобритания - Испания - Непал - Индия - Венгрия - Гонконг - Германия - Дания - Бахрейн',
#        'Великобритания - Аргентина - США - Франция - Россия - Испания',
#        'КНР - США', 'Италия - США', 'Финляндия - Швеция - Германия',
#        'Канада- Испания', 'Франция - Бельгия - Чехия',
#        'Франция-Бельгия-Канада', 'Франция - Германия - США',
#        'США - Дания', 'Индия - КНР', 'Чехия-Великобритания-США',
#        'США-ФРГ-Россия', 'Ирландия-Нидерланды-Франция-США-Великобритания',
#        'Россия, Грузия, Хорватия, Испания',
#        'Финляндия - Швеция - Норвегия', 'Сербия - Великобритания - США',
#        'США - Великобритания - Франция - Гонконг', 'Швейцария - Франция',
#        'Швейцария - Великобритания', 'ОАЭ - США',
#        'США - Франция - Германия - Канада - Австралия',
#        'Германия - Австралия', 'Иран, Франция',
#        'США - Великобритания - Новая Зеландия', 'США-Колумбия',
#        'США-Франция-Ирландия', 'Великобритания - Франция - Бельгия',
#        'США - Великобритания - Япония', 'США - Франция - Германия',
#        'Польша - Ирландия', 'Ирландия - Великобритания - Франция - США',
#        'США - Бельгия - Великобритания', 'СССР, ВНР',
#        'Испания - Франция - США - Великобритания - Бельгия',
#        'Франция - Дания - США', 'США - Гонконг', 'Бразилия - К;анада',
#        'Франция-Германия', 'США - Колумбия',
#        'США - Ирландия - Великобритания - Франция',
#        'Великобритания - США - Канада', 'Польша - Франция',
#        'Канада - США - Нидерланды - Великобритания - Аргентина',
#        'Великобритания - Дания', 'Франция - Бельгия - Япония',
#        'Россия,  Испания', 'Франция -Бельгия',
#        'США - Канада - Германия - Франция', 'США-Канада-Франция',
#        'Россия - Германия', 'Россия-Италия', 'Китай - Гонконг',
#        'Германия-Австрия-Франция-Италия', 'США-Япония',
#        'США - Германия - Канада', 'Испания-Мексика',
#        'США - Япония - Канада - Великобритания - Германия - Франция',
#        'США -Великобритания - Австралия', 'Россия-Украина-Германия',
#        'Израиль - Франция - Великобритания - Германия', 'Корея',
#        'Россия - Болгария', 'США-Индия',
#        'Германия-Канада-Франция-Бельгия', 'Германия-Кения',
#        'Франция - Монако', 'Франция-Испания-Швейцария',
#        'Австрия-Франция-Германия', 'Румыния',
#        'США-Великобритания-Франция', 'Канада-Великобритания',
#        'Канада-Бразилия-Япония', 'Германия - Дания - Норвегия',
#        'Дания - Германия', 'СССР - Италия',
#        'СССР - ГДР - Польша - Италия',
#        'США - Испания - Франция - Великобритания', 'Китай',
#        'Мексика-Аргентина',
#        'Германия - Великобритания - Италия - Испания',
#        'Франция-Германия-Великобритания', 'Россия - Германия - Швейцария',
#        'Франция-Австралия', 'Голландия', 'Швейцария-Франция',
#        'Россия-Белоруссия', 'Франция - Испания - Тайвань',
#        'США-Южная Корея-Новая Зеландия', 'Великобритания-Венгрия',
#        'Россия-Германия', 'Великобритания-Франция-Германия',
#        'Франция-Германия-Италия', 'Швеция-Финляндия-Франция-Норвегия',
#        'Франция-Италия', 'Германия-Израиль',
#        'Швеция - Германия - Дания - Норвегия', 'США-Бельгия',
#        'Франция-Гонконг-Ирландия', 'Эстония', 'Литва-Россия-Украина',
#        'Германия - Италия - Франция',
#        'Великобритания - Австрия - Германия', 'Бельгия - Франция',
#        'Россия-Казахстан', 'Испания - Мальта',
#        'Франция-Россия-Румыния-Италия-Бельгия', 'Россия - Польша',
#        'Испания - Мексика', 'США-Аргентина', 'Израиль-США-Франция',
#        'США - Новая Зеландия - Япония',
#        'Франция - Чехия - Великобритания', 'Россия-Польша',
#        'Германия-Франция-Великобритания', 'США-Германия-Канада',
#        'США-Гонконг-Китай', 'США - Великобритания - Германия',
#        'США-Канада-Австралия', 'Япония-США-Франция',
#        'Франция-Испания-Германия', 'США - Хорватия - Босния-Герцеговина',
#        'Великобритания - Чехия - Франция - Италия',
#        'США - Германия - Нидерланды', 'Германия - Франция - Канада',
#        'Франция-Грузия-Германия-Россия-Украина-Бельгия',
#        'Великобритания - Франция - Италия', 'Россия - США',
#        'Франция - Италия - Иран', 'Россия - Азербайджан', 'Греция',
#        'Дания - США', 'США-Великобритания-Новая Зеландия',
#        'США-Германия-Австралия', 'США-Канада-Италия',
#        'США - Япония - Германия', 'Австралия-США',
#        'Франция - Великобритания - Багамские острова - США',
#        'Швейцария - Люксембург', 'Швейцария - Австрия',
#        'Германия - Швейцария', 'Дания-Швеция-Франция-Германия', 'Польша',
#        'Швейцария-Австрия', 'Бразилия - Канада - США',
#        'Нидерланды - Россия', 'Португалия', 'Франция-Аргентина',
#        'Швеция-Франция', 'Франция-Украина', 'Германия-Украина-Нидерланды',
#        'Италия-Швейцария', 'США-Германия-Великобритания',
#        'Латвия - Россия', 'Германия-Франция-Великобритания-США',
#        'Канада - Италия', 'США - Объединенные Арабские Эмираты',
#        'США-Венгрия', 'Малайзия', 'Россия - Германия - Украина',
#        'США - Австралия - Мексика', 'Литва - Венгрия', 'Германия - Китай',
#        'Казахстан', 'Республика Корея',
#        'США - Германия - Франция - Великобритания - Канада',
#        'Бельгия - Германия - Люксембург - Франция', 'Франция - Греция',
#        'Италия - Канада', 'США - Великобритания - Франция',
#        'США-Италия-Греция', 'Германия - США - Великобритания - Ирландия',
#        'Великобритания - Франция - Германия',
#        'Германия - Нидерланды - ЮАР',
#        'США-Япония-Германия-Великобритания-Нидерланды',
#        'США-Япония-Германия-Великобритания',
#        'Германия - Франция - Польша',
#        'Таиланд-Великобритания-Франция-Германия-Испания-Нидерланды',
#        'Германия-Италия-Швейцария',
#        'Дания - Швеция - Великобритания - Франция - Германия - Нидерланды - Норвегия - Финляндия',
#        'Франция - Великобритания - Нидерланды - Люксембург',
#        'Нидерланды-Великобритания-Франция-Италия-Япония',
#        'Финляндия-Дания-Германия-Ирландия', 'Испания-Аргентина',
#        'Великобритания - Нидерланды - Франция - США', 'Канада - Мексика',
#        'США, Франция', 'Канада-Южная Корея-США',
#        'Великобритания - Франция - Бельгия - США', 'КНР - Канада - США',
#        'Италия - Франция - Германия',
#        'Швеция - Германия - Франция - Дания', 'Франция - США - Бельгия',
#        'Украина - Германия - Латвия - Эстония', 'Австрия - Люксембург',
#        'Великобритания - КНР', 'Монголия', 'Франция - Дания',
#        'Швеция - Дания - Финляндия',
#        'Сингапур - Великобритания - Индонезия - Канада - США',
#        'США - Германия - Япония', 'Таиланд - США', 'Франция - Нидерланды',
#        'Великобритания - Румыния', 'США - Мальта',
#        'Великобритания - Германия - Нидерланды - Дания',
#        'Франция - Германия - Литва - Нидерланды - Россия',
#        'США - ЮАР - Гонконг', 'Австралия - Колумбия',
#        'Великобритания - Польша', 'США - Великобритания - Швеция',
#        'Франция - Швеция - Дания - Норвегия', 'Болгария - США',
#        'СССР, ФРГ', 'Бельгия - Нидерланды - Франция',
#        'Финляндия - Германия', 'Болгария',
#        'Грузия - Россия - Украина - Хорватия - Германия',
#        'Франция - Люксембург', 'Франция - Германия - Австрия',
#        'Норвегия - США', 'Германия-Швеция', 'Франция - Германия - Италия',
#        'Франция-Германия-Австрия', 'КНР-США',
#        'Дания - Латвия - Россия - США', 'Финляндия - Польша',
#        'Германия - Бельгия', 'Германия - США - Франция - Испания',
#        'Бельгия-Германия-Канада-Франция-США-Великобритания',
#        'Нидерланды - Бельгия - Люксембург', 'Канада-Германия',
#        'Люксембург - Бельгия - Франция', 'США-Великобритания-Австралия',
#        'Великобритания, Новая Зеландия', 'Бельгия, Великобритания, США',
#        'Великобритания, Австралия', 'Исландия, Бельгия',
#        'Испания - Швейцария - Великобритания - Германия - Новая Зеландия - Нидерланды - Канада',
#        'Франция, Бельгия', 'Великобритания, США', 'Киргизия-Россия',
#        'Германия, США', 'Великобритания, США, Испания',
#        'Италия - Швейцария - Германия', 'Россия, Армения',
#        'Франция, Германия', 'Китай, Канада, США', 'Германия, Австралия',
#        'КНР, США', 'США, Великобритания, Люксембург',
#        'Испания, Ирландия, Бельгия, Франция',
#        'Великобритания - Гонконг - Венгрия - США - Ирландия',
#        'США - Пуэрто Рико', 'Аргентина - Испания - Уругвай',
#        'Израиль - Германия - Франция - Швейцария',
#        'Великобритания - Мексика - США', 'Испания - Болгария - США',
#        'Россия-Словакия-Чехия',
#        'Швейцария - КНР - США - Россия - Республика Корея - Великобритания',
#        'Россия, Нидерланды, Финляндия',
#        'Испания - Бельгия - Франция - Португалия - Великобритания',
#        'Бразилия - Португалия - Франция', 'Швеция - Норвегия',
#        'Франция - Польша - Бельгия', 'CША', 'Китай, США',
#        'Италия, Франция, Германия', 'Германия - Австрия - Франция',
#        'Чехия - Словакия - Хорватия', 'Россия, Польша, Финляндия',
#        'Россия, Латвия, Чешская Республика',
#        'Франция - Великобритания - Камбоджа - США - КНР',
#        'Чехия - Испания - США', 'Германия - Люксембург - Дания',
#        'Великобритания - Испания - Германия', 'Дания - Исландия',
#        'Германия, Франция, Великобритания',
#        'Великобритания - Испания - Италия - Латвия - Франция - Эстония',
#        'Дания, Швеция, Великобритания, Франция, Германия, Норвегия, Финляндия, Нидерланды, Италия',
#        'Польша - Франция - Великобритания',
#        'Дания, Норвегия, Венгрия, Чехия',
#        'Дания - Франция - Германия - Швеция',
#        'Великобритания, Швеция, США',
#        'Канада, Франция, Италия, Швейцария, США', 'США, Индия',
#        'США - Великобритания - Германия - - Швеция - Канада',
#        'Италия, Франция', 'Республика Беларусь, Германия, США, Россия',
#        'Италия-Швейцария-Франция-Германия',
#        'Россия - Франция - Великобритания - Латвия', 'Россия-Беларусь',
#        'Франция - Испания - Румыния - США - Бельгия', 'Италия-США',
#        'Россия, Австрия', 'Ирландия - Великобритания - США',
#        'Швейцария, Великобритания, Франция, США, Ирландия',
#        'Мексика, Франция, Германия, Дания, Швеция', 'Нидерланды, Бельгия',
#        'Швеция, Норвегия, Финляндия, Франция', 'Испания, Франция, Италия',
#        'Испания-Франция-Греция-Индия-США-Россия-Великобритания',
#        'Великобритания - Япония - США',
#        'Дания, Канада, Норвегия, Австралия, США', 'Аргентина, Испания',
#        'Россия, Германия, Казахстан, Польша, Китай',
#        'Португалия, Франция, Польша, США', 'США - Канада - Аргентина',
#        'Ливан-США', 'Япония - США', 'США, Гонконг',
#        'Франция - Россия - Швейцария - Румыния - Венгрия',
#        'Аргентина-Испания', 'Россия, Сербия', 'США - Болгария - Мексика',
#        'США - Великобритания - Швейцария - Франция',
#        'Таиланд - КНР - США',
#        'Великобритания, Нидерланды, Польша, Швейцария, Франция',
#        'Ирландия - США',
#        'Германия - Франция - Великобритания - Польша - США',
#        'Великобритания-Франция-Италия', 'США - Австралия - Индия',
#        'Франция - КНР', 'Великобритания - Израиль',
#        'Великобритания - Норвегия - Кения - Хорватия',
#        'США - Бразилия - Великобритания - Канада', 'Германия, Бельгия',
#        'Австралия, Канада', 'США, Великобритания, Франция',
#        'Кения, Германия', 'Нидерланды, Бельгия, Люксембург', 'Колумбия',
#        'Латвия - Франция', 'Ирландия, Великобритания',
#        'Франция - Израиль - Германия', 'Швеция, Франция, Великобритания',
#        'Бельгия - Люксембург', 'Германия - Бельгия - Великобритания',
#        'Испания, Франция, Великобритания, Дания, Бельгия, Германия',
#        'Румыния, ЮАР, Иран, Франция, Канада, Великобритания',
#        'Германия, Франция', 'США, Япония',
#        'США, Великобритания, Ирландия, Люксембург', 'Республика Армения',
#        'США, Франция, Япония', 'Япония, США', 'Канада, США',
#        'Республика Кипр - Россия',
#        'Дания - Франция - Италия - Бельгия - Нидерланды',
#        'Россия - Грузия', 'Италия, Германия', 'Норвегия, Швеция, Дания',
#        'Республика Кипр, Россия', 'КНР, Индия, Гонконг, США',
#        'Израиль, Украина', 'США, Россия', 'США - КНР - Индия - Ю.Корея',
#        'США - Швеция', 'Франция, Канада', 'Россия-Китай',
#        'Канада, Великобритания', 'США, Германия',
#        'Канада, США, Каймановы острова',
#        'Бразилия, Уругвай, Дания, Норвегия, Чили, Швеция',
#        'Пуэрто-Рико, Великобритания, США',
#        'Уругвай - Аргентина - Испания',
#        'США - Великобритания - Италия - Израиль - Сербия - Индия',
#        'США - Канада - Франция - Индия', 'Великобритания - Россия - КНР',
#        'Франция, Новая Зеландия', 'Франция, Люксембург, Бельгия',
#        'Канада, США, Норвегия', 'Италия, Испания',
#        'Испания - Германия - Нидерланды', 'Бразилия - США - КНР',
#        'Великобритания, Германия, Дания, США', '2019',
#        'Италия - Фрация - Бразилия - Германия',
#        'Норвегия - Швеция - Россия', 'Великобритания, Япония, США',
#        'Сша, Канада', 'Бельгия, Канада',
#        'Великобритания - Австралия - США', 'США, Канада',
#        'Франция - Финляндия', 'Колумбия - США',
#        'Великобритания, Франция, Бельгия', 'Норвегия - Нидерланды',
#        'Великобритания, Канада, США', 'Япония, Великобритания',
#        'Италия - Бельгия - Франция', 'Россия, Бельгия, Финляндия',
#        'США, Украина', 'Франция, Норвегия',
#        'Великобритания, Южная Корея, Канада, США, Индия, Китай, Япония',
#        'Канада - Норвегия', 'Республика Кипр-Россия', 'Германия, Россия',
#        'Польша - Франция - Испания - Бразилия - Швеция',
#        'Австрия, Великобритания, Германия', 'Франция - Сенегал - Бельгия',
#        'Франция, Бельгия, Люксембург', 'Финляндия, Латвия', 'Пакистан',
#        'Германия, Франция, США', 'Германия - Великобритания - США',
#        'КНР - Франция', 'Дания, Норвегия, Швеция, Исландия',
#        'Республика Кипр, США, Россия', 'Новая Зеландия - КНР',
#        'Дания - Канада - Швеция - Франция - Германия - Великобритания - США'],
#       dtype=object)

# %% [markdown]
# В этом примере видно, что где-то страны перечислены черезь"-", а где-то чепез и ",".
#
# Поставим везде просто "-".

# %%
movies['production_country'] = movies['production_country'].str.replace(',', '-' )
movies['production_country'] = movies['production_country'].str.replace(' - ', '-' )
movies['production_country'].unique()
# Out:
# array(['США', 'СССР', 'Франция', 'СССР- Венгрия',
#        'Германия-Великобритания', 'Великобритания-Италия', 'Чехословакия',
#        'США-Франция-Турция', 'Новая Зеландия', 'Канада-Франция-Испания',
#        'США-Германия', 'США-Великобритания', 'Великобритания',
#        'Франция-Мексика-США', 'Россия- Казахстан- США', 'СССР- Швеция',
#        'СССР- Франция- Англия- Куба- ГДР', 'Германия',
#        'Великобритания-США-Германия-КНР',
#        'СССР- ЧССР- Западный Берлин- ПНР', 'СССР- Италия', 'Гонконг- КНР',
#        'США-Франция', 'США-Япония-Франция-Великобритания',
#        'Гонконг-Сингапур-Таиланд-Великобритания', 'США-Канада',
#        'Франция-Италия-Великобритания-США', 'Франция-США',
#        'Ирландия-Великобритания-Германия', 'Чехия', 'США-Австралия',
#        'СССР- Финляндия', 'США-Франция-Великобритания-Австрия',
#        'США-Бельгия', 'США-Ирландия-Великобритания', 'Великобритания-США',
#        'Люксембург-Нидерланды-Испания-Великобритания-США-Италия',
#        'Великобритания-Франция-США', 'Новая Зеландия-США',
#        'США-Великобритания-Чехия', 'Канада-Франция-Великобритания',
#        'Ирландия', 'Великобритания-Германия-США',
#        'США-Франция-Великобритания', 'Япония', 'СССР- Польша',
#        'Франция-Испания', 'Канада-Франция', 'Германия-Италия-США',
#        'Аргентина-Бразилия', 'Дания-Швейцария-Бельгия-Франция',
#        'США-Испания', 'Германия-США',
#        'Франция-Австрия-Германия-Италия-США', 'Австрия',
#        'США-Канада-Германия', 'СССР-Швейцария-Франция',
#        'Россия-Казахстан', 'Гонконг', 'Италия', 'США-ОАЭ', 'Россия',
#        'США-Франция-Испания-Великобритания', 'Великобритания-Франция',
#        'США-Италия-Испания-Аргентина', 'Франция-Великобритания',
#        'КНР-Гонконг', 'Франция-Италия-Швейцария', 'США-Новая Зеландия',
#        'Франция-Бельгия', 'КНР', 'Германия-Великобритания-Австрия',
#        'Великобритания-Израиль-Франция-Япония-США', 'Швеция', 'Испания',
#        'Дания', 'Франция-Бельгия-Люксембург', 'США-Индия-ОАЭ',
#        'Германия-Канада-Великобритания-Швейцария-Франция', 'Мексика-Чили',
#        'Аргентина', 'Бразилия', 'Чили', 'Австралия', 'Португалия-Франция',
#        'США-ЮАР', 'Исландия-Ирландия-Германия', 'США-Индонезия',
#        'Южная Корея', 'Мексика-Испания-Дания-США', 'Франция-Италия',
#        'США-Венгрия-Великобритания', 'Бельгия-Франция-Италия',
#        'Чехия-Германия', 'Германия-Франция', 'США-Нидерланды', 'Украина',
#        'Великобритания-Германия', 'США-Франция-Испания', 'Италия-Франция',
#        'Канада', 'Швеция-Франция-Дания', 'Германия-Франция-Польша',
#        'Франция-Великобритания-Германия',
#        'США-Бразилия-Франция-Австралия-Великобритания-Германия',
#        'Германия-Австрия', 'Германия-Италия- Шри-Ланка',
#        'Великобритания-Испания', 'США-Великобритания-Канада-Швеция',
#        'Босния и Герцеговина-Франция-Великобритания-Германия-Словения-Бельгия-Сербия',
#        'Великобритания-Франция-Италия-США', 'Испания-Франция',
#        'Великобритания-Австралия-США', 'Норвегия-Швеция-Дания-Германия',
#        'Норвегия', 'Швейцария', 'Греция-Германия-Франция', 'Норвения',
#        'Южная Корея-США', 'Чили-Франция-США', 'Австрия-Германия-Франция',
#        'Швеция-Дания', 'Великобритания-Франция-Бельгия-Италия',
#        'Франция-Германия', 'Грузия-Франция-Люксембург',
#        'США-Франция-Великобритания-Бразилия', 'США-КНР',
#        'Мексика-Франция', 'США-Германия-Гонконг-Сингапур',
#        'Финляндия-Австрия-Россия', 'Испания-Куба', 'Великобритания-ЮАР',
#        'Великобритания-Ирландия', 'Израиль',
#        'Бразилия-Германия-Порртугалия-Франция', 'Франция-Канада-Бельгия',
#        'Испания-Канада-Япония', 'Иран', 'Швеция-Куба',
#        'США-Великобритания-Ирландия', 'Гонконг-КНР', 'Нидерланды',
#        'Испания-Канада', 'Япония-Великобритания',
#        'Великобритания-Норвегия-Дания-Германия',
#        'Финляндия-Франция-Германия',
#        'Мексика-Франция-Нидерланды-Германия', 'США-Индия',
#        'США-Великобритания-Индия', 'США-Канада-Бельгия',
#        'Республика Узбекистан', 'Турция',
#        'Сербия-Словения-Хорватия-Черногория-Македония', 'Киргизия',
#        'Германия-Нидерланды-Беларусь-Россия-Латвия', 'Индия',
#        'Нидерланды-Россия-Германия',
#        'Великобритания-Нидерланды-Франция-Хорватия', 'Канада-Южная Корея',
#        'Великобритания-Польша-КНР-Индия-Норвегия',
#        'Япония-Франция-США-Южная Корея-Турция',
#        'Мексика-Аргентина-Великобритания', 'Израиль-Франция',
#        'Польша-Португалия-Франция-Великобритания', 'Австралия-США',
#        'Франция-Люксембург-Бельгия', 'Армения',
#        'Бельгия-Люксембург-Франция-Швейцария',
#        'США-Великобритания-Канада', 'Норвегия-Швеция', 'КНР-Гонконг-США',
#        'США-Сингапур-Малайзия-Индонезия', 'Германия-Россия',
#        'Япония-Канада', 'Финляндия-Дания-Германия-Ирландия',
#        'Франция-Люксембург-Германия-Бельгия-Швейцария-Великобритания',
#        'Канада-США', 'США-Италия-Испания', 'США-Швейцария-Франция',
#        'Испания-США-Колумбия', 'Канада-ЮАР', 'Франция-Россия',
#        'Германия-Финляндия-Австралия', 'Дания-Швеция', 'Бельгия',
#        'Германия-Франция-Австрия', 'Франция-Индия', 'ЮАР', 'Франция-Перу',
#        'Франция-Канада', 'Республика Беларусь',
#        'Великобритания-Австрия-Франция-США', 'США-Россия',
#        'США-Южная Корея', 'Канада-КНР',
#        'Дания-Швеция-Италия-Франция-Германия',
#        'Франция-Италия-Испания-Венгрия', 'Франция-Германия-Бельгия',
#        'Франция-Великобритания-Чехия', 'Румыния-Франция-Бельгия',
#        'Болгария-Франция-Изриль',
#        'Израиль-Германия-Польша-Бельгия-Франция-Люксембург',
#        'Россия- Германия- Франция- Бельгия', 'Индонезия',
#        'Франция-Португалия', 'Великобритания-Пуэрто-Рико',
#        'СССР- ФРГ- Западный Берлин', 'Россия- Республика Беларусь',
#        'США- Великобритания', 'Франция-Австрия', 'Бельгия-Нидерланды',
#        'Великобритания-США-Индия', 'США-Великобритания-Австралия',
#        'Канада-Франция-США-ОАЭ-Великобритания', 'США-Австралия-Франция',
#        'Дания-Франция-Бельгия-Германия-Великобритания',
#        'Испания-Аргентина', 'Исландия-Финляндия',
#        'Россия-Польша-Голландия-Словакия', 'Дания-Германия-Швеция',
#        'Южная Корея-США-Канада', 'Таиланд', 'США-Мальта', 'США -Германия',
#        'Великобритания-Германия-Франция-Кипр-США', 'Мексика',
#        'США-Украина', 'США-Финляндия-Испания-Великобритания-Франция',
#        'Австралия-Великобритания',
#        'США-Канада-Афганистан-Бельгия-Франция',
#        'США-Великобритания-Германия-Новая Зеландия-Бельгия-Франция',
#        'Ирландия-Финляндия-Бельгия-Великобритания-США-Швейцария',
#        'Малайзия-США', 'Германия-Италия', 'США-Франция-Бельгия-Италия',
#        'Франция-Ирландия-Швеция', 'Азербайджан-Россия',
#        'Великобритания-Италия-Швейцария', 'США-Германия-Великобритания',
#        'Германия-Бельгия-США -Франция', 'США-Китай', 'Чили-Испания',
#        'Франция-Швейцария', 'Канада-Испания',
#        'США-Румыния-Великобритания', 'США-Япония', 'США-Россия-Франция',
#        'Парагвай', 'Германия-Канада', 'США-Канада-Великобритания',
#        'Финляндия-Канада', 'Уругвай-Мексика-Германия', 'США-Чили',
#        'Германия-Аргентина-Нидерланды-Чили', 'США-Канада-Индонезия',
#        'Армения-Казахстан', 'Финляндия', 'Испания-Италия-Франция',
#        'Бельгия-Испания-Канада-Нидерланды',
#        'Великобритания-Франция-Швеция-Бельгия',
#        'Мексика-Эквадор-Канада-США-Франция-Малайзия-Италия-Аргентина-Германия-Индия',
#        'Франция-Бенльгия', 'Индия-Великобритания',
#        'Япония-Великобритания-Франция', 'Испания-Уругвай-Аргентина',
#        'Франция-Италия-Бельгия-Люксембург',
#        'Франция-Украина-Грузия-Армения', 'Сербия-Германия-Венгрия',
#        'Франция-Польша', 'Румыния-США', 'Россия-Азербайджан',
#        'США-Нидерланды-Бельгия-Венгрия-Греция-Канада',
#        'Германия-Франция-Люксембург', 'Великобритания-США-Франция',
#        'США-Австралия-Дания', 'Бельгия-Франция', 'США-Мексика',
#        'Норвегия-Азербайджан-Россия-Колумбия-Великобритания-Венгрия-Румыния-Франция-Грузия',
#        'СЩА', 'Бразилия-Испания', 'Россия- Франция- Латвия',
#        'Нидерланды-США-Германия-Канада-Франция-Ирландия-Великобритания',
#        'Уругвай-Колумбия', 'США-Испания-Болгария', 'Армения-Германия',
#        'США-Великобритания- Франция-Швеция', 'Австралия-Турция-США',
#        'Швеция-Германия', 'Польша-Италия-Россия', 'Франция-Бразилия',
#        'США-Канада-КНР', 'СССР- Венгрия- ЧССР- ГДР',
#        'Бельгия-Германия-Люксембург', 'Бразилия-США',
#        'США-Великобритания-Канада-КНР', 'Франция-Чили',
#        'Франция-США-Великобритания-Колумбия-Бельгия-Россия',
#        'Дания-Великобритания-ЮАР', 'Россия-США-Канада-Люксембург',
#        'Россия-Республика Кипр', 'Германия-США-Швеция-Франция',
#        'Великобритания-Германия-Канада-ЮАР', 'Ирландия- Канада',
#        'Япония-Великобритания-Швейцария-Ирландия-Дания-Франция-Польша-Австралия-Канада',
#        'Великобритания- Канада', 'Бельгия-США',
#        'Великобритания-США-Россия', 'Россия-Украина',
#        'Германия-США-Великобритания-Израиль', 'Канада-Германия',
#        'США- Ю.Корея', 'Индия-Мексика',
#        'Великобритания-Франция-Республика Кипр-Швейцария-США-Сербия',
#        'Испания-Аргентина-Индия-США',
#        'Норвегия-Исландия-США-Великобритания', 'Турция-Германя-Франция',
#        'Австралия-Германия', 'Мексика-Испания',
#        'Великобритания-США-Германия-Бельгия', 'США-Чехия-Франция',
#        'Россия-Италия', 'Норвегия-Дания-Швеция',
#        'Франция-Швейцария-Германия', 'Грузия-Украина',
#        'Россия-Эстония-Финляндия-Беларусь', 'США-Франция-ЮАР',
#        'Великобритания-США-Швейцария',
#        'Мексика-Нидерланды-Германия-Франция', 'США-Испания-Франция',
#        'США-Великобритания-КНР', 'США-Франция-Канада',
#        'Япония- Великобритания- Австрия- Германия- Ю.Корея',
#        'Великобритания-Ирландия-США', 'Бельгия-Италия-Франция',
#        'Швейцария-Германия-ЮАР', 'Великобритания-США-Германия',
#        'Германия-Исландия', 'Испания-США', 'Хорватия',
#        'Финляндия-Исландия-Швеция', 'Канада-США-Германия-Франция',
#        'США-Великобритания-Испания', 'Ирландия-Великобритания',
#        'Аргентина-Испания', 'Австрия-Германия',
#        'Германия-Швейцария-Франция-Южная Корея-США', 'Украина-Нидерланды',
#        'Венгрия-Германия-Швеция',
#        'Германия-Франция- Польша-Турция-Канада-Италия-Россия',
#        'СССР- Афганистан', 'СССР- Монголия', 'Россия-Кипр',
#        'Россия- Грузия- Испания',
#        'Великобритания-Нидерланды-Германия-Франция-Бельгия-Австрия',
#        'Испания-Великобритания-Франция', 'Дания-Норвегия-Великобритания',
#        'Бельгия-Франция-Люксембург',
#        'Италия-Франция-Швейцария-Великобритания',
#        'Франция-Бельгия-Великобритания-Испания-Германия-США',
#        'Швейцария-Израиль-Франция-Великобритания',
#        'Великобритания-США-Канада-Нидерланды-Франция', 'Россия- Италия',
#        'СССР- Албания', 'Россия- Украина- Республика Беларусь- Литва',
#        'Финляндия-Великобритания-Германия', 'Россия- Украина- Польша',
#        'Франция-Италия-Бельгия-КНР',
#        'Германия-Бельгия-Люксембург-Ирландия', 'КНР-Сингапур',
#        'Франция-Бельгия-Великобритания-США-Нидерланды-Канада',
#        'США-Россия-Польша-Германия-Пуэрто Рико', 'Франция-Бельгия-Канада',
#        'Мексика-США', 'США-Гонконг-КНР', 'Греция-Россия',
#        'Ирландия-Дания-Бельгия-Люксембург-Франция', 'Эстония-Россия',
#        'Великобритания-Исландия-Испания-Швейцария-США',
#        'Австралия-Великобритания-Бельгия-Индия',
#        'Швеция-Германия-Франция-Норвегия',
#        'Нидерланды-Бельгия-Германия-Ирландия',
#        'Нидерланды-Великобритания-Бельгия', 'США-Колумбия-Испания',
#        'Франция-Испания-Бельгия-Панама',
#        'США-Великобритания-Чехия-Румыния',
#        'Аргентина-Уругвай-Россия-Германия-Франция-Нидерланды',
#        'Швеция-Франция-Норвегия-Дания', 'Италия-Франция-Великобритания',
#        'Великобритания- Франция', 'Австралия- США', 'Венесуэла',
#        'Великобритания-США-Австралия-Ирландия-Германия-Куба-Канада',
#        'Южная Корея-КНР', 'Аргентина-Мексика-Бразилия-Франция-США',
#        'Швеция-США', 'Франция-Германия-Турция-Катар', 'Франция-Китай',
#        'Россия- Германия- Великобритания',
#        'Великобритания-Италия-Испания', 'Италия-Россия',
#        'Япония-КНР-Южная Корея', 'Россия- Германия', 'Россия-Ирландия',
#        'Македония-Франция-Великобритания', 'Франция-Бразилия-Италия',
#        'Россия-США', 'Армения-Россия', 'Россия- Румыния',
#        'Франция- Бельгия', 'Грузия-Франция', 'ЮАР-США',
#        'Великобритания-США-Германия-Канада-Австралия', 'США-Ирландия',
#        'Россия- Республика Кипр', 'Германия-Люксембург-Франция',
#        'Россия-Франция', 'США-Нидерланды-Финляндия-Великобритания-Италия',
#        'Республика Кипр', 'Венгрия', 'Франция-США-Норвегия-Дания',
#        'Германия-Австрия-Ирландия', 'США-Финляндия',
#        'Италия-Великобритания', 'Россия- Испания',
#        'США-Великобритания-Болгария', 'Великобритания-Люксембург',
#        'Индия-США', 'США-Канада-Россия-Франция-Чили-Ирландия',
#        'Грузия-Россия',
#        'Дания-Австрия-Ирландия-Финляндия-Норвегия-Швеция-Нидерланды',
#        'Грузия', 'Австралия-Ирландия', 'Великобритания-Канада',
#        'Италия-Аргентина-Словения',
#        'Испания-Франция-Нидерланды-Германия-Бельгия-Великобритания-Канада',
#        'Франция-Чехия-Бельгия', 'Великобритания-Франция-Германия-США',
#        'Ирландия-Великобритания-Франция-США-Германия-Нидерланды',
#        'США-Канада-Япония-КНР', 'США-Великобритания-Исландия',
#        'Франция-Германия-Нидерланды',
#        'Франция-Германия-Швеция-США-Чехия-Словакия-Великобритания-Нидерланды',
#        'Франция-Канада-Н.Зеландия-США-Нидерланды-Германия-Швеция-Россия',
#        'Турция-США',
#        'Великобритания-США-Канада-Бельгия-Нидерланды-Австрия-Германия',
#        'Израиль-Франция-Германия-Палестина-США-Австрия-Великобритания',
#        'Аргентина-Франция-Испания', 'СССР- Россия',
#        'Великобритания-Франция-Италия-Индия-Дания-КНР-Бангладеш-Камбоджа-Гаити-Уганда',
#        'Италия-Франция-Швейцария', 'Ирландия-Великобритания-Канада',
#        'Перу', 'США-Норвегия', 'Китай-Гонконг', 'США-Германия-КНР',
#        'Великобритания-Новая Зеландия', 'Франция-Дания-Швеция-КНР',
#        'США-Великобритания-Германия-Бельгия-Дания',
#        'США-Франция-Канада-Германия-Австралия-Индия', nan,
#        'СССР- Румыния- Франция', 'СССР- ГДР',
#        'Великобритания-Франция-Австрия-Швеция', 'Россия- Таджикистан',
#        'Нидерланды-Бельгия-Болгария', 'Великобритания-Канада-США',
#        'Франция-Бельгия-Испания', 'Китай-Гонконг-США', 'США-Вьетнам',
#        'США-Германия-Франция', 'Германия-Франция-Бельгия', 'США-Италия',
#        'Германия-Дания-Испания-Швеция-Канада-Эстония-Франция',
#        'Княжество Андорра-Украина', 'Германия-Люксембург-Бельгия',
#        'Великобритания-Россия-Украина-США',
#        'Германия-Бельгия-Люксембург-Норвегия',
#        'США-Австралия-Новая Зеландия-Великобритания',
#        'США-Франция-Канада-Великобритания', 'Испания-Колумбия',
#        'Великобритания-Чехия-Франция', 'Россия- Украина', 'Исландия',
#        'Великобритания-Франция-Венгрия',
#        'Россия- Франция- Германия- Бельгия', 'Франция-Македония',
#        'Нидерланды-Франция-Германия-Бельгия-Швеция-Великобритания',
#        'Испания-США-Великобритания-Канада', 'Республика Казахстан',
#        'Франция-Испания-Дания-Венгрия-Швейцария', 'Франция-КНР',
#        'США-Пуэрто-Рико-Франция', 'Мексика-Тайвань-США',
#        'Великобритания-Испания-Непал-Индия-Венгрия-Гонконг-Германия-Дания-Бахрейн',
#        'Великобритания-Аргентина-США-Франция-Россия-Испания', 'КНР-США',
#        'Италия-США', 'Финляндия-Швеция-Германия', 'Канада- Испания',
#        'Франция-Бельгия-Чехия', 'Франция-Германия-США', 'США-Дания',
#        'Индия-КНР', 'Чехия-Великобритания-США', 'США-ФРГ-Россия',
#        'Ирландия-Нидерланды-Франция-США-Великобритания',
#        'Россия- Грузия- Хорватия- Испания', 'Финляндия-Швеция-Норвегия',
#        'Сербия-Великобритания-США', 'США-Великобритания-Франция-Гонконг',
#        'Швейцария-Франция', 'Швейцария-Великобритания', 'ОАЭ-США',
#        'США-Франция-Германия-Канада-Австралия', 'Германия-Австралия',
#        'Иран- Франция', 'США-Великобритания-Новая Зеландия',
#        'США-Колумбия', 'США-Франция-Ирландия',
#        'Великобритания-Франция-Бельгия', 'США-Великобритания-Япония',
#        'США-Франция-Германия', 'Польша-Ирландия',
#        'Ирландия-Великобритания-Франция-США',
#        'США-Бельгия-Великобритания', 'СССР- ВНР',
#        'Испания-Франция-США-Великобритания-Бельгия', 'Франция-Дания-США',
#        'США-Гонконг', 'Бразилия-К;анада',
#        'США-Ирландия-Великобритания-Франция', 'Великобритания-США-Канада',
#        'Польша-Франция', 'Канада-США-Нидерланды-Великобритания-Аргентина',
#        'Великобритания-Дания', 'Франция-Бельгия-Япония',
#        'Россия-  Испания', 'Франция -Бельгия',
#        'США-Канада-Германия-Франция', 'США-Канада-Франция',
#        'Россия-Германия', 'Германия-Австрия-Франция-Италия',
#        'США-Германия-Канада', 'Испания-Мексика',
#        'США-Япония-Канада-Великобритания-Германия-Франция',
#        'США -Великобритания-Австралия', 'Россия-Украина-Германия',
#        'Израиль-Франция-Великобритания-Германия', 'Корея',
#        'Россия-Болгария', 'Германия-Канада-Франция-Бельгия',
#        'Германия-Кения', 'Франция-Монако', 'Франция-Испания-Швейцария',
#        'Австрия-Франция-Германия', 'Румыния',
#        'США-Великобритания-Франция', 'Канада-Великобритания',
#        'Канада-Бразилия-Япония', 'Германия-Дания-Норвегия',
#        'Дания-Германия', 'СССР-Италия', 'СССР-ГДР-Польша-Италия',
#        'США-Испания-Франция-Великобритания', 'Китай', 'Мексика-Аргентина',
#        'Германия-Великобритания-Италия-Испания',
#        'Франция-Германия-Великобритания', 'Россия-Германия-Швейцария',
#        'Франция-Австралия', 'Голландия', 'Россия-Белоруссия',
#        'Франция-Испания-Тайвань', 'США-Южная Корея-Новая Зеландия',
#        'Великобритания-Венгрия', 'Великобритания-Франция-Германия',
#        'Франция-Германия-Италия', 'Швеция-Финляндия-Франция-Норвегия',
#        'Германия-Израиль', 'Швеция-Германия-Дания-Норвегия',
#        'Франция-Гонконг-Ирландия', 'Эстония', 'Литва-Россия-Украина',
#        'Германия-Италия-Франция', 'Великобритания-Австрия-Германия',
#        'Испания-Мальта', 'Франция-Россия-Румыния-Италия-Бельгия',
#        'Россия-Польша', 'США-Аргентина', 'Израиль-США-Франция',
#        'США-Новая Зеландия-Япония', 'Франция-Чехия-Великобритания',
#        'Германия-Франция-Великобритания', 'США-Гонконг-Китай',
#        'США-Великобритания-Германия', 'США-Канада-Австралия',
#        'Япония-США-Франция', 'Франция-Испания-Германия',
#        'США-Хорватия-Босния-Герцеговина',
#        'Великобритания-Чехия-Франция-Италия', 'США-Германия-Нидерланды',
#        'Германия-Франция-Канада',
#        'Франция-Грузия-Германия-Россия-Украина-Бельгия',
#        'Великобритания-Франция-Италия', 'Франция-Италия-Иран', 'Греция',
#        'Дания-США', 'США-Германия-Австралия', 'США-Канада-Италия',
#        'США-Япония-Германия',
#        'Франция-Великобритания-Багамские острова-США',
#        'Швейцария-Люксембург', 'Швейцария-Австрия', 'Германия-Швейцария',
#        'Дания-Швеция-Франция-Германия', 'Польша', 'Бразилия-Канада-США',
#        'Нидерланды-Россия', 'Португалия', 'Франция-Аргентина',
#        'Швеция-Франция', 'Франция-Украина', 'Германия-Украина-Нидерланды',
#        'Италия-Швейцария', 'Латвия-Россия',
#        'Германия-Франция-Великобритания-США', 'Канада-Италия',
#        'США-Объединенные Арабские Эмираты', 'США-Венгрия', 'Малайзия',
#        'Россия-Германия-Украина', 'США-Австралия-Мексика',
#        'Литва-Венгрия', 'Германия-Китай', 'Казахстан', 'Республика Корея',
#        'США-Германия-Франция-Великобритания-Канада',
#        'Бельгия-Германия-Люксембург-Франция', 'Франция-Греция',
#        'Италия-Канада', 'США-Италия-Греция',
#        'Германия-США-Великобритания-Ирландия', 'Германия-Нидерланды-ЮАР',
#        'США-Япония-Германия-Великобритания-Нидерланды',
#        'США-Япония-Германия-Великобритания',
#        'Таиланд-Великобритания-Франция-Германия-Испания-Нидерланды',
#        'Германия-Италия-Швейцария',
#        'Дания-Швеция-Великобритания-Франция-Германия-Нидерланды-Норвегия-Финляндия',
#        'Франция-Великобритания-Нидерланды-Люксембург',
#        'Нидерланды-Великобритания-Франция-Италия-Япония',
#        'Великобритания-Нидерланды-Франция-США', 'Канада-Мексика',
#        'США- Франция', 'Канада-Южная Корея-США',
#        'Великобритания-Франция-Бельгия-США', 'КНР-Канада-США',
#        'Италия-Франция-Германия', 'Швеция-Германия-Франция-Дания',
#        'Франция-США-Бельгия', 'Украина-Германия-Латвия-Эстония',
#        'Австрия-Люксембург', 'Великобритания-КНР', 'Монголия',
#        'Франция-Дания', 'Швеция-Дания-Финляндия',
#        'Сингапур-Великобритания-Индонезия-Канада-США',
#        'США-Германия-Япония', 'Таиланд-США', 'Франция-Нидерланды',
#        'Великобритания-Румыния',
#        'Великобритания-Германия-Нидерланды-Дания',
#        'Франция-Германия-Литва-Нидерланды-Россия', 'США-ЮАР-Гонконг',
#        'Австралия-Колумбия', 'Великобритания-Польша',
#        'США-Великобритания-Швеция', 'Франция-Швеция-Дания-Норвегия',
#        'Болгария-США', 'СССР- ФРГ', 'Бельгия-Нидерланды-Франция',
#        'Финляндия-Германия', 'Болгария',
#        'Грузия-Россия-Украина-Хорватия-Германия', 'Франция-Люксембург',
#        'Франция-Германия-Австрия', 'Норвегия-США', 'Германия-Швеция',
#        'Дания-Латвия-Россия-США', 'Финляндия-Польша', 'Германия-Бельгия',
#        'Германия-США-Франция-Испания',
#        'Бельгия-Германия-Канада-Франция-США-Великобритания',
#        'Нидерланды-Бельгия-Люксембург', 'Люксембург-Бельгия-Франция',
#        'Великобритания- Новая Зеландия', 'Бельгия- Великобритания- США',
#        'Великобритания- Австралия', 'Исландия- Бельгия',
#        'Испания-Швейцария-Великобритания-Германия-Новая Зеландия-Нидерланды-Канада',
#        'Великобритания- США', 'Киргизия-Россия', 'Германия- США',
#        'Великобритания- США- Испания', 'Италия-Швейцария-Германия',
#        'Россия- Армения', 'Франция- Германия', 'Китай- Канада- США',
#        'Германия- Австралия', 'КНР- США',
#        'США- Великобритания- Люксембург',
#        'Испания- Ирландия- Бельгия- Франция',
#        'Великобритания-Гонконг-Венгрия-США-Ирландия', 'США-Пуэрто Рико',
#        'Аргентина-Испания-Уругвай', 'Израиль-Германия-Франция-Швейцария',
#        'Великобритания-Мексика-США', 'Испания-Болгария-США',
#        'Россия-Словакия-Чехия',
#        'Швейцария-КНР-США-Россия-Республика Корея-Великобритания',
#        'Россия- Нидерланды- Финляндия',
#        'Испания-Бельгия-Франция-Португалия-Великобритания',
#        'Бразилия-Португалия-Франция', 'Швеция-Норвегия',
#        'Франция-Польша-Бельгия', 'CША', 'Китай- США',
#        'Италия- Франция- Германия', 'Германия-Австрия-Франция',
#        'Чехия-Словакия-Хорватия', 'Россия- Польша- Финляндия',
#        'Россия- Латвия- Чешская Республика',
#        'Франция-Великобритания-Камбоджа-США-КНР', 'Чехия-Испания-США',
#        'Германия-Люксембург-Дания', 'Великобритания-Испания-Германия',
#        'Дания-Исландия', 'Германия- Франция- Великобритания',
#        'Великобритания-Испания-Италия-Латвия-Франция-Эстония',
#        'Дания- Швеция- Великобритания- Франция- Германия- Норвегия- Финляндия- Нидерланды- Италия',
#        'Польша-Франция-Великобритания', 'Дания- Норвегия- Венгрия- Чехия',
#        'Дания-Франция-Германия-Швеция', 'Великобритания- Швеция- США',
#        'Канада- Франция- Италия- Швейцария- США', 'США- Индия',
#        'США-Великобритания-Германия-- Швеция-Канада', 'Италия- Франция',
#        'Республика Беларусь- Германия- США- Россия',
#        'Италия-Швейцария-Франция-Германия',
#        'Россия-Франция-Великобритания-Латвия', 'Россия-Беларусь',
#        'Франция-Испания-Румыния-США-Бельгия', 'Россия- Австрия',
#        'Ирландия-Великобритания-США',
#        'Швейцария- Великобритания- Франция- США- Ирландия',
#        'Мексика- Франция- Германия- Дания- Швеция', 'Нидерланды- Бельгия',
#        'Швеция- Норвегия- Финляндия- Франция', 'Испания- Франция- Италия',
#        'Испания-Франция-Греция-Индия-США-Россия-Великобритания',
#        'Великобритания-Япония-США',
#        'Дания- Канада- Норвегия- Австралия- США', 'Аргентина- Испания',
#        'Россия- Германия- Казахстан- Польша- Китай',
#        'Португалия- Франция- Польша- США', 'США-Канада-Аргентина',
#        'Ливан-США', 'Япония-США', 'США- Гонконг',
#        'Франция-Россия-Швейцария-Румыния-Венгрия', 'Россия- Сербия',
#        'США-Болгария-Мексика', 'США-Великобритания-Швейцария-Франция',
#        'Таиланд-КНР-США',
#        'Великобритания- Нидерланды- Польша- Швейцария- Франция',
#        'Ирландия-США', 'Германия-Франция-Великобритания-Польша-США',
#        'США-Австралия-Индия', 'Великобритания-Израиль',
#        'Великобритания-Норвегия-Кения-Хорватия',
#        'США-Бразилия-Великобритания-Канада', 'Германия- Бельгия',
#        'Австралия- Канада', 'США- Великобритания- Франция',
#        'Кения- Германия', 'Нидерланды- Бельгия- Люксембург', 'Колумбия',
#        'Латвия-Франция', 'Ирландия- Великобритания',
#        'Франция-Израиль-Германия', 'Швеция- Франция- Великобритания',
#        'Бельгия-Люксембург', 'Германия-Бельгия-Великобритания',
#        'Испания- Франция- Великобритания- Дания- Бельгия- Германия',
#        'Румыния- ЮАР- Иран- Франция- Канада- Великобритания',
#        'Германия- Франция', 'США- Япония',
#        'США- Великобритания- Ирландия- Люксембург', 'Республика Армения',
#        'США- Франция- Япония', 'Япония- США', 'Канада- США',
#        'Республика Кипр-Россия',
#        'Дания-Франция-Италия-Бельгия-Нидерланды', 'Россия-Грузия',
#        'Италия- Германия', 'Норвегия- Швеция- Дания',
#        'Республика Кипр- Россия', 'КНР- Индия- Гонконг- США',
#        'Израиль- Украина', 'США- Россия', 'США-КНР-Индия-Ю.Корея',
#        'США-Швеция', 'Франция- Канада', 'Россия-Китай',
#        'Канада- Великобритания', 'США- Германия',
#        'Канада- США- Каймановы острова',
#        'Бразилия- Уругвай- Дания- Норвегия- Чили- Швеция',
#        'Пуэрто-Рико- Великобритания- США', 'Уругвай-Аргентина-Испания',
#        'США-Великобритания-Италия-Израиль-Сербия-Индия',
#        'США-Канада-Франция-Индия', 'Великобритания-Россия-КНР',
#        'Франция- Новая Зеландия', 'Франция- Люксембург- Бельгия',
#        'Канада- США- Норвегия', 'Италия- Испания',
#        'Испания-Германия-Нидерланды', 'Бразилия-США-КНР',
#        'Великобритания- Германия- Дания- США', '2019',
#        'Италия-Фрация-Бразилия-Германия', 'Норвегия-Швеция-Россия',
#        'Великобритания- Япония- США', 'Сша- Канада', 'Бельгия- Канада',
#        'США- Канада', 'Франция-Финляндия', 'Колумбия-США',
#        'Великобритания- Франция- Бельгия', 'Норвегия-Нидерланды',
#        'Великобритания- Канада- США', 'Япония- Великобритания',
#        'Италия-Бельгия-Франция', 'Россия- Бельгия- Финляндия',
#        'США- Украина', 'Франция- Норвегия',
#        'Великобритания- Южная Корея- Канада- США- Индия- Китай- Япония',
#        'Канада-Норвегия', 'Германия- Россия',
#        'Польша-Франция-Испания-Бразилия-Швеция',
#        'Австрия- Великобритания- Германия', 'Франция-Сенегал-Бельгия',
#        'Франция- Бельгия- Люксембург', 'Финляндия- Латвия', 'Пакистан',
#        'Германия- Франция- США', 'Германия-Великобритания-США',
#        'КНР-Франция', 'Дания- Норвегия- Швеция- Исландия',
#        'Республика Кипр- США- Россия', 'Новая Зеландия-КНР',
#        'Дания-Канада-Швеция-Франция-Германия-Великобритания-США'],
#       dtype=object)

# %% [markdown]
# Изучим age_restriction

# %%
movies['age_restriction'].value_counts()
# Out:
# «16+» - для детей старше 16 лет           2851
# «18+» - запрещено для детей               1605
# «12+» - для детей старше 12 лет           1593
# «0+» - для любой зрительской аудитории     811
# «6+» - для детей старше 6 лет              626
# Name: age_restriction, dtype: int64

# %% [markdown]
# Здесь все хорошо оставляем без изменений.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 🤔<a class="tocSkip"></h2>
#     <s>
# Давай также попробуем выявить и другую основную проблему категориальных столбцов?
#
# Сразу замечу, что дело не только в пропусках и запятых, ответить тебе могут помочь следующие вопросы: Почему мы называем столбцы категориальными? Сможем ли мы сформировать категории или сгруппировать данные в нашем случае?)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>  Ты про то, чтобы в графе страна оставить, только первое значение? Сейчас попраим.</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 🤔 v_2 <a class="tocSkip"> </h2>
# <s>
# Нам нужно только указать проблему)  Про страну я ничего не писала)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>  Но я все же оставлю.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓 v_3 <a class="tocSkip"> </h2>
#
# Здесь основной проблемой является нличие большого кол-ва  уникальных значений из-за того, что во всех этих полях идет перечисление.

# %% [markdown]
# В графе страна-производитель оставим первое значение.

# %%
for country in movies['production_country']:
    main_country = country.split()
    movies['production_country'] = main_country[0]

# %%
movies.head()
# Out:
#                   title   puNumber show_start_date            type  \
# 0      Открытый простор  221048915      2015-11-27  Художественный
# 1  Особо важное задание  111013716      2016-09-13  Художественный
# 2          Особо опасен  221038416      2016-10-10  Художественный
# 3          Особо опасен  221026916      2016-06-10  Художественный
# 4          Особо опасен  221030815      2015-07-29  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"                США
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                          не указан
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
# 2    «18+» - запрещено для детей                 NaN                    NaN
# 3    «18+» - запрещено для детей                 NaN                    NaN
# 4    «18+» - запрещено для детей                 NaN                    NaN
#
#    budget financing_source  ratings                     genres  box_office
# 0     NaN          Частное     7.20     боевик,драма,мелодрама         NaN
# 1     NaN          Частное     6.60              драма,военный         NaN
# 2     NaN          Частное     6.80  фантастика,боевик,триллер         NaN
# 3     NaN          Частное     6.80  фантастика,боевик,триллер         NaN
# 4     NaN          Частное     6.80  фантастика,боевик,триллер         NaN

# %% [markdown]
# На данном этапе мы рассмотрели подробнее категориальные значения.
#
# - Заменили дубликаты в графе о номере прокатного удостоверия.
#
# - Откорректировали даные в графах 'type', 'film_studio', 'production_country', 'producer', 'director', 'genres', удалив них лишние пробелы, тем самым исключив наличие неявных дубликатов.
#
# - В графе страна оставили только первое, основное значение.

# %% [markdown]
# #### Шаг 2.5. Проверьте количественные значения
#
# - Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_budget" aria-expanded="false" aria-controls="collapseHint_budget">Подсказка</button>
#         </div>
#         <div id="collapseHint_budget" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на описание столбца <code>budget</code>. Как этот столбец соотносится с двумя другими: <code>refundable_support</code> и <code>nonrefundable_support</code>?
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Изучим внимательнее фильмы с государственной поддержкой.

# %%
movies['financing_source'].value_counts()
# Out:
# Частное                             7154
# Министерство культуры                164
# Фонд кино                            146
# Министерство культуры, Фонд кино      22
# Name: financing_source, dtype: int64

# %%
print('Снято', len(movies.query('financing_source != "Частное"')), 'фильма с участием государственной поддержки')
# Out:
# Снято 332 фильма с участием государственной поддержки

# %%
movies.query('financing_source != "Частное"').head(30)
# Out:
#                                           title   puNumber show_start_date  \
# 1281                              Пока еще жива  111005313      2013-10-11
# 1448                        Бесславные придурки  111003314      2014-03-28
# 1498                                  Невидимки  111004213      2013-09-10
# 1524                                      БЕРЦЫ  111004314      2014-05-05
# 1792                                   Братья Ч  111004414      2014-04-23
# 1854  Тайна Сухаревой башни. Чародей равновесия  114000115      2015-02-18
# 1870                     А зори здесь тихие..._  111002915      2015-03-16
# 1871                                Две женщины  111013714      2014-10-02
# 1903                                  Призрак_.  111001815      2015-03-02
# 1912                                   Ведьма .  111002215      2015-03-05
# 1987                              Елки Лохматые  111023114      2014-12-10
# 1991                                    Смайлик  111008614      2014-08-08
# 1997       Овечка Долли была злая и рано умерла  111015214      2014-11-10
# 2005          Снежная Королева 2: Перезаморозка  114000214      2014-11-13
# 2014                         Дедушка моей мечты  111007714      2014-07-22
# 2053                                        14+  111023614      2014-12-19
# 2058                                  Дуxless 2  111000415      2015-01-26
# 2084                           Дорога на Берлин  111001315      2015-02-17
# 2092                                  Батальонъ  111000715      2015-01-29
# 2106                             С пяти до семи  111000615      2015-01-28
# 2108                                     ОХРАНА  111001115      2015-02-11
# 2109                         Полное превращение  111001215      2015-02-12
# 2132                       Битва за Севастополь  111001415      2015-02-20
# 2142                                 Территория  111000515      2015-01-27
# 2143                               Неуловимые .  111002715      2015-03-16
# 2146                                    Главный  111003415      2015-03-27
# 2150                               РЕВЕРБЕРАЦИЯ  111003515      2015-03-30
# 2166                                   Находка.  111003615      2015-04-02
# 2169                   Трагедия в бухте Роджерс  111003215      2015-03-26
# 2205                           8 новых свиданий  111014914      2014-10-30
#
#                 type                                        film_studio  \
# 1281  Художественный  АНО содействия развитию кинематографии "Ангел-...
# 1448  Художественный                         ООО "Компания "АТК-Студио"
# 1498  Художественный                        ООО "Компания "РЕАЛ-ДАКОТА"
# 1524  Художественный                             ООО "Студия "Пассажир"
# 1792  Художественный                             ООО "Студия "Пассажир"
# 1854    Анимационный                         ООО "Студия "Мастер-Фильм"
# 1870  Художественный                        ООО "Компания "Реал-Дакота"
# 1871  Художественный  ООО "Продюсерский Центр "Хорошо Продакшн", Rez...
# 1903  Художественный                                 ООО "Водород 2011"
# 1912  Художественный                         ООО "Кинокомпания "Ракурс"
# 1987  Художественный                                       ООО "ТаББаК"
# 1991  Художественный           ООО "Продюсерская кинокомпания "Киномир"
# 1997  Художественный                           ООО "Пиманов и партнеры"
# 2005    Анимационный                                 ООО "ВИЗАРТ ФИЛЬМ"
# 2014  Художественный                                     ООО "Пендулум"
# 2053  Художественный                         ООО Киностудия  "Сентябрь"
# 2058  Художественный  ООО "Киностудия "Слово", ООО "Арт Пикчерс Студия"
# 2084  Художественный  ООО "Продюсерская компания Александра Литвинов...
# 2092  Художественный        ООО "Корнер Ворк", ООО "Арт Пикчерс Студия"
# 2106  Художественный                           ООО "АМАЛЬГАМА ПРОДАКШН"
# 2108  Художественный                                       ООО "Амкарт"
# 2109  Художественный                                ООО "Каро Продакшн"
# 2132  Художественный  ООО "Кинокомпания "Новые люди", ООО "Студия "К...
# 2142  Художественный  ООО "Творческое объединение "Кинокомпания "Анд...
# 2143  Художественный             ООО "Энджой мувиз", ООО "Ультра стори"
# 2146  Художественный                           ООО "Киностудия "МАСТЕР"
# 2150  Художественный                                      ООО "Артлайт"
# 2166  Художественный                         ООО "Кинокомпания "Фигаро"
# 2169  Художественный                                       ООО "Валдай"
# 2205  Художественный                            ООО "Смарт ТВ Продакшн"
#
#      production_country                              director  \
# 1281                США                            А.Атанесян
# 1448                США                             А.Якимчук
# 1498                США              Р.Давлетьяров, С.Комаров
# 1524                США  Е.Миндадзе (псевдоним Катя Шагалова)
# 1792                США                              М.Угаров
# 1854                США                             С.Серегин
# 1870                США                         Р.Давлетьяров
# 1871                США                           В.Глаголева
# 1903                США                          А.Войтинский
# 1912                США                             Д.Федоров
# 1987                США                      Максим Свешников
# 1991                США                           Т.Аленикова
# 1997                США                             А.Пиманов
# 2005                США                             А.Цицилин
# 2014                США                           А.Стриженов
# 2053                США                              А.Зайцев
# 2058                США                            Р.Прыгунов
# 2084                США                               С.Попов
# 2092                США                             Д.Месхиев
# 2106                США                           В.Щегольков
# 2108                США                             А.Прошкин
# 2109                США                  П.Санаев, Ф.Коршунов
# 2132                США                           С.Мокрицкий
# 2142                США                             А.Мельник
# 2143                США                           А.Аксененко
# 2146                США                                Ю.Кара
# 2150                США                           К.Сухарьков
# 2166                США                              В.Демент
# 2169                США                             Ф.Абрютин
# 2205                США                           М.Бальчюнас
#
#                                          producer  \
# 1281             А.Атанесян, М.Бабаханов, Р.Бутко
# 1448                                   А.Тютрюмов
# 1498    Р.Давлетьяров, А.Котелевский, А.Олейников
# 1524                                   Л.Антонова
# 1792                       А.Миндадзе, Л.Антонова
# 1854                                  А.Герасимов
# 1870                                    не указан
# 1871                                    Н.Иванова
# 1903                                   С.Сельянов
# 1912                                  В.Сидоренко
# 1987           Тимур Бекмамбетов, Евгения Аронова
# 1991                                   Т.Яковенко
# 1997                        А.Пиманов, О.Погодина
# 2005             ООО "ВИЗАРТ ФИЛЬМ", ООО "ТаББаК"
# 2014         Л.Якубович, А.Стриженов, Л.Лищинская
# 2053                          О.Гранина, А.Зайцев
# 2058           П.Ануров, Ф.Бондарчук, Д.Рудовский
# 2084                     А.Литвинов, К.Шахназаров
# 2092                                 И.Угольников
# 2106                        А.Феофанов, С.Новиков
# 2108                                   Д.Пиркулов
# 2109                         Ю.Обухов, А.Рязанцев
# 2132                        Н.Мокрицкая, Е.Олесов
# 2142                                    А.Мельник
# 2143  Г.Малков, В.Поляков, И.Капитонов, В.Муругов
# 2146                                       Ю.Кара
# 2150                                    А.Новиков
# 2166                                    Н.Будкина
# 2169                         С.Кучмаева, С.Зернов
# 2205            ООО "Грин Филмс", ООО "ПЦ "Горад"
#
#                              age_restriction  refundable_support  \
# 1281         «16+» - для детей старше 16 лет                0.00
# 1448         «12+» - для детей старше 12 лет                0.00
# 1498         «12+» - для детей старше 12 лет                0.00
# 1524         «16+» - для детей старше 16 лет                0.00
# 1792         «16+» - для детей старше 16 лет                0.00
# 1854           «6+» - для детей старше 6 лет                0.00
# 1870         «12+» - для детей старше 12 лет         50000000.00
# 1871         «12+» - для детей старше 12 лет                0.00
# 1903           «6+» - для детей старше 6 лет                0.00
# 1912         «16+» - для детей старше 16 лет                0.00
# 1987           «6+» - для детей старше 6 лет         26000000.00
# 1991         «16+» - для детей старше 16 лет                0.00
# 1997         «12+» - для детей старше 12 лет                0.00
# 2005  «0+» - для любой зрительской аудитории         30000000.00
# 2014         «12+» - для детей старше 12 лет                0.00
# 2053         «16+» - для детей старше 16 лет                0.00
# 2058         «16+» - для детей старше 16 лет                0.00
# 2084         «12+» - для детей старше 12 лет                0.00
# 2092         «12+» - для детей старше 12 лет                0.00
# 2106         «16+» - для детей старше 16 лет                0.00
# 2108         «16+» - для детей старше 16 лет                0.00
# 2109         «16+» - для детей старше 16 лет                0.00
# 2132         «12+» - для детей старше 12 лет                0.00
# 2142         «12+» - для детей старше 12 лет         30000000.00
# 2143         «16+» - для детей старше 16 лет                0.00
# 2146           «6+» - для детей старше 6 лет                0.00
# 2150             «18+» - запрещено для детей                0.00
# 2166         «16+» - для детей старше 16 лет                0.00
# 2169         «12+» - для детей старше 12 лет                0.00
# 2205         «12+» - для детей старше 12 лет                0.00
#
#       nonrefundable_support       budget                  financing_source  \
# 1281            26500000.00  79411900.00             Министерство культуры
# 1448            26000000.00  37142857.00             Министерство культуры
# 1498           107847945.00 176023490.00                         Фонд кино
# 1524            28000000.00  40574140.00             Министерство культуры
# 1792            25000000.00  40015122.00             Министерство культуры
# 1854            25000000.00  51850000.00             Министерство культуры
# 1870           100000000.00 220588394.00                         Фонд кино
# 1871            46502299.00  86210067.00  Министерство культуры, Фонд кино
# 1903            75000000.00 139551503.00                         Фонд кино
# 1912            34000000.00  48571430.00             Министерство культуры
# 1987            30000000.00  80000000.00                         Фонд кино
# 1991            25000000.00  36259500.00             Министерство культуры
# 1997            25000000.00  70876172.00                         Фонд кино
# 2005            40000000.00 252489571.00                         Фонд кино
# 2014            28000000.00  74910000.00             Министерство культуры
# 2053            23000000.00         0.00  Министерство культуры, Фонд кино
# 2058            75000000.00         0.00                         Фонд кино
# 2084            45000000.00  89782312.00             Министерство культуры
# 2092            56579055.00 436437176.00  Министерство культуры, Фонд кино
# 2106            25500000.00  40500000.00             Министерство культуры
# 2108            45000000.00  68490606.00  Министерство культуры, Фонд кино
# 2109            30000000.00  45006609.00                         Фонд кино
# 2132            27510000.00 131000000.00             Министерство культуры
# 2142            30000000.00 500000000.00                         Фонд кино
# 2143            25000000.00  61011407.00                         Фонд кино
# 2146            10000000.00  40000000.00             Министерство культуры
# 2150            25000000.00  37371262.00             Министерство культуры
# 2166            24000000.00  35296950.00             Министерство культуры
# 2169            30000000.00  43000000.00             Министерство культуры
# 2205            30000000.00  77401751.00                         Фонд кино
#
#       ratings                          genres   box_office
# 1281     8.10                 драма,мелодрама    365353.60
# 1448      NaN                       не указан     28140.00
# 1498     5.30              комедия,фантастика  19957031.50
# 1524     4.20                           драма     55917.50
# 1792     6.40                           драма    232100.00
# 1854     6.10      мультфильм,фэнтези,история  15078858.60
# 1870     8.50           драма,военный,история 249166767.70
# 1871     6.70                           драма   4731239.50
# 1903     7.00      триллер,боевик,приключения 352804320.40
# 1912     7.40       фэнтези,приключения,драма     51907.50
# 1987     5.00                семейный,комедия 121225633.80
# 1991     6.80                       мелодрама    554251.00
# 1997     6.60  фантастика,комедия,приключения  43534847.10
# 2005     6.50  мультфильм,фэнтези,приключения 313489846.50
# 2014     5.70                комедия,семейный   6277796.20
# 2053     6.60                       мелодрама  10234016.10
# 2058     6.60                           драма 446163511.00
# 2084     6.20           военный,драма,история  22723575.00
# 2092     7.10           драма,военный,история 451812221.70
# 2106     6.70                 драма,мелодрама    366998.00
# 2108     5.00                   драма,комедия    310738.00
# 2109     5.40              комедия,фантастика  11663188.00
# 2132     7.50         биография,военный,драма 401804461.90
# 2142     6.80        детектив,фэнтези,триллер  72578317.40
# 2143     5.60                    боевик,драма  33005527.30
# 2146     9.40       фантастика,боевик,комедия    334750.00
# 2150      NaN                       не указан     19820.00
# 2166     6.70                           драма    854334.50
# 2169     6.10          детектив,история,драма     40050.00
# 2205     6.00                         комедия 393344626.30

# %% [markdown]
# Не у всех фильмов с гос.поддержкой указан бюджет. а где-то где он указан он меньше суммы зарезервированных для него возвратных и невозвратных средств. Составим отдельный датафрейм с ними.

# %%
incorrect_budget = movies[movies['budget'] < (movies['refundable_support'] + movies['nonrefundable_support'])]
incorrect_budget
# Out:
#                        title   puNumber show_start_date            type  \
# 2053                     14+  111023614      2014-12-19  Художественный
# 2058               Дуxless 2  111000415      2015-01-26  Художественный
# 2472             Воин (2015)  111017315      2015-09-28  Художественный
# 2532                 Бармен.  111009615      2015-05-26  Художественный
# 2615     Савва. Сердце воина  114001715      2015-07-21    Анимационный
# 2684          Тряпичный союз  111010215      2015-06-08  Художественный
# 2788      Срочно выйду замуж  111017115      2015-09-30  Художественный
# 2874       Помню - не помню!  111004916      2016-03-01  Художественный
# 3047  Любовь с ограничениями  111008216      2016-04-29  Художественный
# 3565       Притяжение (2016)  111018116      2016-12-16  Художественный
# 3675                Чудо-юдо  114001817      2017-06-27    Анимационный
# 3739                    Мифы  111004317      2017-06-07  Художественный
# 5673                   Селфи  111012117      2018-02-01  Художественный
# 5806              Два хвоста  114001018      2018-05-31    Анимационный
# 6008      Принцесса и дракон  114003018      2018-08-23    Анимационный
# 6323                Баба Яга  114006518      2018-11-08    Анимационный
# 6823     Большое путешествие  114002419      2019-04-20    Анимационный
#
#                                             film_studio production_country  \
# 2053                         ООО Киностудия  "Сентябрь"                США
# 2058  ООО "Киностудия "Слово", ООО "Арт Пикчерс Студия"                США
# 2472   ООО "Форпост Продакшн", ООО "Арт Пикчерс Студия"                США
# 2532          АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"                США
# 2615   ООО "Глюкоза Продакшн", ООО "Арт Пикчерс Студия"                США
# 2684                      ООО "Кинокомпания "КОКТЕБЕЛЬ"                США
# 2788          АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"                США
# 2874                                    ООО "КиноФирма"                США
# 3047          АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"                США
# 3565      ООО "Водород 2011",  ООО "Арт Пикчерс Студия"                США
# 3675                                    ООО "КиноФирма"                США
# 3739           ООО "ХАЙПФИЛМ", ООО "Арт Пикчерс Студия"                США
# 5673  ООО "Киностудия "Слово", ООО "Арт Пикчерс Студия"                США
# 5806                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"                США
# 6008                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"                США
# 6323                           ООО "Арт Пикчерс Студия"                США
# 6823                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"                США
#
#                             director  \
# 2053                        А.Зайцев
# 2058                      Р.Прыгунов
# 2472                     А.Андрианов
# 2532                    Д.Штурманова
# 2615                        М.Фадеев
# 2684                     М.Местецкий
# 2788                       С Чекалов
# 2874                     В.Ровенский
# 3047                         Д.Тюрин
# 3565                     Ф.Бондарчук
# 3675                       А.Лукичев
# 3739                    А.Молочников
# 5673                      Н.Хомерики
# 5806  В.Ровенский, Н.Лопато, В.Азеев
# 6008                      М.Нефедова
# 6323                         В.Саков
# 6823           Н.Лопато, В.Ровенский
#
#                                                producer  \
# 2053                                О.Гранина, А.Зайцев
# 2058                 П.Ануров, Ф.Бондарчук, Д.Рудовский
# 2472                           ООО "Арт Пикчерс Студия"
# 2532                                        Т.Вайнштейн
# 2615                                         А.Чистяков
# 2684                              Р.Борисевич, А.Кушаев
# 2788              Ф.Бондарчук, Т.Вайнштейн, Д.Рудовский
# 2874                                    ООО "КиноФирма"
# 3047              Ф.Бондарчук, Т.Вайнштейн, Д.Рудовский
# 3565                           ООО "Арт Пикчерс Студия"
# 3675                                    ООО "КиноФирма"
# 3739  Ф.Бондарчук, Д.Рудовский, И.Стюарт, М.Османн, ...
# 5673                 П.Ануров, Ф.Бондарчук, Д.Рудовский
# 5806                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
# 6008                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
# 6323  ООО "Арт Пикчерс Студия", ООО "КРИЭЙТИВ АНИМЭЙ...
# 6823                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
#
#                       age_restriction  refundable_support  \
# 2053  «16+» - для детей старше 16 лет                0.00
# 2058  «16+» - для детей старше 16 лет                0.00
# 2472  «12+» - для детей старше 12 лет         10000000.00
# 2532  «16+» - для детей старше 16 лет         20000000.00
# 2615    «6+» - для детей старше 6 лет         60000000.00
# 2684      «18+» - запрещено для детей                0.00
# 2788  «16+» - для детей старше 16 лет                0.00
# 2874  «12+» - для детей старше 12 лет                0.00
# 3047  «16+» - для детей старше 16 лет         19000000.00
# 3565  «12+» - для детей старше 12 лет                0.00
# 3675    «6+» - для детей старше 6 лет         20000000.00
# 3739  «16+» - для детей старше 16 лет         25000000.00
# 5673  «16+» - для детей старше 16 лет         20000000.00
# 5806    «6+» - для детей старше 6 лет         10000000.00
# 6008    «6+» - для детей старше 6 лет         40000000.00
# 6323    «6+» - для детей старше 6 лет                0.00
# 6823    «6+» - для детей старше 6 лет         60000000.00
#
#       nonrefundable_support  budget                  financing_source  \
# 2053            23000000.00    0.00  Министерство культуры, Фонд кино
# 2058            75000000.00    0.00                         Фонд кино
# 2472            70000000.00    0.00                         Фонд кино
# 2532                   0.00    0.00                         Фонд кино
# 2615           100000000.00    0.00                         Фонд кино
# 2684            59000000.00    0.00                         Фонд кино
# 2788            35000000.00    0.00                         Фонд кино
# 2874             6000000.00    0.00             Министерство культуры
# 3047            51000000.00    0.00                         Фонд кино
# 3565           250000000.00    0.00                         Фонд кино
# 3675            20000000.00    0.00                         Фонд кино
# 3739            20000000.00    0.00                         Фонд кино
# 5673            40000000.00    0.00                         Фонд кино
# 5806            60000000.00    0.00                         Фонд кино
# 6008            40000000.00    0.00                         Фонд кино
# 6323           138969465.00    0.00                         Фонд кино
# 6823           120000000.00    0.00                         Фонд кино
#
#       ratings                          genres    box_office
# 2053     6.60                       мелодрама   10234016.10
# 2058     6.60                           драма  446163511.00
# 2472     7.80           боевик,драма,криминал  196572438.40
# 2532     6.20                 комедия,фэнтези   67418974.80
# 2615     4.60  мультфильм,приключения,фэнтези  184487551.40
# 2684     6.30                   комедия,драма    1957738.51
# 2788     5.10               комедия,мелодрама   72937783.20
# 2874     4.30                         комедия   15362931.43
# 3047     6.30               комедия,мелодрама   70299052.00
# 3565     5.60                      фантастика 1038321489.00
# 3675     5.20     мультфильм,фэнтези,семейный   55108014.76
# 3739     4.80                         комедия   50451949.00
# 5673     5.80                   триллер,драма  225196400.03
# 5806     5.00              мультфильм,детский  106514301.03
# 6008     5.20      мультфильм,фэнтези,детский   83366328.66
# 6323      NaN                       не указан    1334699.40
# 6823     6.20  мультфильм,комедия,приключения  147606826.51

# %%
movies['gos_fin_perc'] = (movies['refundable_support'] + movies['nonrefundable_support']) / movies['budget']
gosfin_perc = movies['gos_fin_perc'].median().round(2)
print('Коэффициент поддержки фильмов государством', gosfin_perc)
# Out:
# Коэффициент поддержки фильмов государством 0.61

# %% [markdown]
# Зная этот коэффициент можем заполнить пропуски в графе бюджет и подставить эти значения в исходную таблицу.

# %%
movies.loc[incorrect_budget.index, 'budget'] = \
(movies.loc[incorrect_budget.index, 'refundable_support'] + movies.loc[incorrect_budget.index, 'nonrefundable_support'])\
/ gosfin_perc
movies.loc[incorrect_budget.index]
# Out:
#                        title   puNumber show_start_date            type  \
# 2053                     14+  111023614      2014-12-19  Художественный
# 2058               Дуxless 2  111000415      2015-01-26  Художественный
# 2472             Воин (2015)  111017315      2015-09-28  Художественный
# 2532                 Бармен.  111009615      2015-05-26  Художественный
# 2615     Савва. Сердце воина  114001715      2015-07-21    Анимационный
# 2684          Тряпичный союз  111010215      2015-06-08  Художественный
# 2788      Срочно выйду замуж  111017115      2015-09-30  Художественный
# 2874       Помню - не помню!  111004916      2016-03-01  Художественный
# 3047  Любовь с ограничениями  111008216      2016-04-29  Художественный
# 3565       Притяжение (2016)  111018116      2016-12-16  Художественный
# 3675                Чудо-юдо  114001817      2017-06-27    Анимационный
# 3739                    Мифы  111004317      2017-06-07  Художественный
# 5673                   Селфи  111012117      2018-02-01  Художественный
# 5806              Два хвоста  114001018      2018-05-31    Анимационный
# 6008      Принцесса и дракон  114003018      2018-08-23    Анимационный
# 6323                Баба Яга  114006518      2018-11-08    Анимационный
# 6823     Большое путешествие  114002419      2019-04-20    Анимационный
#
#                                             film_studio production_country  \
# 2053                         ООО Киностудия  "Сентябрь"                США
# 2058  ООО "Киностудия "Слово", ООО "Арт Пикчерс Студия"                США
# 2472   ООО "Форпост Продакшн", ООО "Арт Пикчерс Студия"                США
# 2532          АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"                США
# 2615   ООО "Глюкоза Продакшн", ООО "Арт Пикчерс Студия"                США
# 2684                      ООО "Кинокомпания "КОКТЕБЕЛЬ"                США
# 2788          АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"                США
# 2874                                    ООО "КиноФирма"                США
# 3047          АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"                США
# 3565      ООО "Водород 2011",  ООО "Арт Пикчерс Студия"                США
# 3675                                    ООО "КиноФирма"                США
# 3739           ООО "ХАЙПФИЛМ", ООО "Арт Пикчерс Студия"                США
# 5673  ООО "Киностудия "Слово", ООО "Арт Пикчерс Студия"                США
# 5806                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"                США
# 6008                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"                США
# 6323                           ООО "Арт Пикчерс Студия"                США
# 6823                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"                США
#
#                             director  \
# 2053                        А.Зайцев
# 2058                      Р.Прыгунов
# 2472                     А.Андрианов
# 2532                    Д.Штурманова
# 2615                        М.Фадеев
# 2684                     М.Местецкий
# 2788                       С Чекалов
# 2874                     В.Ровенский
# 3047                         Д.Тюрин
# 3565                     Ф.Бондарчук
# 3675                       А.Лукичев
# 3739                    А.Молочников
# 5673                      Н.Хомерики
# 5806  В.Ровенский, Н.Лопато, В.Азеев
# 6008                      М.Нефедова
# 6323                         В.Саков
# 6823           Н.Лопато, В.Ровенский
#
#                                                producer  \
# 2053                                О.Гранина, А.Зайцев
# 2058                 П.Ануров, Ф.Бондарчук, Д.Рудовский
# 2472                           ООО "Арт Пикчерс Студия"
# 2532                                        Т.Вайнштейн
# 2615                                         А.Чистяков
# 2684                              Р.Борисевич, А.Кушаев
# 2788              Ф.Бондарчук, Т.Вайнштейн, Д.Рудовский
# 2874                                    ООО "КиноФирма"
# 3047              Ф.Бондарчук, Т.Вайнштейн, Д.Рудовский
# 3565                           ООО "Арт Пикчерс Студия"
# 3675                                    ООО "КиноФирма"
# 3739  Ф.Бондарчук, Д.Рудовский, И.Стюарт, М.Османн, ...
# 5673                 П.Ануров, Ф.Бондарчук, Д.Рудовский
# 5806                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
# 6008                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
# 6323  ООО "Арт Пикчерс Студия", ООО "КРИЭЙТИВ АНИМЭЙ...
# 6823                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
#
#                       age_restriction  refundable_support  \
# 2053  «16+» - для детей старше 16 лет                0.00
# 2058  «16+» - для детей старше 16 лет                0.00
# 2472  «12+» - для детей старше 12 лет         10000000.00
# 2532  «16+» - для детей старше 16 лет         20000000.00
# 2615    «6+» - для детей старше 6 лет         60000000.00
# 2684      «18+» - запрещено для детей                0.00
# 2788  «16+» - для детей старше 16 лет                0.00
# 2874  «12+» - для детей старше 12 лет                0.00
# 3047  «16+» - для детей старше 16 лет         19000000.00
# 3565  «12+» - для детей старше 12 лет                0.00
# 3675    «6+» - для детей старше 6 лет         20000000.00
# 3739  «16+» - для детей старше 16 лет         25000000.00
# 5673  «16+» - для детей старше 16 лет         20000000.00
# 5806    «6+» - для детей старше 6 лет         10000000.00
# 6008    «6+» - для детей старше 6 лет         40000000.00
# 6323    «6+» - для детей старше 6 лет                0.00
# 6823    «6+» - для детей старше 6 лет         60000000.00
#
#       nonrefundable_support       budget                  financing_source  \
# 2053            23000000.00  37704918.03  Министерство культуры, Фонд кино
# 2058            75000000.00 122950819.67                         Фонд кино
# 2472            70000000.00 131147540.98                         Фонд кино
# 2532                   0.00  32786885.25                         Фонд кино
# 2615           100000000.00 262295081.97                         Фонд кино
# 2684            59000000.00  96721311.48                         Фонд кино
# 2788            35000000.00  57377049.18                         Фонд кино
# 2874             6000000.00   9836065.57             Министерство культуры
# 3047            51000000.00 114754098.36                         Фонд кино
# 3565           250000000.00 409836065.57                         Фонд кино
# 3675            20000000.00  65573770.49                         Фонд кино
# 3739            20000000.00  73770491.80                         Фонд кино
# 5673            40000000.00  98360655.74                         Фонд кино
# 5806            60000000.00 114754098.36                         Фонд кино
# 6008            40000000.00 131147540.98                         Фонд кино
# 6323           138969465.00 227818795.08                         Фонд кино
# 6823           120000000.00 295081967.21                         Фонд кино
#
#       ratings                          genres    box_office  gos_fin_perc
# 2053     6.60                       мелодрама   10234016.10           inf
# 2058     6.60                           драма  446163511.00           inf
# 2472     7.80           боевик,драма,криминал  196572438.40           inf
# 2532     6.20                 комедия,фэнтези   67418974.80           inf
# 2615     4.60  мультфильм,приключения,фэнтези  184487551.40           inf
# 2684     6.30                   комедия,драма    1957738.51           inf
# 2788     5.10               комедия,мелодрама   72937783.20           inf
# 2874     4.30                         комедия   15362931.43           inf
# 3047     6.30               комедия,мелодрама   70299052.00           inf
# 3565     5.60                      фантастика 1038321489.00           inf
# 3675     5.20     мультфильм,фэнтези,семейный   55108014.76           inf
# 3739     4.80                         комедия   50451949.00           inf
# 5673     5.80                   триллер,драма  225196400.03           inf
# 5806     5.00              мультфильм,детский  106514301.03           inf
# 6008     5.20      мультфильм,фэнтези,детский   83366328.66           inf
# 6323      NaN                       не указан    1334699.40           inf
# 6823     6.20  мультфильм,комедия,приключения  147606826.51           inf

# %% [markdown]
# В этом пункте мы дополнили данные о фильмах с гос.поддержкой:
#
# * Расчитали медианный коэффициент поддержки фильмов государством.
#
# * Зная этот коэффициент расчитали и дополнили таблицу данными о бюджете.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Очень хорошо!)

# %% [markdown]
# #### Шаг 2.6. Добавьте новые столбцы

# %% [markdown]
# - Создайте столбец с информацией о годе проката. Выделите год из даты премьеры фильма.

# %%
#создаем отдельный столб с указанием года проката
movies['show_year'] = pd.DatetimeIndex(movies['show_start_date']).year

# %% [markdown]
# - Создайте два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_2" aria-expanded="false" aria-controls="collapseHint_2">Подсказка</button>
#         </div>
#         <div id="collapseHint_2" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Чтобы создать такие столбцы, лучше всего использовать собственную функцию. Эту функцию можно применить к двум столбцам сразу.
#             </div>
#         </div>
#     </div>
# </div>

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   int64
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7486 non-null   object
#  5   production_country     7486 non-null   object
#  6   director               7486 non-null   object
#  7   producer               7486 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       7486 non-null   object
#  13  ratings                6519 non-null   float64
#  14  genres                 7486 non-null   object
#  15  box_office             3158 non-null   float64
#  16  gos_fin_perc           332 non-null    float64
#  17  show_year              7486 non-null   int64
# dtypes: float64(6), int64(2), object(10)
# memory usage: 1.0+ MB

# %%
#пропишем функцию, которая будет выбирать первое значение в столбце
def main(name):
    name = name.split(',')
    return name[0]

#столбцы откуда будем брать данные для новых значений
change_col = ['genres', 'director']

for col in change_col:
    movies['main_' + col] = movies[col].apply(main) 

    
def find_first (name):
    name = name.split(',')
    return name[0]
 
cols_2 = ['genres', 'director']
 
for col in cols_2:
    movies['new'] = movies[col].apply(find_first)
   
movies['new_' + col] = movies[col].apply(find_first)

# %%
movies.head()
# Out:
#                   title   puNumber show_start_date            type  \
# 0      Открытый простор  221048915      2015-11-27  Художественный
# 1  Особо важное задание  111013716      2016-09-13  Художественный
# 2          Особо опасен  221038416      2016-10-10  Художественный
# 3          Особо опасен  221026916      2016-06-10  Художественный
# 4          Особо опасен  221030815      2015-07-29  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"                США
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                          не указан
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  ...  financing_source  \
# 0    «18+» - запрещено для детей                 NaN  ...           Частное
# 1  «6+» - для детей старше 6 лет                 NaN  ...           Частное
# 2    «18+» - запрещено для детей                 NaN  ...           Частное
# 3    «18+» - запрещено для детей                 NaN  ...           Частное
# 4    «18+» - запрещено для детей                 NaN  ...           Частное
#
#    ratings                     genres  box_office gos_fin_perc  show_year  \
# 0     7.20     боевик,драма,мелодрама         NaN          NaN       2015
# 1     6.60              драма,военный         NaN          NaN       2016
# 2     6.80  фантастика,боевик,триллер         NaN          NaN       2016
# 3     6.80  фантастика,боевик,триллер         NaN          NaN       2016
# 4     6.80  фантастика,боевик,триллер         NaN          NaN       2015
#
#    main_genres      main_director                new       new_director
# 0       боевик      Кевин Костнер      Кевин Костнер      Кевин Костнер
# 1        драма          Е.Матвеев          Е.Матвеев          Е.Матвеев
# 2   фантастика  Тимур Бекмамбетов  Тимур Бекмамбетов  Тимур Бекмамбетов
# 3   фантастика  Тимур Бекмамбетов  Тимур Бекмамбетов  Тимур Бекмамбетов
# 4   фантастика  Тимур Бекмамбетов  Тимур Бекмамбетов  Тимур Бекмамбетов
#
# [5 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Столбцы добавлены верно)

# %% [markdown]
# - Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %% [markdown]
# Эти данные содержаться в movies['gos_fin_perc']. Можно рассмотреть эти данные отдельно.

# %%
movies.query('budget > 0')
# Out:
#                             title   puNumber show_start_date            type  \
# 1281                Пока еще жива  111005313      2013-10-11  Художественный
# 1448          Бесславные придурки  111003314      2014-03-28  Художественный
# 1498                    Невидимки  111004213      2013-09-10  Художественный
# 1524                        БЕРЦЫ  111004314      2014-05-05  Художественный
# 1792                     Братья Ч  111004414      2014-04-23  Художественный
# ...                           ...        ...             ...             ...
# 7464                Союз спасения  111022019      2019-12-26  Художественный
# 7466  Иван Царевич и Серый Волк 4  114005019      2019-12-20    Анимационный
# 7474                    Вторжение  111022519      2019-12-23  Художественный
# 7476                   Я свободен  111023019      2019-12-26  Художественный
# 7478        (Не)идеальный мужчина  111023119      2019-12-24  Художественный
#
#                                             film_studio production_country  \
# 1281  АНО содействия развитию кинематографии "Ангел-...                США
# 1448                         ООО "Компания "АТК-Студио"                США
# 1498                        ООО "Компания "РЕАЛ-ДАКОТА"                США
# 1524                             ООО "Студия "Пассажир"                США
# 1792                             ООО "Студия "Пассажир"                США
# ...                                                 ...                ...
# 7464                                ЗАО "Дирекция кино"                США
# 7466          ООО "Студия анимационного кино "Мельница"                США
# 7474       ООО "Арт Пикчерс Студия", ООО "Водород 2011"                США
# 7476                АО "ТПО "Киностудия им. М.Горького"                США
# 7478                            ООО "Нон-Стоп Продакшн"                США
#
#                                   director  \
# 1281                            А.Атанесян
# 1448                             А.Якимчук
# 1498              Р.Давлетьяров, С.Комаров
# 1524  Е.Миндадзе (псевдоним Катя Шагалова)
# 1792                              М.Угаров
# ...                                    ...
# 7464                             А.Кравчук
# 7466                 Д.Шмидт, К.Феоктистов
# 7474                           Ф.Бондарчук
# 7476                             И.Северов
# 7478    М.Бальчюнас (псевдоним М.Вайсберг)
#
#                                                producer  \
# 1281                   А.Атанесян, М.Бабаханов, Р.Бутко
# 1448                                         А.Тютрюмов
# 1498          Р.Давлетьяров, А.Котелевский, А.Олейников
# 1524                                         Л.Антонова
# 1792                             А.Миндадзе, Л.Антонова
# ...                                                 ...
# 7464                                А.Максимов, К.Эрнст
# 7466                             С.Сельянов, А.Боярский
# 7474  Ф.Бондарчук, М.Врубель, А.Андрющенко, Д.Рудовский
# 7476                                           С.Зернов
# 7478  С.Мелькумов, А.Роднянский, М.Вайсберг, Р.Минас...
#
#                       age_restriction  refundable_support  ...  \
# 1281  «16+» - для детей старше 16 лет                0.00  ...
# 1448  «12+» - для детей старше 12 лет                0.00  ...
# 1498  «12+» - для детей старше 12 лет                0.00  ...
# 1524  «16+» - для детей старше 16 лет                0.00  ...
# 1792  «16+» - для детей старше 16 лет                0.00  ...
# ...                               ...                 ...  ...
# 7464  «12+» - для детей старше 12 лет        100000000.00  ...
# 7466    «6+» - для детей старше 6 лет        100000000.00  ...
# 7474  «12+» - для детей старше 12 лет        100000000.00  ...
# 7476  «12+» - для детей старше 12 лет                0.00  ...
# 7478  «12+» - для детей старше 12 лет         40000000.00  ...
#
#            financing_source  ratings                           genres  \
# 1281  Министерство культуры     8.10                  драма,мелодрама
# 1448  Министерство культуры      NaN                        не указан
# 1498              Фонд кино     5.30               комедия,фантастика
# 1524  Министерство культуры     4.20                            драма
# 1792  Министерство культуры     6.40                            драма
# ...                     ...      ...                              ...
# 7464              Фонд кино     6.00          история,биография,драма
# 7466              Фонд кино     6.70  мультфильм,приключения,семейный
# 7474              Фонд кино     5.70                фантастика,боевик
# 7476  Министерство культуры     5.90                            драма
# 7478              Фонд кино     4.50     комедия,фантастика,мелодрама
#
#        box_office gos_fin_perc  show_year  main_genres  \
# 1281    365353.60         0.33       2013        драма
# 1448     28140.00         0.70       2014    не указан
# 1498  19957031.50         0.61       2013      комедия
# 1524     55917.50         0.69       2014        драма
# 1792    232100.00         0.62       2014        драма
# ...           ...          ...        ...          ...
# 7464 717703185.53         0.51       2019      история
# 7466 501069235.00         0.53       2019   мультфильм
# 7474          NaN         0.53       2019   фантастика
# 7476          NaN         0.65       2019        драма
# 7478          NaN         0.67       2019      комедия
#
#                              main_director  \
# 1281                            А.Атанесян
# 1448                             А.Якимчук
# 1498                         Р.Давлетьяров
# 1524  Е.Миндадзе (псевдоним Катя Шагалова)
# 1792                              М.Угаров
# ...                                    ...
# 7464                             А.Кравчук
# 7466                               Д.Шмидт
# 7474                           Ф.Бондарчук
# 7476                             И.Северов
# 7478    М.Бальчюнас (псевдоним М.Вайсберг)
#
#                                        new  \
# 1281                            А.Атанесян
# 1448                             А.Якимчук
# 1498                         Р.Давлетьяров
# 1524  Е.Миндадзе (псевдоним Катя Шагалова)
# 1792                              М.Угаров
# ...                                    ...
# 7464                             А.Кравчук
# 7466                               Д.Шмидт
# 7474                           Ф.Бондарчук
# 7476                             И.Северов
# 7478    М.Бальчюнас (псевдоним М.Вайсберг)
#
#                               new_director
# 1281                            А.Атанесян
# 1448                             А.Якимчук
# 1498                         Р.Давлетьяров
# 1524  Е.Миндадзе (псевдоним Катя Шагалова)
# 1792                              М.Угаров
# ...                                    ...
# 7464                             А.Кравчук
# 7466                               Д.Шмидт
# 7474                           Ф.Бондарчук
# 7476                             И.Северов
# 7478    М.Бальчюнас (псевдоним М.Вайсберг)
#
# [332 rows x 22 columns]

# %% [markdown]
# В это пункте работы добавлены новые столбцы, содержащие информацию о годе проката, главном жанре и главно режиссере.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Замечательная работа по предобработке данных! Типы преобразованы правильно, столбцы добавлены верно, пропуски обработаны)

# %% [markdown]
# ### Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# - Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах.

# %% [markdown]
# Рассмотрим количесто фильмов ежегодно получавших прокатное удостоверение.

# %%
year_analisys = movies.pivot_table(index='show_year',
                                   values=['box_office', 'puNumber'],
                                   aggfunc='count'
                                  )
year_analisys.columns = ['прокат в кинотеатрах', 'общее количество фильмов']
year_analisys.plot(kind = 'bar',
                  title = 'Количество сазданных фильмов')

plt.ylabel('количество фильмов')
plt.xlabel('год')

plt.show();

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Можно добавить подписи к графику, используя `plt.xlabel()` и `plt.ylabel()`. Подробнее об оформлении графиков, ты можешь узнать тут:
#
# https://slemeshevsky.github.io/python-course/visual/html/._visual-flatly002.html
#
# </div>

# %%
year_analisys['доля фильмов в прокате кинотеатров, %'] = \
year_analisys['прокат в кинотеатрах'] / year_analisys['общее количество фильмов'] * 100
year_analisys
# Out:
#            прокат в кинотеатрах  общее количество фильмов  \
# show_year
# 2010                        105                       985
# 2011                        109                       622
# 2012                        128                       593
# 2013                        184                       630
# 2014                        279                       807
# 2015                        465                       705
# 2016                        526                       818
# 2017                        357                       505
# 2018                        475                       891
# 2019                        530                       930
#
#            доля фильмов в прокате кинотеатров, %
# show_year
# 2010                                       10.66
# 2011                                       17.52
# 2012                                       21.59
# 2013                                       29.21
# 2014                                       34.57
# 2015                                       65.96
# 2016                                       64.30
# 2017                                       70.69
# 2018                                       53.31
# 2019                                       56.99

# %% [markdown]
# Не смотря на то, что 2010-1 год был самым урожайным на количество выданных удостоверений, в кинотеатры попала лишь 10% фильмов.
#
# Общее количество фильмов год от года менялось весма рандомным образом от 505 до 930.
#
# Самое меньшее количество фильмов вшла в 2017-м. Зато в кинопрокате оказалась большая часть из них, 70%.
#
# В 2018-м ровно наоборот, вышло очень много фильмов, 891. И не смотря на то, до театров дошло 475, в процентном отношении провал на 17%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Отлично, можно также добавить график с долей фильмов)

# %% [markdown]
# - Изучите, как менялась динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?

# %%
year_analisys['сумма сборов'] = movies.groupby('show_year')['box_office'].sum()
year_analisys
# Out:
#            прокат в кинотеатрах  общее количество фильмов  \
# show_year
# 2010                        105                       985
# 2011                        109                       622
# 2012                        128                       593
# 2013                        184                       630
# 2014                        279                       807
# 2015                        465                       705
# 2016                        526                       818
# 2017                        357                       505
# 2018                        475                       891
# 2019                        530                       930
#
#            доля фильмов в прокате кинотеатров, %   сумма сборов
# show_year
# 2010                                       10.66     2428654.00
# 2011                                       17.52    14102765.00
# 2012                                       21.59     6955423.00
# 2013                                       29.21    29799706.20
# 2014                                       34.57  7444951859.20
# 2015                                       65.96 39497365196.40
# 2016                                       64.30 47866299741.91
# 2017                                       70.69 48563707217.51
# 2018                                       53.31 49668403134.32
# 2019                                       56.99 48425708779.59

# %%
year_analisys['сумма сборов'].plot(kind = 'bar',
                                   title = 'сумма сборов');

# %% [markdown]
# Не смотря на весьма неодназначные данные по количеству вышедших в прокат фильмов в год, по сумме сборов всегда прирост, разве что в 2019 показатель чуть меньше, недели годом ранее.
#
# Самый резкий скачок произошел в 2015-м году. Скорее всего это связанос курсом доллара. Добавим его динамику отдельно.

# %%
data = {'year': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
        'dollar': [30.37, 29.39, 31.09, 31.85, 38.42, 60.96, 67.03, 58.35, 62.71, 64.74]
        }
dollar = pd.DataFrame(data)
dollar.plot(kind = 'line',
           x='year',
           y='dollar',
           xlim=(2010, 2019),
           grid=True,
           title = 'курс доллара');

# %% [markdown]
# Так и есть резкий взлет в 2015-м. В 2017 доллар чуть сдал свои позиции, но как мы помним из анализа выше, в этом году вышло самое большое количество фильмов за это 10-летие, потому логично что на объемах кассовх сборов это не отрпзилось.

# %% [markdown]
# - С помощью сводной таблицы посчитайте среднюю и медианную сумму сборов для каждого года.

# %% [markdown]
# Рассмотрим медианную доходность от фильмов по годам.

# %%
import matplotlib.pyplot as plt
(
    movies.pivot_table(index = 'show_year',
                  values = 'box_office',
                  aggfunc = 'median')
    .plot(kind = 'line',
         title = 'динамика медианы сборов фильма в кинотеатрах',
         grid = True,
         xlim = (2010, 2019))
);

# %% [markdown]
# Рассмотрим график изменения медианной прибыли в кинопрокатах по годам. Резкий скачок был в 2014 году. Как раз когда курс доллара к рублю взлетел.
#
# В 2016 году в прокат в кинотеатрах вышло много фильмов, 526. А как говорит основной закон рыночной экономики гласит – чем выше конкуренция, тем ниже прибыль. соотвественно ниже медианное значение средней доходности на 1 фильм.
#
# А в 2017-м как раз выходило меньше количество фильмов и медиана снова взлетила, это самый высокий показатель периода 2010-2019.
# Расчитаем кооэффициент Пирсона для этих 2 показателей.

# %%
#Для расчета Пирсона создадим отдельный датафрейм, который на далее не будет нужен
b = (
    movies.query('box_office >0')
          .pivot_table(index = 'show_year',
                       values = 'box_office',
                       aggfunc = ['median', 'count'])
)
b.columns = ['медианная прибыль', 'количество фильмов']
print(b)
b['медианная прибыль'].corr(b['количество фильмов'])
# Out:
#            медианная прибыль  количество фильмов
# show_year
# 2010                 1710.00                 101
# 2011                 3000.00                 109
# 2012                 6220.00                 123
# 2013                 3580.00                 179
# 2014                20400.00                 273
# 2015              5003450.15                 462
# 2016              3915041.02                 525
# 2017              9968340.00                 357
# 2018              8891102.21                 475
# 2019              4627798.34                 530
# 0.7167456620203876

# %% [markdown]
# Коэффициент Пирсона 0.72, это говорит нам о высокой коррелиции, из таблицы видно, что чем больше выходило фильмов, тем меньше средняя доходность по ним.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Отличная работа! Молодец, что дополнительно проверяешь корреляцию)

# %% [markdown]
# - Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %% [markdown]
# Рассмотрим в цифрах сборы фильмов по категориям

# %%
movies.pivot_table(index='show_year',
                columns='age_restriction',
                values='box_office',
                aggfunc='median')
# Out:
# age_restriction  «0+» - для любой зрительской аудитории  \
# show_year
# 2010                                            6052.50
# 2011                                            7010.00
# 2012                                           18067.50
# 2013                                           13225.00
# 2014                                          190855.00
# 2015                                         2943318.70
# 2016                                         2571294.10
# 2017                                        22178956.00
# 2018                                         3616937.28
# 2019                                         3885434.50
#
# age_restriction  «12+» - для детей старше 12 лет  \
# show_year
# 2010                                     2650.00
# 2011                                     3741.50
# 2012                                     3685.00
# 2013                                     2250.00
# 2014                                     6037.50
# 2015                                 15351562.50
# 2016                                  4690635.25
# 2017                                  9010548.00
# 2018                                  8931965.66
# 2019                                  3405545.76
#
# age_restriction  «16+» - для детей старше 16 лет  «18+» - запрещено для детей  \
# show_year
# 2010                                     1000.00                       915.00
# 2011                                     2835.00                       520.00
# 2012                                     1600.00                      1385.00
# 2013                                     3300.00                      1775.00
# 2014                                    13640.00                    180108.00
# 2015                                  4676819.40                   4616614.70
# 2016                                  5133021.74                   6107001.74
# 2017                                  9702077.00                   8212677.00
# 2018                                  9010638.62                   7179466.00
# 2019                                  3210717.81                   5603216.55
#
# age_restriction  «6+» - для детей старше 6 лет
# show_year
# 2010                                       NaN
# 2011                                    450.00
# 2012                                   6475.00
# 2013                                   3457.50
# 2014                                 125810.00
# 2015                               20380982.20
# 2016                                3026256.15
# 2017                               51992103.00
# 2018                               14688850.32
# 2019                               12875350.34

# %% [markdown]
# Визуализируем с помощью графика

# %%
(
    movies.pivot_table(index='show_year',
                columns='age_restriction',
                values='box_office',
                aggfunc='median') \
    .plot(title='сборы фильмов по возрастным категориям',
          kind='line',
          xlim=[2015, 2019],
         figsize=(10, 5))
);

# %% [markdown]
# Фильмы в категориях 12+, 16+, 18+ показывают весьма стабильную диамику.
#
# А вот 0+ и 6+ год от года не стабильны. В 2017-м 6+ и 12+. Резко стрельнули. Посмотрим топ-5 кино того года в этих категориях.
#
# **ТОП-5 «0+» - для любой зрительской аудитории":**

# %%
(
    movies.query('age_restriction =="«0+» - для любой зрительской аудитории" \
    and show_year == 2017')
    .sort_values(by = 'box_office', ascending = False)
    .head(5)
)
# Out:
#                                                   title   puNumber  \
# 3687                Урфин Джюс и его деревянные солдаты  114000817
# 5564                       Колобанга. Привет, Интернет!  114002817
# 3480                      Маша и медведь. Новые истории  114001417
# 2949  Машкины Страшилки. Серия "Чудовищная правда о ...  214011517
# 3223                          МУЛЬТ в кино. Выпуск № 50  114000517
#
#      show_start_date          type                                film_studio  \
# 3687      2017-04-06  Анимационный  ООО "Студия анимационного кино "Мельница"
# 5564      2017-11-30  Анимационный                            ООО "Колобанга"
# 3480      2017-05-25  Анимационный                       ООО "Маша и Медведь"
# 2949      2017-06-09  Анимационный  ООО Студия "АНИМАККОРД" - АНИМАККОРД ЛТД.
# 3223      2017-03-21  Анимационный                         ООО "Мульт в кино"
#
#      production_country                                      director  \
# 3687                США               Д.Шмидт, Ф.Дмитриев, В.Торопчин
# 5564                США                         А.Романец, В.Марченко
# 3480                США  Г.Орлов, А.Беляев, Н.Мальгина, В.Байрамгулов
# 2949                США                                    Д.Червяцов
# 3223                США                                    О.Семёнова
#
#                              producer                         age_restriction  \
# 3687           С.Сельянов, А.Боярский  «0+» - для любой зрительской аудитории
# 5564                          А.Ревва  «0+» - для любой зрительской аудитории
# 3480  Д.Ловейко, О.Кузовков, М.Ратина  «0+» - для любой зрительской аудитории
# 2949            Д.Ловейко, О.Кузовков  «0+» - для любой зрительской аудитории
# 3223                        П.Смирнов  «0+» - для любой зрительской аудитории
#
#       refundable_support  ...  financing_source  ratings  \
# 3687                0.00  ...         Фонд кино     5.70
# 5564                 NaN  ...           Частное     4.90
# 3480                 NaN  ...           Частное      NaN
# 2949                 NaN  ...           Частное      NaN
# 3223                 NaN  ...           Частное     3.90
#
#                               genres   box_office gos_fin_perc  show_year  \
# 3687  мультфильм,приключения,детский 206478186.00         0.22       2017
# 5564              мультфильм,детский  22178956.00          NaN       2017
# 3480                       не указан    941788.00          NaN       2017
# 2949                       не указан          NaN          NaN       2017
# 3223              мультфильм,детский          NaN          NaN       2017
#
#       main_genres  main_director         new new_director
# 3687   мультфильм        Д.Шмидт     Д.Шмидт      Д.Шмидт
# 5564   мультфильм      А.Романец   А.Романец    А.Романец
# 3480    не указан        Г.Орлов     Г.Орлов      Г.Орлов
# 2949    не указан     Д.Червяцов  Д.Червяцов   Д.Червяцов
# 3223   мультфильм     О.Семёнова  О.Семёнова   О.Семёнова
#
# [5 rows x 22 columns]

# %% [markdown]
# **ТОП-5 «6+» - для детей старше 6 лет:**

# %%
(
    movies.query('age_restriction == "«6+» - для детей старше 6 лет" \
    and show_year == 2017')
    .sort_values(by = 'box_office', ascending = False)
    .head(5)
)
# Out:
#                title   puNumber show_start_date            type  \
# 5653  Движение вверх  111011817      2017-12-21  Художественный
# 3742      Гадкий я 3  124001617      2017-06-15    Анимационный
# 3235  Босс-Молокосос  124000317      2017-02-09    Анимационный
# 3637        Зверопой  124000217      2017-02-03    Анимационный
# 5641      Ёлки Новые  111011617      2017-12-21  Художественный
#
#                                             film_studio production_country  \
# 5653              ООО "Студия "ТРИТЭ" Никиты Михалкова"                США
# 3742      Иллюминейшен Интертейнмент, Юниверсал Пикчерз                США
# 3235                                 ДримУоркс Анимейшн                США
# 3637  Дентсю, Фьюджи Телевижн Нетворк Интертейнмент,...                США
# 5641                                       ООО "ТаББаК"                США
#
#                                                director  \
# 5653                                       А.Мегердичев
# 3742              Кайл Балда, Эрик Гуильон, Пьер Коффан
# 3235                                        Том МакГрат
# 3637                  Гарт Дженнингс, Кристоф Лоурделет
# 5641  Д.Киселев, А.Першин (Ж.Крыжовников), А.Карпило...
#
#                                                producer  \
# 5653  Л.Верещагин, А.Златопольский, Н.Михалков, ООО ...
# 3742   Кристофер Меледандри, Джанет Хили, Бретт Хоффман
# 3235                                    Рэмси Энн Наито
# 3637             Игорь Хайт, Джанет Хили, Бретт Хоффман
# 5641                       Т.Бекмамбетов, Г.Стрижевская
#
#                     age_restriction  refundable_support  ...  \
# 5653  «6+» - для детей старше 6 лет                0.00  ...
# 3742  «6+» - для детей старше 6 лет                 NaN  ...
# 3235  «6+» - для детей старше 6 лет                 NaN  ...
# 3637  «6+» - для детей старше 6 лет                 NaN  ...
# 5641  «6+» - для детей старше 6 лет         50000000.00  ...
#
#       financing_source  ratings                          genres    box_office  \
# 5653         Фонд кино     7.50                     спорт,драма 2779686144.00
# 3742           Частное     6.30   мультфильм,фантастика,фэнтези 1390392637.00
# 3235           Частное     6.50  мультфильм,комедия,приключения 1376726723.00
# 3637           Частное     7.30       мультфильм,мюзикл,комедия  886614109.00
# 5641         Фонд кино     5.80               комедия,мелодрама  855451052.00
#
#      gos_fin_perc  show_year  main_genres   main_director             new  \
# 5653         0.68       2017        спорт    А.Мегердичев    А.Мегердичев
# 3742          NaN       2017   мультфильм      Кайл Балда      Кайл Балда
# 3235          NaN       2017   мультфильм     Том МакГрат     Том МакГрат
# 3637          NaN       2017   мультфильм  Гарт Дженнингс  Гарт Дженнингс
# 5641         0.57       2017      комедия       Д.Киселев       Д.Киселев
#
#         new_director
# 5653    А.Мегердичев
# 3742      Кайл Балда
# 3235     Том МакГрат
# 3637  Гарт Дженнингс
# 5641       Д.Киселев
#
# [5 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Общие продажи - не самая лучшая метрика для поиска наиболее прибыльной категории. Мы можем найти возрастную категорию, где фильмы стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>  Поменяла категорию для анализа на медиану, чуть подкорректировала выводы, добавила два рейтинга</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# Отлично)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Замечательная работа по исследовательскому анализу и визуализации)

# %% [markdown]
# ### Шаг 4. Исследуйте фильмы, которые получили государственную поддержку
#
# На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг.

# %% [markdown]
# Рассмотрим отдельно фильмы с гос.поддержкой.

# %%
#сделаем для них отдельный датафрейм
gosmovies = movies.query('financing_source != "Частное"')

# %%
print('в 2010 - 2019 годах вышло', len(gosmovies), 'фильма с государственной поддержкой.')
# Out:
# в 2010 - 2019 годах вышло 332 фильма с государственной поддержкой.

# %%
count_gosmovies = (
    gosmovies.pivot_table(index = 'show_year',
                 values = 'puNumber',
                 aggfunc = 'count')
)

count_gosmovies.columns = ['количество фильмов']

print(count_gosmovies)



count_gosmovies.plot(kind = 'bar',
   title = 'Количество вышедших с госудраственной поддержкой фильмов');
# Out:
#            количество фильмов
# show_year
# 2013                        2
# 2014                       16
# 2015                       86
# 2016                       61
# 2017                       41
# 2018                       56
# 2019                       70

# %% [markdown]
# Самым активным, в плане фильмопроизвосдтва был 2015 год. Это касается как всех фильмов, там и конкретно фильмов с государственной поддержкой. аналогично и с 2017, самый тихий год в общем киномире и конкретно по фильмам с господдержкой.
#
# Рассмотрим, разбивку по источникам финансирования.

# %%
fig, ax = plt.subplots(figsize=(10,5))

colors = {"Министерство культуры, Фонд кино":"gray", "Министерство культуры":"blue", "Фонд кино":"red"}
data = []
labels = []
for i in gosmovies["financing_source"].unique():
    data.append(gosmovies.loc[gosmovies["financing_source"]==i, "show_year"].values)
    labels.append(i)

ax.hist(data, 10, alpha=0.75, label=labels)
ax.legend(prop={'size': 10})
fig.tight_layout()
plt.show()

# %% [markdown]
# А каких-то году больше фильмов спонсирует министерство культуры, в каком-то фонд кино. Тут нет четкой закономерности.

# %%
fin_gosmovies =  (
    gosmovies.pivot_table(index = 'show_year', 
                          values = 'budget',
                          aggfunc = 'sum')
)

fin_gosmovies.columns = ['суммарный бюджет фильмов']

print(fin_gosmovies)
fin_gosmovies.plot(kind='bar',
                   title = 'суммарный бюджет фильмов вышедших с государственной поддержкой');
# Out:
#            суммарный бюджет фильмов
# show_year
# 2013                   255435390.00
# 2014                  1317189701.03
# 2015                  8012947895.52
# 2016                  7763368977.51
# 2017                  7111516830.30
# 2018                  7223775724.16
# 2019                 12837948576.21

# %% [markdown]
# Объемы шокируют. Динамика объемов спонсирования в кино по годам. Опять наблюдается резкий скачок в 2015 с 255 миллионов рублей до 8 миллиардов. Причин могут быть 2, и резкий скачок курса доллара, и большЕЕ количество фильмов по сравнению с предыдущими годами. Количество вышедших в прокат фильмов в 2015 году больше чем в 5 раз больше, по отношение к предыдущем году.
#
# Далее годовой бюджет потихоньку идет на убыль.
#
# Второй резкий скачок финансирования был в 2019 году, с 7 миллиардов рублей до 12.3.
# Посмотрим медианное значение денежных вливаний в фильм по годам. Но исключим

# %%
medianfin_gosmovies = (
    movies.query('financing_source != "Частное"')
    .pivot_table(index = 'show_year', 
                 values = 'budget',
                 aggfunc = 'median')
)

medianfin_gosmovies.columns = ['Медианный бюджет фильма с государственной поддержкой']
print(medianfin_gosmovies)    
medianfin_gosmovies.plot(kind = 'bar',
     title = 'Медианный бюджет фильма с государственной поддержкой');
# Out:
#            Медианный бюджет фильма с государственной поддержкой
# show_year
# 2013                                            127717695.00
# 2014                                             61036441.50
# 2015                                             57727750.09
# 2016                                             69883049.00
# 2017                                             78096315.00
# 2018                                            103984842.37
# 2019                                             78388683.00

# %% [markdown]
# В 2013-м году вышло всего 2 фильма. Потому этот год не показательный.
#
#
# Средняя стоимость фильма в 2015 году упала с 61 до 57 миллионов рублей. Значит увеличение объемов финансирования связано исключительно с количеством фильмов.
#
# Самые дорогие фильмы выходили в 2018-м году, средний бюджет был 103 миллиона.
#
# Рассмотрим статистику по сборам.

# %%
gen_gosmovies = gosmovies.pivot_table(index = 'show_year',
                      values = 'box_office',
                      aggfunc = ['sum', 'median', 'mean'])
gen_gosmovies.columns =  ['Общие кассовые сборы', 'Медианные кассовые сборы', 'Средние кассовые сборы']
gen_gosmovies
# Out:
#            Общие кассовые сборы  Медианные кассовые сборы  \
# show_year
# 2013                20322385.10               10161192.55
# 2014              1017422166.60                5504517.85
# 2015              5785285418.14                9200824.50
# 2016              6081707839.10               17921115.61
# 2017             10865075300.96               50451949.00
# 2018              9934069010.25               27023390.31
# 2019              8409627454.63               25977291.30
#
#            Средние кассовые сборы
# show_year
# 2013                  10161192.55
# 2014                  63588885.41
# 2015                  68062181.39
# 2016                 101361797.32
# 2017                 278591674.38
# 2018                 177394089.47
# 2019                 140160457.58

# %% [markdown]
# Очень большие различия между кассовыми медианными и средними кассовыми сборами с 2016-го по 2019-й год. Это говорит нам о наличии какие-то ультрапопулярных фильмах в эти года. Визуализируем это.

# %%
years = [2015, 2016, 2017, 2018, 2019]
for year in years:
    gosmovies.query('show_year == @year').boxplot(column = 'box_office')
    plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Здорово, что используешь цикл для автоматизации)

# %% [markdown]
# Так и есть. Есть выбросы в разы превыщающие средние показатели. Не будем тх исключать из данных, чтобы потом в рейтингах видеть все фильмы. Но для дальнейшего анализа используем медианные значения.

# %% [markdown]
# Рассмотрим корреляцию между объемами гос.вливаний и кассовыми сборами.

# %%
#Оставим только фильмы которые вышли в кинопрокат.
cass_gosmovies = gosmovies.query('box_office > 0')
cass_gosmovies['budget'].corr(cass_gosmovies['box_office'])
# Out:
# 0.3816710869350528

# %% [markdown]
#  Корреляция бюджета и сборов слабая.

# %% [markdown]
# Добавим столбец в котором будет расчитана разница между сбором и бюджетом, чтобы примерно представлять себе окупились ли те или иные фильмы.

# %%
gosmovies['profit'] = gosmovies['box_office'] - gosmovies['budget']
# Out:
# /tmp/ipykernel_31/2213146157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gosmovies['profit'] = gosmovies['box_office'] - gosmovies['budget']

# %% [markdown]
# Посмотрим на 15 фильмов, с самыми большими ~~надеждами~~ бюджетами.

# %%
gosmovies.sort_values(by = 'budget', ascending = False).head(15)
# Out:
#                      title   puNumber show_start_date            type  \
# 7114  Тайна Печати Дракона  111012819      2019-09-12  Художественный
# 5437              Матильда  111005717      2017-08-17  Художественный
# 7464         Союз спасения  111022019      2019-12-26  Художественный
# 7474             Вторжение  111022519      2019-12-23  Художественный
# 7171                  Грех  111014419      2019-08-31  Художественный
# 3351               Дуэлянт  111015416      2016-09-14  Художественный
# 2920              Экипаж .  111005416      2016-03-21  Художественный
# 5653        Движение вверх  111011817      2017-12-21  Художественный
# 6549                  Т-34  111024918      2018-12-21  Художественный
# 3255   Время первых (2017)  111001317      2017-02-21  Художественный
# 5569   Легенда о Коловрате  111007617      2017-11-30  Художественный
# 2142            Территория  111000515      2015-01-27  Художественный
# 6699                 Тобол  111002419      2019-02-16  Художественный
# 5502               Салют-7  111006917      2017-10-01  Художественный
# 6887               Девятая  111007019      2019-09-19  Художественный
#
#                                             film_studio production_country  \
# 7114  ООО "Кинокомпания "СТВ"; ООО "РФГ Корп"; ООО "...                США
# 5437                     ООО "ТПО "РОК", ООО "Матильда"                США
# 7464                                ЗАО "Дирекция кино"                США
# 7474       ООО "Арт Пикчерс Студия", ООО "Водород 2011"                США
# 7171  НО Фонд Андрея Кончаловского по поддержке кино...                США
# 3351                            ООО "Нон-Стоп Продакшн"                США
# 2920              ООО "Студия "ТРИТЭ" Никиты Михалкова"                США
# 5653              ООО "Студия "ТРИТЭ" Никиты Михалкова"                США
# 6549  ООО "Кинокомпания МАРС-фильм" по заказу ООО "М...                США
# 3255              ООО "ТаББаК", ООО "Студия Третий Рим"                США
# 5569                      ООО "Продюсерский центр ИВАН"                США
# 2142  ООО "Творческое объединение "Кинокомпания "Анд...                США
# 6699  ООО Кинокомпания "Соливс" по заказу АО "ВБД Груп"                США
# 5502                           ООО "Лемон Филмз Студио"                США
# 6887                            ООО "Нон-Стоп Продакшн"                США
#
#                                    director  \
# 7114                            О.Степченко
# 5437                              А.Учитель
# 7464                              А.Кравчук
# 7474                            Ф.Бондарчук
# 7171  А.Михалков (псевдоним А.Кончаловский)
# 3351                             А.Мизгирев
# 2920                              Н.Лебедев
# 5653                           А.Мегердичев
# 6549                              А.Сидоров
# 3255                              Д.Киселев
# 5569                          И.Шурховецкий
# 2142                              А.Мельник
# 6699                     И.Зайцев, О.Урушев
# 5502                              К.Шипенко
# 6887                             Н.Хомерики
#
#                                                producer  \
# 7114                             С.Сельянов, А.Петрухин
# 5437                    А.Учитель, А.Достман, В.Винокур
# 7464                                А.Максимов, К.Эрнст
# 7474  Ф.Бондарчук, М.Врубель, А.Андрющенко, Д.Рудовский
# 7171  НО Фонд Андрея Кончаловского по поддержке кино...
# 3351                          А.Роднянский, С.Мелькумов
# 2920  Л.Верещагин, А.Златопольский, Н.Михалков, ООО ...
# 5653  Л.Верещагин, А.Златопольский, Н.Михалков, ООО ...
# 6549  А.Златопольский, Р.Дишдишян, Л.Блаватник, Н.Яр...
# 3255                           Т.Бекмамбетов, Е.Миронов
# 5569  ООО "Централ Партнершип",              АО "Тел...
# 2142                                          А.Мельник
# 6699  Э.Илоян, В.Шляппо, Д.Жалинский, А.Троцюк, О.Ур...
# 5502           С.Сельянов, Б.Бакурадзе, А.Златопольский
# 6887                          С.Мелькумов, А.Роднянский
#
#                       age_restriction  refundable_support  ...  ratings  \
# 7114    «6+» - для детей старше 6 лет        180000000.00  ...     5.80
# 5437  «16+» - для детей старше 16 лет        110000000.00  ...     7.70
# 7464  «12+» - для детей старше 12 лет        100000000.00  ...     6.00
# 7474  «12+» - для детей старше 12 лет        100000000.00  ...     5.70
# 7171  «16+» - для детей старше 16 лет                0.00  ...     6.90
# 3351  «16+» - для детей старше 16 лет        150000000.00  ...     6.60
# 2920    «6+» - для детей старше 6 лет         50000000.00  ...     7.60
# 5653    «6+» - для детей старше 6 лет                0.00  ...     7.50
# 6549  «12+» - для детей старше 12 лет         60000000.00  ...     6.50
# 3255    «6+» - для детей старше 6 лет         75000000.00  ...     7.50
# 5569  «12+» - для детей старше 12 лет        100000000.00  ...     6.40
# 2142  «12+» - для детей старше 12 лет         30000000.00  ...     6.80
# 6699  «16+» - для детей старше 16 лет                0.00  ...     5.80
# 5502  «12+» - для детей старше 12 лет                0.00  ...     7.40
# 6887  «16+» - для детей старше 16 лет                0.00  ...     5.80
#
#                              genres    box_office  gos_fin_perc show_year  \
# 7114            приключения,фэнтези  333597059.59          0.12      2019
# 5437       фэнтези,комедия,семейный  511775548.00          0.29      2017
# 7464        история,биография,драма  717703185.53          0.51      2019
# 7474              фантастика,боевик           NaN          0.53      2019
# 7171        драма,биография,история   54243202.71          0.08      2019
# 3351                          драма  364285139.60          0.66      2016
# 2920      драма,триллер,приключения 1402255390.00          0.70      2016
# 5653                    спорт,драма 2779686144.00          0.68      2017
# 6549           драма,военный,боевик 2271754004.52          0.32      2018
# 3255  приключения,триллер,биография  544332260.00          0.47      2017
# 5569         история,боевик,фэнтези  590405065.00          0.70      2017
# 2142       детектив,фэнтези,триллер   72578317.40          0.12      2015
# 6699                  история,драма  138162876.53          0.26      2019
# 5502      драма,приключения,триллер  752679777.00          0.46      2017
# 6887      детектив,триллер,криминал   55876887.40          0.66      2019
#
#       main_genres                          main_director  \
# 7114  приключения                            О.Степченко
# 5437      фэнтези                              А.Учитель
# 7464      история                              А.Кравчук
# 7474   фантастика                            Ф.Бондарчук
# 7171        драма  А.Михалков (псевдоним А.Кончаловский)
# 3351        драма                             А.Мизгирев
# 2920        драма                              Н.Лебедев
# 5653        спорт                           А.Мегердичев
# 6549        драма                              А.Сидоров
# 3255  приключения                              Д.Киселев
# 5569      история                          И.Шурховецкий
# 2142     детектив                              А.Мельник
# 6699      история                               И.Зайцев
# 5502        драма                              К.Шипенко
# 6887     детектив                             Н.Хомерики
#
#                                         new  \
# 7114                            О.Степченко
# 5437                              А.Учитель
# 7464                              А.Кравчук
# 7474                            Ф.Бондарчук
# 7171  А.Михалков (псевдоним А.Кончаловский)
# 3351                             А.Мизгирев
# 2920                              Н.Лебедев
# 5653                           А.Мегердичев
# 6549                              А.Сидоров
# 3255                              Д.Киселев
# 5569                          И.Шурховецкий
# 2142                              А.Мельник
# 6699                               И.Зайцев
# 5502                              К.Шипенко
# 6887                             Н.Хомерики
#
#                                new_director         profit
# 7114                            О.Степченко -1971477243.41
# 5437                              А.Учитель  -521130409.00
# 7464                              А.Кравчук  -262296814.47
# 7474                            Ф.Бондарчук            NaN
# 7171  А.Михалков (псевдоним А.Кончаловский)  -725698762.29
# 3351                             А.Мизгирев  -319915396.40
# 2920                              Н.Лебедев   766971523.00
# 5653                           А.Мегердичев  2189493953.00
# 6549                              А.Сидоров  1707969287.52
# 3255                              Д.Киселев    15890283.00
# 5569                          И.Шурховецкий    90392336.00
# 2142                              А.Мельник  -427421682.60
# 6699                               И.Зайцев  -361663692.47
# 5502                              К.Шипенко   258945820.00
# 6887                             Н.Хомерики  -397827778.60
#
# [15 rows x 23 columns]

# %% [markdown]
# "Тайна печати дракона" стоил нашему государству дороже всего, 2.3 миллиарда рублей. Возможно из-за гонарара Джеки Чана?) Хоть на каскадерах сэкономили.
#
# А вот по сборам.... Тадададааам, неутешительно, этот же фильм оглушает своим провалом. Убыток от его создания порядка двух миллиардов рублей.

# %%
print('С 2010 по 2019 ФК и МинКульт вложили в создание фильмов', round(gosmovies['budget'].sum()))
print('Эти фильмы собрали в кино', round(gosmovies['box_office'].sum()))
print('таким образом суммарная "условная прибыль"', round(gosmovies['profit'].sum()))
# Out:
# С 2010 по 2019 ФК и МинКульт вложили в создание фильмов 44522183095
# Эти фильмы собрали в кино 42113509575
# таким образом суммарная "условная прибыль" -754575739

# %% [markdown]
# Прибыль ушла в минус. То есть фильмы спонсируемые ФК и МинКультом в сумме принесли убытки.

# %% [markdown]
# Фильмы каких жанров больше собирают в прокате?

# %%
gosmovies.groupby('main_genres')['box_office'].sum().sort_values(ascending = False)
# Out:
# main_genres
# комедия       12479977454.33
# драма          9490844101.04
# мультфильм     5622014134.66
# спорт          2967768387.44
# фантастика     1718204279.39
# не указан      1481748724.64
# история        1455468234.57
# приключения    1205596976.62
# военный        1017670471.80
# фэнтези         995836607.97
# ужасы           710123189.35
# триллер         700450190.14
# боевик          595928934.50
# семейный        584424749.65
# биография       516883037.64
# криминал        239793863.00
# детектив        138547511.40
# мюзикл          101705004.98
# мелодрама        54788966.23
# реальное ТВ      32721103.43
# детский           3013652.00
# Name: box_office, dtype: float64

# %% [markdown]
# На комедии в кино люди идут охотнее всего.
#
# А на какие больше всего выделяют деньги?

# %%
gosmovies.groupby('main_genres')['budget'].sum().sort_values(ascending = False)
# Out:
# main_genres
# драма         11174837507.67
# комедия        6300832781.64
# мультфильм     6154351926.02
# приключения    3374742189.00
# фантастика     2602936880.57
# фэнтези        2340123765.00
# история        2145062206.00
# триллер        1389321595.74
# военный        1285906825.00
# детектив       1198222297.00
# не указан      1170780249.08
# мелодрама       955710252.03
# боевик          734584348.98
# спорт           710468965.00
# семейный        636799787.00
# мюзикл          564197472.00
# ужасы           563877625.00
# биография       528933637.00
# криминал        426594781.00
# детский         183898004.00
# реальное ТВ      80000000.00
# Name: budget, dtype: float64

# %% [markdown]
# Драмы влетают в копеечку.
#
# Но первая тройка и по сборам и по бюджеты совпадает, это комедии, драмы и мультфильмы.

# %% [markdown]
# Посмотрим на 10 самых кассовых фильмов.

# %%
top_gosmovies = movies.query('financing_source != "Частное"').sort_values(by = 'box_office', ascending=False).head(10)
top_gosmovies
# Out:
#                                 title   puNumber show_start_date  \
# 7456                            Холоп  111021719      2019-12-19
# 5653                   Движение вверх  111011817      2017-12-21
# 6549                             Т-34  111024918      2018-12-21
# 5505               Последний богатырь  111007017      2017-10-19
# 5708                              Лёд  111000518      2018-02-01
# 2920                         Экипаж .  111005416      2016-03-21
# 3565                Притяжение (2016)  111018116      2016-12-16
# 5641                       Ёлки Новые  111011617      2017-12-21
# 5826                           Тренер  111003218      2018-04-19
# 5659  Три богатыря и принцесса Египта  114003317      2017-12-21
#
#                 type                                        film_studio  \
# 7456  Художественный            ООО "МЕМ-МЕДИА" по заказу АО "ВБД Груп"
# 5653  Художественный              ООО "Студия "ТРИТЭ" Никиты Михалкова"
# 6549  Художественный  ООО "Кинокомпания МАРС-фильм" по заказу ООО "М...
# 5505  Художественный  ООО "Киностудия "Слово" по заказу ООО "Уолт Ди...
# 5708  Художественный  ООО "Водород 2011", ООО "Арт Пикчерс Студия", ...
# 2920  Художественный              ООО "Студия "ТРИТЭ" Никиты Михалкова"
# 3565  Художественный      ООО "Водород 2011",  ООО "Арт Пикчерс Студия"
# 5641  Художественный                                       ООО "ТаББаК"
# 5826  Художественный  ООО "ДК интертеймент", ООО "Киностудия "Слово"...
# 5659    Анимационный          ООО "Студия анимационного кино "Мельница"
#
#      production_country                                           director  \
# 7456                США                                          К.Шипенко
# 5653                США                                       А.Мегердичев
# 6549                США                                          А.Сидоров
# 5505                США                                         Д.Дьяченко
# 5708                США                                           О.Трофим
# 2920                США                                          Н.Лебедев
# 3565                США                                        Ф.Бондарчук
# 5641                США  Д.Киселев, А.Першин (Ж.Крыжовников), А.Карпило...
# 5826                США                                       Д.Козловский
# 5659                США                                       К.Феоктистов
#
#                                                producer  \
# 7456  Э.Илоян, Д.Жалинский, В.Дусмухаметов, Т.Бадзие...
# 5653  Л.Верещагин, А.Златопольский, Н.Михалков, ООО ...
# 6549  А.Златопольский, Р.Дишдишян, Л.Блаватник, Н.Яр...
# 5505  Э.Илоян, Д.Жалинский, М.Озкан, А.Троцюк, В.Шляппо
# 5708  М.Врубель, А.Андрющенко, Ф.Бондарчук, Д.Рудовс...
# 2920  Л.Верещагин, А.Златопольский, Н.Михалков, ООО ...
# 3565                           ООО "Арт Пикчерс Студия"
# 5641                       Т.Бекмамбетов, Г.Стрижевская
# 5826  Д.Козловский, П.Ануров, Л.Верещагин, А.Златопо...
# 5659                             С.Сельянов, А.Боярский
#
#                       age_restriction  refundable_support  ...  \
# 7456  «12+» - для детей старше 12 лет         25000000.00  ...
# 5653    «6+» - для детей старше 6 лет                0.00  ...
# 6549  «12+» - для детей старше 12 лет         60000000.00  ...
# 5505  «12+» - для детей старше 12 лет         50000000.00  ...
# 5708  «12+» - для детей старше 12 лет         25000000.00  ...
# 2920    «6+» - для детей старше 6 лет         50000000.00  ...
# 3565  «12+» - для детей старше 12 лет                0.00  ...
# 5641    «6+» - для детей старше 6 лет         50000000.00  ...
# 5826  «12+» - для детей старше 12 лет                0.00  ...
# 5659    «6+» - для детей старше 6 лет         50000000.00  ...
#
#       financing_source  ratings                           genres  \
# 7456         Фонд кино     6.80                          комедия
# 5653         Фонд кино     7.50                      спорт,драма
# 6549         Фонд кино     6.50             драма,военный,боевик
# 5505         Фонд кино     6.80      комедия,фэнтези,приключения
# 5708         Фонд кино      NaN                        не указан
# 2920         Фонд кино     7.60        драма,триллер,приключения
# 3565         Фонд кино     5.60                       фантастика
# 5641         Фонд кино     5.80                комедия,мелодрама
# 5826         Фонд кино     6.80                      драма,спорт
# 5659         Фонд кино     5.50  мультфильм,приключения,семейный
#
#         box_office gos_fin_perc  show_year  main_genres  main_director  \
# 7456 3073568690.79         0.38       2019      комедия      К.Шипенко
# 5653 2779686144.00         0.68       2017        спорт   А.Мегердичев
# 6549 2271754004.52         0.32       2018        драма      А.Сидоров
# 5505 1655037688.00         0.28       2017      комедия     Д.Дьяченко
# 5708 1445731797.89         0.57       2018    не указан       О.Трофим
# 2920 1402255390.00         0.70       2016        драма      Н.Лебедев
# 3565 1038321489.00          inf       2016   фантастика    Ф.Бондарчук
# 5641  855451052.00         0.57       2017      комедия      Д.Киселев
# 5826  820528005.21         0.67       2018        драма   Д.Козловский
# 5659  759226773.00         0.29       2017   мультфильм   К.Феоктистов
#
#                new  new_director
# 7456     К.Шипенко     К.Шипенко
# 5653  А.Мегердичев  А.Мегердичев
# 6549     А.Сидоров     А.Сидоров
# 5505    Д.Дьяченко    Д.Дьяченко
# 5708      О.Трофим      О.Трофим
# 2920     Н.Лебедев     Н.Лебедев
# 3565   Ф.Бондарчук   Ф.Бондарчук
# 5641     Д.Киселев     Д.Киселев
# 5826  Д.Козловский  Д.Козловский
# 5659  К.Феоктистов  К.Феоктистов
#
# [10 rows x 22 columns]

# %% [markdown]
# Топ - "Холоп", "Движение вверх", "Т-34", "Последний богатырь", "Лед".
#
# Все эти фильмы вышли при поддержке Фонда Кино. Что оправдано, ведь ФК как раз спонсирует в основном более коммерческие понятныеи фильмы. В то время, как министерство кино поддерживает больше неккомерческих, детских, документальных и авторских фильмов.

# %% [markdown]
# Какие же фильмы самые любимые зрителями

# %%
toprating_gosmovies = movies.query('financing_source != "Частное"').sort_values(by = 'ratings', ascending=False).head(10)
toprating_gosmovies
# Out:
#                         title   puNumber show_start_date            type  \
# 2146                  Главный  111003415      2015-03-27  Художественный
# 3139            Я умею вязать  111019615      2015-11-27  Художественный
# 3627                  БОЛЬШОЙ  111017416      2016-11-22  Художественный
# 1870   А зори здесь тихие..._  111002915      2015-03-16  Художественный
# 6855                 Миллиард  111006719      2019-04-17  Художественный
# 1281            Пока еще жива  111005313      2013-10-11  Художественный
# 3782                 Мотылёк.  111001617      2017-03-22  Художественный
# 7180  Байкал - Сердце мира 3D  112004619      2019-11-01  Документальный
# 7254                    Герой  111015819      2019-09-26  Художественный
# 2482                Однажды._  111004215      2015-04-15  Художественный
#
#                                             film_studio production_country  \
# 2146                           ООО "Киностудия "МАСТЕР"                США
# 3139                                ООО "Белое Зеркало"                США
# 3627   ЗАО "ПРОДЮСЕРСКАЯ КОМПАНИЯ ВАЛЕРИЯ ТОДОРОВСКОГО"                США
# 1870                        ООО "Компания "Реал-Дакота"                США
# 6855                        ООО "Медиа Юниверсал Ивент"                США
# 1281  АНО содействия развитию кинематографии "Ангел-...                США
# 3782                             ООО "Кинокомпания КИТ"                США
# 7180              ООО "Продюсерский центр "Новое Время"                США
# 7254                                        ООО "Карго"                США
# 2482        ООО "Компания "РЕАЛ-ДАКОТА", НП "Интерфест"                США
#
#                                director  \
# 2146                             Ю.Кара
# 3139  Н.Степанова при участии С.Иванова
# 3627                      В.Тодоровский
# 1870                      Р.Давлетьяров
# 6855                         Р.Прыгунов
# 1281                         А.Атанесян
# 3782                          К.Худяков
# 7180                           А.Попова
# 7254                         К.Оганисян
# 2482                      Р.Давлетьяров
#
#                                      producer  \
# 2146                                   Ю.Кара
# 3139                С.Кикнавелидзе, Д.Улюкаев
# 3627           В.Тодоровский, А.Златопольский
# 1870                                не указан
# 6855        В.Маслов, В.Верещагин, Б.Анисимов
# 1281         А.Атанесян, М.Бабаханов, Р.Бутко
# 3782                     Е.Бабенко, В.Ремизов
# 7180  И.Добровольский, А.Разуваева, Ю.Перкуль
# 7254                               К.Оганисян
# 2482             Р.Давлетьяров, А.Котелевский
#
#                              age_restriction  refundable_support  ...  \
# 2146           «6+» - для детей старше 6 лет                0.00  ...
# 3139         «16+» - для детей старше 16 лет                0.00  ...
# 3627         «12+» - для детей старше 12 лет         10000000.00  ...
# 1870         «12+» - для детей старше 12 лет         50000000.00  ...
# 6855         «12+» - для детей старше 12 лет                0.00  ...
# 1281         «16+» - для детей старше 16 лет                0.00  ...
# 3782             «18+» - запрещено для детей          7346881.00  ...
# 7180  «0+» - для любой зрительской аудитории                0.00  ...
# 7254         «12+» - для детей старше 12 лет         20000000.00  ...
# 2482         «16+» - для детей старше 16 лет                0.00  ...
#
#                       financing_source  ratings                     genres  \
# 2146             Министерство культуры     9.40  фантастика,боевик,комедия
# 3139             Министерство культуры     9.00                      драма
# 3627                         Фонд кино     8.50    криминал,комедия,боевик
# 1870                         Фонд кино     8.50      драма,военный,история
# 6855                         Фонд кино     8.20                      драма
# 1281             Министерство культуры     8.10            драма,мелодрама
# 3782  Министерство культуры, Фонд кино     8.00                      драма
# 7180             Министерство культуры     8.00                   семейный
# 7254                         Фонд кино     7.90       фэнтези,боевик,драма
# 2482                         Фонд кино     7.90    драма,криминал,детектив
#
#        box_office gos_fin_perc  show_year  main_genres  \
# 2146    334750.00         0.25       2015   фантастика
# 3139    801370.00         0.32       2015        драма
# 3627 228578204.00         0.66       2016     криминал
# 1870 249166767.70         0.68       2015        драма
# 6855 408646665.70         0.58       2019        драма
# 1281    365353.60         0.33       2013        драма
# 3782    410058.00         0.59       2017        драма
# 7180          NaN         0.09       2019     семейный
# 7254 172871342.04         0.48       2019      фэнтези
# 2482  12748398.30         0.62       2015        драма
#
#                           main_director                                new  \
# 2146                             Ю.Кара                             Ю.Кара
# 3139  Н.Степанова при участии С.Иванова  Н.Степанова при участии С.Иванова
# 3627                      В.Тодоровский                      В.Тодоровский
# 1870                      Р.Давлетьяров                      Р.Давлетьяров
# 6855                         Р.Прыгунов                         Р.Прыгунов
# 1281                         А.Атанесян                         А.Атанесян
# 3782                          К.Худяков                          К.Худяков
# 7180                           А.Попова                           А.Попова
# 7254                         К.Оганисян                         К.Оганисян
# 2482                      Р.Давлетьяров                      Р.Давлетьяров
#
#                            new_director
# 2146                             Ю.Кара
# 3139  Н.Степанова при участии С.Иванова
# 3627                      В.Тодоровский
# 1870                      Р.Давлетьяров
# 6855                         Р.Прыгунов
# 1281                         А.Атанесян
# 3782                          К.Худяков
# 7180                           А.Попова
# 7254                         К.Оганисян
# 2482                      Р.Давлетьяров
#
# [10 rows x 22 columns]

# %% [markdown]
# Здесь уже гораздо чаще встречаются фильмы спонсируемые Фондом Кино.
#
# А вообще подборка, не самая популярная. Интересно было бы посмотреть количество оценок и исключить фильмым с низким количеством. Возможно картина изменилась бы.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Ты отлично справилась с исследовнием фильмов с гос. поддержкой

# %% [markdown]
# ### Шаг 5. Напишите общий вывод

# %% [markdown]
# **1.** Мы взяли два массива данных, опубликованных на портале открытых данных министерства культуры РФ.
#
# Один содержал в себе информацию о фильмах получивших прокатное удостоверение, такую как: год лицензии, страна, жанры, режисссеры, продюсссеры, бюджет, категория и пр. Во втором информация о кассовых сборах.
#
#
# **2.** Предобработка данных.
#
# - Проведена работа по коррекции типов и формата данных:
#
#   - Объеденена информация из двух датафреймов в один.
#
#   - Подкорректирован столбец в датой начала проката.
#
#   - Данные о рейтингах приведены в к общему виду.
#
# - Изучены и обрботаны пропуски:
#
#   - Кино которое не получало государственного субсидирования отметили как "частное".
#
#   - Проставили 0, в информации об объёмах государственных средств, где их не было.
#
#   - Пропуски в категориях страна, продюссер, режиссер и жанр заменила на "не указано".
#
#   - Пропуски в рейтингах оставили без изменений.
#
#   - Пропуски в кассовых сборах,тоже оставили без изменений.
#
# - Проведена работа по обработке явных и неявных дубликатов:
#
#   - Заменили дубликаты в графе о номере прокатного удостоверия.
#
#   - Откорректировали даные в графах 'type', 'film_studio', 'production_country', 'producer', 'director', 'genres', удалив них лишние пробелы, тем самым исключив наличие неявных дубликатов.
#
#   - Привели знаки пунктуации в графе страна-производитель к общему виду.
#
# - Обработали недостаящие количественные значение в таблице:
#
#   - Расчитали медианный коэффициент поддержки фильмов государством.
#
#   - Зная этот коэффициент расчитали и дополнили таблицу данными о бюджете.
#
# - Добавлены новые столбцы с данными о:
#
#   - году проката
#
#   - главном жанре
#
#   - главном режиссере
#
#
# **3.** Исследовательский анализ:
#
# 1) Количество выпускаемых фильмов:
#
# - Самое большее число фильмов получивших прокатное удостоверение было в 2010-м году.
#
# Из них в кинопрокат попало 105, это 10%, Это самый маленьких показатель среди всег годов.
#
# - Меньше всего фильмов вышло в 2017-м году, из них в кинотеатры попало 357, это 70%. Это самый высокий показатель.
#
# Данные наглядно представлены на графике.
#
# 2) Кассовые сборы:
#
# - Самым скромным - 2010-й год, всего около 2.5 миллионов общих кассовых сборов.
# - Резкий взлет объемов выручки в 2015-связан с усилением доллара относительно рубля.
# - Самым урожайным на кассовые сборы оказался 2018-й год, 49 миллиардов рублей.
# - Медианная прибыль по фильмам:
#
#   - резкий скачок доходность, опять связанос курсом доллара.
#   - Далее чем большее количество фильмов выходило в год, тем ниже средняя доходность на 1 фильм.
#
# Данные визуализированы таблицей и графиком.
#
# 3) Возрастная категория:
#
# - Фильмы категории 12+, 16+, 18+ показывают стобильную динамику.
#
# - Скачки есть в 2-17-м году, в категориях 0+ и 6+. Добавлен рейтинг фильмо
#
# **4.** Анализ фильмов с государственной поддержкой.
#
# 1)Количество вышедших фильмов.
#
# - Всего с 2010 по 2019-й год при госуударственной поддержке вышло 322 фильма.
# - Динамика количества вышедших фильмовс гос.под. по годам совпадает с с динамикой всех фильмов. В 2015-м большевышло больше всего фильмов, 86, к 2017-му резкий спад, 41 фильм.
# - Данные дполнены графиком количества вышедших фильмо с разбивкой по источникам финансирования.
#
# 2) Бюджет.
#
# - Первй резкий скачок объемов финансирования в 2015-м году, 8 миллиардов рублей.
# Опять же это момент, подорожания доллара.
#
# - Второй в 2019, 12.8 миллиардов рублей.
#
# - Средняя стоимость фильма в 2015 году упала с 61 до 57 миллионов рублей. Значит увеличение объемов финансирования связано исключительно с количеством фильмов.
#
# - Самые дорогие фильмы выходили в 2018-м году, средний бюджет был 103 миллиона.
#
# 3) Сборы.
#
# - Сборы по годам, очень разномастны и неоднозанчны. Большие ращличия между медианный и средними значениями, говорит нам о наличии выбросов. Что-то ультрапопулярное меняет картину достаточно резко.
#
# - Корреляция между денежными вливаниями и сборами слабая.
#
# - Составлена таблица с 15-ю самыми кассовыми фильмами.
#
# - Даблица дополнена столбцом с разницей между бюджетом и прибылью, она примерно показывает окупаемость тех или иных фильмов.
#
# - Финансирование фильмов не окупается.
#
# С 2010 по 2019 ФК и МинКульт вложили в создание фильмов 44 522 183 095 руб.
#
# Эти фильмы собрали в кино 42 113 509 575 руб.
#
# Таким образом убыток составил 754 575 739 руб.
#
# - Составлен рейтинг 10 самых доходных фильмов.
#
# Топ - "Холоп", "Движение вверх", "Т-34", "Последний богатырь", "Лед". Все эти фильмы вышли при поддержке Фонда Кино, что и логично, этот источник финансирует более коммерческие проекты.
#
#
#
# 4) Жанры.
#
# Больше всего денег приносят фильмы созданные в жанре:
#
# комедия       12 479 977 454.33 руб.
#
# драма          9 490 844 101.04 руб.
#
# мультфильм     5 622 014 134.66 руб.
#
# Больше всего денег было потрачено на создание:
#
# драма         11 174 837 507.67 руб.
#
# комедия        6 300 832 781.64 руб.
#
# мультфильм     6 154 351 926.02 руб.
#
# 5) Рейтинг.
#
# Составлен топ с самыми высокими оценками. В нем не самые известные фильмы. Скорее всего это связано с количеством оценок. Желательно добавить данные этим показателем и можно его еще раз исследовать.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
#  Содержательный вывод по проделанной работе!)

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <h2> Общий комментарий ревьюера 😊 v_3<a class="tocSkip"> </h2>
#     <br/>
# Мария,  спасибо за проект! Успехов в дальнейшем обучении!)

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <h2> Общий комментарий ревьюера 😊 v_2<a class="tocSkip"> </h2>
#     <br/>
#
# Мария, нужно доработать) Оставила комментарии с пояснениями)

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <h2> Общий комментарий ревьюера 😊<a class="tocSkip"> </h2>
#     <br/>
# Мария, ты проделала прекрасную работу, основные задачи проекта выполнены. Все расчеты проведены совершенно верно, также не могу не выделить аккуратность работы, визуализацию и работу с циклами!
#
# Необходимо доработать:
#
# * Дубликаты
# * Категориальные столбцы
# * Объединение таблиц
# * Остальные комментарии ты найдешь в работе
#
# **Желаю удачи и жду твой проект на повторное ревью! Если у тебя вдруг есть какие–либо вопросы, то я с радостью отвечу на них 😊**
#
# ![gif](https://i.gifer.com/378.gif)
#
# Также оставлю дополнительный материал по визуализации, если будет интересно:
#
#
# * книга Александра Богачева [Графики, которые убеждают всех](https://book24.ru/product/grafiki-kotorye-ubezhdayut-vsekh-5873820/)
# * [cheatsheet по визуализации](https://extremepresentation.typepad.com/.a/6a00d8341bfd2e53ef0111683a7591970c-pi)
# * бесплатный курс от Яндекс.Практикум [Визуальныe презентации](https://practicum.yandex.ru/visual-presentation/)
# * Формат таблиц в pandas с помощью style. В том числе цветовое выделение. (https://habr.com/ru/post/521894/)
# * Основные компоненты matplotlib (https://pyprog.pro/mpl/mpl_main_components.html)
# * 50 оттенков matplotlib — The Master Plots (с полным кодом на Python) (https://habr.com/ru/post/468295/)
# * Построение графиков с использованием двух осей. (https://matplotlib.org/stable/gallery/subplots_axes_and_figures/two_scales.html)
# * Сайт, подробно представлюящий практически все типы визуализаций. (https://datavizproject.com/)
# * Шпаргалка по визуализации данных в Python с помощью Plotly (https://habr.com/ru/post/502958/)
# </div>
